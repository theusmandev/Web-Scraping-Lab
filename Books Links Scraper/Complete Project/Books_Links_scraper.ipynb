# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import time
import xml.etree.ElementTree as ET
import os
import concurrent.futures
import random
from datetime import datetime
from threading import Lock
import re

# 🚀 Google Drive Mount (Optional)
try:
    from google.colab import drive
    drive.mount('/content/drive')
    SAVE_PATH_XLSX = "/content/drive/My Drive/Blogger_Novels.xlsx"
    FAILED_LINKS_FILE = "/content/drive/My Drive/failed_links.txt"
    PROGRESS_FILE = "/content/drive/My Drive/progress.txt"
    LOG_FILE = "/content/drive/My Drive/scrape_log.txt"
except ImportError:
    SAVE_PATH_XLSX = "Blogger_Novels.xlsx"
    FAILED_LINKS_FILE = "failed_links.txt"
    PROGRESS_FILE = "progress.txt"
    LOG_FILE = "scrape_log.txt"

# 📌 Headers & Session
HEADERS = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/121.0.0.0 Safari/537.36",
    "Accept": "text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,*/*;q=0.8",
    "Accept-Language": "en-US,en;q=0.5",
    "Connection": "keep-alive"
}
session = requests.Session()
session.headers.update(HEADERS)

# 🔄 Progress Lock
progress_lock = Lock()

# 📥 Step 1: Extract all post URLs from sitemap
SITEMAP_URL = "https://urdureadings.com/post-sitemap1.xml"
try:
    response = session.get(SITEMAP_URL, timeout=30)
    if response.status_code == 200:
        root = ET.fromstring(response.content)
        post_urls = [elem.text for elem in root.findall(".//{http://www.sitemaps.org/schemas/sitemap/0.9}loc")]
        print(f"✅ Found {len(post_urls)} posts to scrape.")
    else:
        print(f"❌ Failed to fetch sitemap: HTTP {response.status_code}")
        exit()
except ET.ParseError:
    print("❌ Failed to parse sitemap XML.")
    exit()
except requests.exceptions.RequestException as e:
    print(f"❌ Sitemap request failed: {e}")
    exit()

# 🔄 Resume Last Progress
last_index = 0
if os.path.exists(PROGRESS_FILE):
    try:
        with open(PROGRESS_FILE, "r") as f:
            last_index = int(f.read().strip())
    except (ValueError, IOError):
        print("⚠ Could not read progress file. Starting from index 0.")

# ⏳ Function to estimate remaining time
def estimate_time(start_time, processed, total):
    elapsed_time = time.time() - start_time
    avg_time_per_post = elapsed_time / processed if processed > 0 else 0
    remaining_posts = total - processed
    estimated_remaining_time = remaining_posts * avg_time_per_post
    return time.strftime('%H:%M:%S', time.gmtime(estimated_remaining_time))

# 🔍 Function to resolve redirects
def resolve_redirect(url):
    try:
        response = session.head(url, allow_redirects=True, timeout=10)
        return response.url
    except requests.exceptions.RequestException:
        return url

# 🔍 Step 2: Scrape Each Novel Post with Auto-Retry
def scrape_post(post_url):
    retries = 5
    for attempt in range(retries):
        try:
            response = session.get(post_url, timeout=60)
            if response.status_code == 429:
                print(f"⚠ Rate limit hit for {post_url}. Waiting...")
                time.sleep(2 ** attempt * 10)
                continue
            if response.status_code != 200:
                print(f"⚠ Retrying ({attempt+1}/{retries}) for {post_url}: HTTP {response.status_code}")
                time.sleep(5)
                continue

            soup = BeautifulSoup(response.text, "html.parser")

            # Extract Title (unchanged, since titles are working)
            title_selectors = [
                "h1.entry-title",
                "h2.entry-title",
                "h1.post-title",
                "h2.post-title",
                "h3.entry-title",
                "h3.post-title",
                "div.post-title",
                "div.entry-title",
                "h1",
                "h2",
                "h3"
            ]
            title = None
            title_element = None
            for selector in title_selectors:
                title_elem = soup.select_one(selector)
                if title_elem:
                    title = title_elem.text.strip()
                    title_element = title_elem
                    print(f"📌 Found title with selector '{selector}': '{title}' for URL: {post_url}")
                    break

            if not title or "digest library" in title.lower():
                headers = soup.find_all(["h1", "h2", "h3"])
                for header in headers:
                    text = header.text.strip()
                    if "digest library" not in text.lower() and len(text) > 10 and not text.lower().startswith("home"):
                        title = text
                        title_element = header
                        print(f"📌 Fallback title found: '{title}' for URL: {post_url}")
                        break

            if not title or "digest library" in title.lower():
                title_tag = soup.find("title")
                if title_tag:
                    title = title_tag.text.strip()
                    if "digest library" in title.lower():
                        title = title.replace("Digest Library", "").replace("|", "").strip()
                    print(f"📌 Title from <title> tag: '{title}' for URL: {post_url}")

            title = title if title and "digest library" not in title.lower() else "No Title Found"
            print(f"📌 Final title: '{title}' for URL: {post_url}")

            # Extract Download Links
            # 1. Get all <a> tags with href
            all_links = [a["href"] for a in soup.find_all("a", href=True)]
            # 2. Get URLs from <button> tags or data attributes
            button_links = [button.get("onclick", "").strip("'").replace("window.location.href=", "")
                           for button in soup.find_all("button") if button.get("onclick")]
            # 3. Resolve redirects for all links
            all_links = [resolve_redirect(link) for link in all_links + button_links if link]

            # 4. Filter for known download domains
            download_domains = ["drive.google", "mediafire", "dropbox", "mega.nz"]
            google_drive_links = [link for link in all_links if "drive.google" in link]
            mediafire_links = [link for link in all_links if "mediafire" in link]
            other_links = [link for link in all_links if any(domain in link for domain in ["dropbox", "mega.nz"])]

            # 5. Search entire page content for raw URLs
            content_selectors = ["div.post-body", "div.entry-content", "div.post-content", "article", "div.post"]
            content = None
            for selector in content_selectors:
                content = soup.select_one(selector)
                if content:
                    break
            if not content:
                content = soup  # Fallback to entire page

            raw_urls = []
            text = content.get_text()
            url_pattern = r'https?://[^\s<>"]+|www\.[^\s<>"]+'
            raw_urls = re.findall(url_pattern, text)
            raw_urls = [url for url in raw_urls if any(domain in url.lower() for domain in download_domains)]

            # Combine links
            google_drive_links.extend([url for url in raw_urls if "drive.google" in url and url not in google_drive_links])
            mediafire_links.extend([url for url in raw_urls if "mediafire" in url and url not in mediafire_links])
            other_links.extend([url for url in raw_urls if any(domain in url for domain in ["dropbox", "mega.nz"]) and url not in other_links])

            # Log for debugging
            with open(LOG_FILE, "a") as f:
                f.write(f"{datetime.now()}: URL: {post_url}, Title: {title}\n")
                f.write(f"  All <a> hrefs: {all_links}\n")
                f.write(f"  Button links: {button_links}\n")
                f.write(f"  Raw URLs from content: {raw_urls}\n")
                f.write(f"  Google Drive Links: {google_drive_links}\n")
                f.write(f"  Mediafire Links: {mediafire_links}\n")
                f.write(f"  Other Links: {other_links}\n")
                if title_element:
                    parent = title_element.find_parent()
                    context = str(parent)[:200] if parent else "No parent"
                    f.write(f"  Title Context: {context}\n")
                # Log content snippet for debugging
                content_snippet = text[:200].replace('\n', ' ')
                f.write(f"  Content Snippet: {content_snippet}\n")

            return {
                "Title": title,
                "Google Drive Links": ", ".join(google_drive_links) if google_drive_links else "No Google Drive Link",
                "Mediafire Links": ", ".join(mediafire_links) if mediafire_links else "No Mediafire Link",
                "Other Links": ", ".join(other_links) if other_links else "No Other Links"
            }
        except requests.exceptions.RequestException as e:
            print(f"⚠ Attempt {attempt+1} failed for {post_url}: {e}")
            time.sleep(5)

    # ❌ Save failed link
    with open(FAILED_LINKS_FILE, "a") as f:
        f.write(post_url + "\n")
    return None

# 📌 Step 3: Scrape Each Post & Save Data in Batches
novels_data = []
BATCH_SIZE = 20
start_time = time.time()

with concurrent.futures.ThreadPoolExecutor(max_workers=5) as executor:
    future_to_url = {executor.submit(scrape_post, post_urls[idx]): idx for idx in range(last_index, len(post_urls))}

    for count, future in enumerate(concurrent.futures.as_completed(future_to_url), start=1):
        idx = future_to_url[future]
        result = future.result()
        if result:
            novels_data.append(result)

        # ✅ Save every batch of 100 posts
        if len(novels_data) >= BATCH_SIZE:
            df = pd.DataFrame(novels_data)
            try:
                if os.path.exists(SAVE_PATH_XLSX):
                    existing_df = pd.read_excel(SAVE_PATH_XLSX, engine='openpyxl')
                    df = pd.concat([existing_df, df], ignore_index=True)
                df.to_excel(SAVE_PATH_XLSX, index=False, engine='openpyxl')
                novels_data = []
                with progress_lock:
                    with open(PROGRESS_FILE, "w") as f:
                        f.write(str(idx))
            except (PermissionError, IOError) as e:
                print(f"❌ Cannot write to {SAVE_PATH_XLSX}: {e}")
                exit()

        # ⏳ Show estimated remaining time
        if count % 50 == 0:
            remaining_time = estimate_time(start_time, count, len(post_urls) - last_index)
            print(f"⏳ Estimated time remaining: {remaining_time}")

        time.sleep(random.uniform(1, 2))

# 📥 Step 4: Final Save
if novels_data:
    df = pd.DataFrame(novels_data)
    try:
        if os.path.exists(SAVE_PATH_XLSX):
            existing_df = pd.read_excel(SAVE_PATH_XLSX, engine='openpyxl')
            df = pd.concat([existing_df, df], ignore_index=True)
        df.to_excel(SAVE_PATH_XLSX, index=False, engine='openpyxl')
    except (PermissionError, IOError) as e:
        print(f"❌ Cannot write to {SAVE_PATH_XLSX}: {e}")
        exit()

# ✅ Delete progress file
if os.path.exists(PROGRESS_FILE):
    try:
        os.remove(PROGRESS_FILE)
    except OSError:
        print("⚠ Could not delete progress file.")

print(f"✅ Scraping complete! Data saved in '{SAVE_PATH_XLSX}'")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# ❌ Failed to fetch sitemap: HTTP 429
# ⚠ Rate limit hit for https://urdureadings.com/ishq-javdani-novel-by-gul-arbab-pdf/. Waiting...
# ⚠ Rate limit hit for https://urdureadings.com/ru-sayah-novel-by-aatir-shaheen-pdf/. Waiting...
# ⚠ Rate limit hit for https://urdureadings.com/taash-ghar-novel-by-aymal-raza-pdf/. Waiting...
# 📌 Found title with selector 'h2.entry-title': 'Mere Jeene Ki Wajah Novel by Tania Hashmi' for URL: https://urdureadings.com/
# 📌 Final title: 'Mere Jeene Ki Wajah Novel by Tania Hashmi' for URL: https://urdureadings.com/
# 📌 Found title with selector 'h1.entry-title': 'Mala Novel By Nimra Ahmed' for URL: https://urdureadings.com/mala-novel-by-nimra-ahmed-pdf/
# 📌 Final title: 'Mala Novel By Nimra Ahmed' for URL: https://urdureadings.com/mala-novel-by-nimra-ahmed-pdf/
# 📌 Found title with selector 'h1.entry-title': 'Donwload Complete Imran Series By Mazhar Kaleem MA' for URL: https://urdureadings.com/complete-imran-series-by-mazhar-kaleem-download/
# 📌 Final title: 'Donwload Complete Imran Series By Mazhar Kaleem MA' for URL: https://urdureadings.com/complete-imran-series-by-mazhar-kaleem-download/
# 📌 Found title with selector 'h1.entry-title': 'Namal Complete Novel By Nimra Ahmed' for URL: https://urdureadings.com/download-namal-complete-novel-by-nimra-ahmed/
# 📌 Final title: 'Namal Complete Novel By Nimra Ahmed' for URL: https://urdureadings.com/download-namal-complete-novel-by-nimra-ahmed/
# 📌 Found title with selector 'h1.entry-title': 'Aab e Hayat Novel By Umera Ahmed' for URL: https://urdureadings.com/aab-e-hayat-novel-by-umera-ahmed/
# 📌 Final title: 'Aab e Hayat Novel By Umera Ahmed' for URL: https://urdureadings.com/aab-e-hayat-novel-by-umera-ahmed/
# 📌 Found title with selector 'h1.entry-title': 'Mera Bakht Novel By Sehar Sajid' for URL: https://urdureadings.com/mera-bakht-novel-by-sehar-sajid-pdf/
# 📌 Final title: 'Mera Bakht Novel By Sehar Sajid' for URL: https://urdureadings.com/mera-bakht-novel-by-sehar-sajid-pdf/
# 📌 Found title with selector 'h1.entry-title': 'Ishq Javdani Novel By Gul Arbab' for URL: https://urdureadings.com/ishq-javdani-novel-by-gul-arbab-pdf/
# 📌 Final title: 'Ishq Javdani Novel By Gul Arbab' for URL: https://urdureadings.com/ishq-javdani-novel-by-gul-arbab-pdf/
# 📌 Found title with selector 'h1.entry-title': 'Tash Ghar Novel By Aymal Raza' for URL: https://urdureadings.com/taash-ghar-novel-by-aymal-raza-pdf/
# 📌 Final title: 'Tash Ghar Novel By Aymal Raza' for URL: https://urdureadings.com/taash-ghar-novel-by-aymal-raza-pdf/
# 📌 Found title with selector 'h1.entry-title': 'Ru Sayah Novel By Aatir Shaheen' for URL: https://urdureadings.com/ru-sayah-novel-by-aatir-shaheen-pdf/
# 📌 Final title: 'Ru Sayah Novel By Aatir Shaheen' for URL: https://urdureadings.com/ru-sayah-novel-by-aatir-shaheen-pdf/
# 📌 Found title with selector 'h1.entry-title': 'Peer e Kamil Novel By Umera Ahmed' for URL: https://urdureadings.com/peer-e-kamil-novel-by-umera-ahmed-pdf/
# 📌 Final title: 'Peer e Kamil Novel By Umera Ahmed' for URL: https://urdureadings.com/peer-e-kamil-novel-by-umera-ahmed-pdf/
# 📌 Found title with selector 'h1.entry-title': 'Jannat Kay Pattay Novel By Nimra Ahmed' for URL: https://urdureadings.com/jannat-kay-pattay-novel-by-nimra-ahmed/
# 📌 Final title: 'Jannat Kay Pattay Novel By Nimra Ahmed' for URL: https://urdureadings.com/jannat-kay-pattay-novel-by-nimra-ahmed/
# 📌 Found title with selector 'h1.entry-title': 'I’m Truly Yours Novel (Complete) By Suneha Rauf' for URL: https://urdureadings.com/im-truly-yours-novel-complete-pdf/
# 📌 Final title: 'I’m Truly Yours Novel (Complete) By Suneha Rauf' for URL: https://urdureadings.com/im-truly-yours-novel-complete-pdf/
# 📌 Found title with selector 'h1.entry-title': 'Dil Kanch Ka Ghar Novel By Umme Iman Qazi' for URL: https://urdureadings.com/dil-kanch-ka-ghar-novel-by-umme-iman-qazi-pdf/
# 📌 Final title: 'Dil Kanch Ka Ghar Novel By Umme Iman Qazi' for URL: https://urdureadings.com/dil-kanch-ka-ghar-novel-by-umme-iman-qazi-pdf/
# 📌 Found title with selector 'h1.entry-title': 'Ma Anmol Novel By Nimra Ahmed' for URL: https://urdureadings.com/ma-anmol-novel-by-nimra-ahmed-pdf/
# 📌 Final title: 'Ma Anmol Novel By Nimra Ahmed' for URL: https://urdureadings.com/ma-anmol-novel-by-nimra-ahmed-pdf/
# 📌 Found title with selector 'h1.entry-title': 'Seep Sadaf Aur Sahil Novel By Rukh Chaudhary' for URL: https://urdureadings.com/seep-sadaf-aur-sahil-novel-by-rukh-chaudhary-pdf/
# 📌 Final title: 'Seep Sadaf Aur Sahil Novel By Rukh Chaudhary' for URL: https://urdureadings.com/seep-sadaf-aur-sahil-novel-by-rukh-chaudhary-pdf/
# 📌 Found title with selector 'h1.entry-title': 'Paon Ki Zanjeer (Stories) By Razia Butt' for URL: https://urdureadings.com/paon-ki-zanjeer-stories-by-razia-butt-pdf/
# 📌 Final title: 'Paon Ki Zanjeer (Stories) By Razia Butt' for URL: https://urdureadings.com/paon-ki-zanjeer-stories-by-razia-butt-pdf/
# 📌 Found title with selector 'h1.entry-title': 'Salsabeel Novel By Nayab Jillani' for URL: https://urdureadings.com/salsabeel-novel-by-nayab-jillani-pdf/
# 📌 Final title: 'Salsabeel Novel By Nayab Jillani' for URL: https://urdureadings.com/salsabeel-novel-by-nayab-jillani-pdf/
# 📌 Found title with selector 'h1.entry-title': 'Mere Jeene Ki Wajah Novel by Tania Hashmi' for URL: https://urdureadings.com/mere-jeene-ki-wajah-novel-by-tania-hashmi-pdf/
# 📌 Final title: 'Mere Jeene Ki Wajah Novel by Tania Hashmi' for URL: https://urdureadings.com/mere-jeene-ki-wajah-novel-by-tania-hashmi-pdf/
# 📌 Found title with selector 'h1.entry-title': 'Arsh-e-Falak Novel By Bisma Bhatti' for URL: https://urdureadings.com/arsh-e-falak-novel-by-bisma-bhatti-pdf/
# 📌 Final title: 'Arsh-e-Falak Novel By Bisma Bhatti' for URL: https://urdureadings.com/arsh-e-falak-novel-by-bisma-bhatti-pdf/
# 📌 Found title with selector 'h1.entry-title': 'Yeh Jo Raig-e-Dasht-e-Firaq Hai Novel By Nazia Kanwal Nazi' for URL: https://urdureadings.com/yeh-jo-raig-e-dasht-e-firaq-hai-novel-pdf/
# 📌 Final title: 'Yeh Jo Raig-e-Dasht-e-Firaq Hai Novel By Nazia Kanwal Nazi' for URL: https://urdureadings.com/yeh-jo-raig-e-dasht-e-firaq-hai-novel-pdf/
# 📌 Found title with selector 'h1.entry-title': 'Soz-e-Ishq Novel By Misbah' for URL: https://urdureadings.com/soz-e-ishq-novel-by-misbah-pdf/
# 📌 Final title: 'Soz-e-Ishq Novel By Misbah' for URL: https://urdureadings.com/soz-e-ishq-novel-by-misbah-pdf/
# 📌 Found title with selector 'h1.entry-title': 'Humsafar Novel By Rida Khan' for URL: https://urdureadings.com/humsafar-novel-by-rida-khan-pdf/
# 📌 Final title: 'Humsafar Novel By Rida Khan' for URL: https://urdureadings.com/humsafar-novel-by-rida-khan-pdf/
# 📌 Found title with selector 'h1.entry-title': 'Hai Tu Hi Meri Manzil Novel By Malaika Falak' for URL: https://urdureadings.com/hai-tu-hi-meri-manzil-novel-by-malaika-falak-pdf/
# 📌 Final title: 'Hai Tu Hi Meri Manzil Novel By Malaika Falak' for URL: https://urdureadings.com/hai-tu-hi-meri-manzil-novel-by-malaika-falak-pdf/
# 📌 Found title with selector 'h1.entry-title': 'Safar-e-Kunn Novel By Aliza Ayat' for URL: https://urdureadings.com/safar-e-kunn-novel-by-aliza-ayat-pdf/
# 📌 Final title: 'Safar-e-Kunn Novel By Aliza Ayat' for URL: https://urdureadings.com/safar-e-kunn-novel-by-aliza-ayat-pdf/
# 📌 Found title with selector 'h1.entry-title': 'Shehr-e-Ajnabi Novel By Memona Khurshid Ali' for URL: https://urdureadings.com/shehr-e-ajnabi-novel-by-memona-khurshid-ali-pdf/
# 📌 Final title: 'Shehr-e-Ajnabi Novel By Memona Khurshid Ali' for URL: https://urdureadings.com/shehr-e-ajnabi-novel-by-memona-khurshid-ali-pdf/
# 📌 Found title with selector 'h1.entry-title': 'Kya Hui Hai Khata Novel By Rimsha Hussain' for URL: https://urdureadings.com/kya-hui-hai-khata-novel-by-rimsha-hussain-pdf/
# 📌 Final title: 'Kya Hui Hai Khata Novel By Rimsha Hussain' for URL: https://urdureadings.com/kya-hui-hai-khata-novel-by-rimsha-hussain-pdf/
# 📌 Found title with selector 'h1.entry-title': 'Ammad-Ud-Din Zangi Novel By Aslam Rahi M.A' for URL: https://urdureadings.com/ammad-ud-din-zangi-novel-by-aslam-rahi-m-a-pdf/
# 📌 Final title: 'Ammad-Ud-Din Zangi Novel By Aslam Rahi M.A' for URL: https://urdureadings.com/ammad-ud-din-zangi-novel-by-aslam-rahi-m-a-pdf/
# 📌 Found title with selector 'h1.entry-title': 'Rag-e-Jaan Novel By Mahnoor Shehzad' for URL: https://urdureadings.com/rag-e-jaan-novel-by-mahnoor-shehzad-pdf/
# 📌 Final title: 'Rag-e-Jaan Novel By Mahnoor Shehzad' for URL: https://urdureadings.com/rag-e-jaan-novel-by-mahnoor-shehzad-pdf/
# 📌 Found title with selector 'h1.entry-title': 'Pak Mehram Novel By Farah Jalal' for URL: https://urdureadings.com/pak-mehram-novel-by-farah-jalal-pdf/
# 📌 Final title: 'Pak Mehram Novel By Farah Jalal' for URL: https://urdureadings.com/pak-mehram-novel-by-farah-jalal-pdf/
# 📌 Found title with selector 'h1.entry-title': 'Malal-e-Ishq Novel By Iqra Riaz' for URL: https://urdureadings.com/malal-e-ishq-novel-by-iqra-riaz-pdf/
# 📌 Final title: 'Malal-e-Ishq Novel By Iqra Riaz' for URL: https://urdureadings.com/malal-e-ishq-novel-by-iqra-riaz-pdf/
# 📌 Found title with selector 'h1.entry-title': 'Taghoot Novel By Anwar Siddiqi' for URL: https://urdureadings.com/taghoot-novel-by-anwar-siddiqi-pdf/
# 📌 Final title: 'Taghoot Novel By Anwar Siddiqi' for URL: https://urdureadings.com/taghoot-novel-by-anwar-siddiqi-pdf/
# 📌 Found title with selector 'h1.entry-title': 'Ek Paigham-e-Mohabbat Novel By Mirha Khan' for URL: https://urdureadings.com/ek-paigham-e-mohabbat-novel-by-mirha-khan-pdf/
# 📌 Final title: 'Ek Paigham-e-Mohabbat Novel By Mirha Khan' for URL: https://urdureadings.com/ek-paigham-e-mohabbat-novel-by-mirha-khan-pdf/
# 📌 Found title with selector 'h1.entry-title': 'Dayar-e-Dil Mein Novel By Aneeza Syed' for URL: https://urdureadings.com/dayar-e-dil-mein-novel-by-aneeza-syed-pdf/
# 📌 Final title: 'Dayar-e-Dil Mein Novel By Aneeza Syed' for URL: https://urdureadings.com/dayar-e-dil-mein-novel-by-aneeza-syed-pdf/
# 📌 Found title with selector 'h1.entry-title': 'Oonch Neech Ka Pahar Novel by Umme Taifoor' for URL: https://urdureadings.com/oonch-neech-ka-pahar-novel-by-umme-taifoor-pdf/
# 📌 Final title: 'Oonch Neech Ka Pahar Novel by Umme Taifoor' for URL: https://urdureadings.com/oonch-neech-ka-pahar-novel-by-umme-taifoor-pdf/
# 📌 Found title with selector 'h1.entry-title': 'Bakht Novel By Mehrunisa Shahmeer' for URL: https://urdureadings.com/bakht-novel-by-mehrunisa-shahmeer-pdf/
# 📌 Final title: 'Bakht Novel By Mehrunisa Shahmeer' for URL: https://urdureadings.com/bakht-novel-by-mehrunisa-shahmeer-pdf/
# 📌 Found title with selector 'h1.entry-title': 'Tera Hoon Jan Le Novel (Haal-e-Dil Season 2) By Rimsha Hussain' for URL: https://urdureadings.com/tera-hoon-jan-le-novel-haal-e-dil-season-2-by-rimsha-hussain-pdf/
# 📌 Final title: 'Tera Hoon Jan Le Novel (Haal-e-Dil Season 2) By Rimsha Hussain' for URL: https://urdureadings.com/tera-hoon-jan-le-novel-haal-e-dil-season-2-by-rimsha-hussain-pdf/
# 📌 Found title with selector 'h1.entry-title': 'Junoon-e-Ishq Hai Tum Se Novel By Noor Fatima' for URL: https://urdureadings.com/junoon-e-ishq-hai-tum-se-novel-by-noor-fatima-pdf/
# 📌 Final title: 'Junoon-e-Ishq Hai Tum Se Novel By Noor Fatima' for URL: https://urdureadings.com/junoon-e-ishq-hai-tum-se-novel-by-noor-fatima-pdf/
# 📌 Found title with selector 'h1.entry-title': 'Bano Novel By Razia Butt' for URL: https://urdureadings.com/bano-novel-by-razia-butt/
# 📌 Final title: 'Bano Novel By Razia Butt' for URL: https://urdureadings.com/bano-novel-by-razia-butt/
# 📌 Found title with selector 'h1.entry-title': 'Aangan Novel By Khadija Mastoor' for URL: https://urdureadings.com/aangan-novel-by-khadija-mastoor-download-pdf/
# 📌 Final title: 'Aangan Novel By Khadija Mastoor' for URL: https://urdureadings.com/aangan-novel-by-khadija-mastoor-download-pdf/
# 📌 Found title with selector 'h1.entry-title': 'Mohabbat Ke Anokhay Phool Novel By Ruqayya Ali' for URL: https://urdureadings.com/mohabbat-ke-anokhay-phool-novel-by-ruqayya-ali-pdf/
# 📌 Final title: 'Mohabbat Ke Anokhay Phool Novel By Ruqayya Ali' for URL: https://urdureadings.com/mohabbat-ke-anokhay-phool-novel-by-ruqayya-ali-pdf/
# 📌 Found title with selector 'h1.entry-title': 'Azizam Novel by Hoori Shah' for URL: https://urdureadings.com/azizam-novel-by-hoori-shah-pdf/
# 📌 Final title: 'Azizam Novel by Hoori Shah' for URL: https://urdureadings.com/azizam-novel-by-hoori-shah-pdf/
# 📌 Found title with selector 'h1.entry-title': 'Laagi Tum Se Mann Ki Lagan Novel By Fatima Ahmed' for URL: https://urdureadings.com/laagi-tum-se-mann-ki-lagan-novel-by-fatima-ahmed-pdf/
# 📌 Final title: 'Laagi Tum Se Mann Ki Lagan Novel By Fatima Ahmed' for URL: https://urdureadings.com/laagi-tum-se-mann-ki-lagan-novel-by-fatima-ahmed-pdf/
# 📌 Found title with selector 'h1.entry-title': 'Qalandar Zaat Novel By Amjad Javed' for URL: https://urdureadings.com/qalandar-zaat-novel-by-amjad-javed-pdf/
# 📌 Final title: 'Qalandar Zaat Novel By Amjad Javed' for URL: https://urdureadings.com/qalandar-zaat-novel-by-amjad-javed-pdf/
# 📌 Found title with selector 'h1.entry-title': 'Hubb-e-Qalb Novel by Yaman Eva' for URL: https://urdureadings.com/hubb-e-qalb-novel-by-yaman-eva-pdf/
# 📌 Final title: 'Hubb-e-Qalb Novel by Yaman Eva' for URL: https://urdureadings.com/hubb-e-qalb-novel-by-yaman-eva-pdf/
# 📌 Found title with selector 'h1.entry-title': 'Hasil Mulaqat Novel By Farah Bukhari' for URL: https://urdureadings.com/hasil-mulaqat-novel-by-farah-bukhari-pdf/
# 📌 Final title: 'Hasil Mulaqat Novel By Farah Bukhari' for URL: https://urdureadings.com/hasil-mulaqat-novel-by-farah-bukhari-pdf/
# 📌 Found title with selector 'h1.entry-title': 'Hazaron Khwahishen Novel By Aleem-Ul-Haq Haqi' for URL: https://urdureadings.com/hazaron-khwahishen-novel-by-aleem-ul-haq-haqi-pdf/
# 📌 Final title: 'Hazaron Khwahishen Novel By Aleem-Ul-Haq Haqi' for URL: https://urdureadings.com/hazaron-khwahishen-novel-by-aleem-ul-haq-haqi-pdf/
# 📌 Found title with selector 'h1.entry-title': 'Sitamgar Se Humsafar Novel By Fatima' for URL: https://urdureadings.com/sitamgar-se-humsafar-novel-by-fatima-pdf/
# 📌 Final title: 'Sitamgar Se Humsafar Novel By Fatima' for URL: https://urdureadings.com/sitamgar-se-humsafar-novel-by-fatima-pdf/
# 📌 Found title with selector 'h1.entry-title': 'Ishq-e-Bekhabar Novel By Bint-e-Ahmed Shaikh' for URL: https://urdureadings.com/ishq-e-bekhabar-novel-by-bint-e-ahmed-shaikh-pdf/
# 📌 Final title: 'Ishq-e-Bekhabar Novel By Bint-e-Ahmed Shaikh' for URL: https://urdureadings.com/ishq-e-bekhabar-novel-by-bint-e-ahmed-shaikh-pdf/
# 📌 Found title with selector 'h1.entry-title': 'Marg-e-Tamanna Novel By Mawra Talha' for URL: https://urdureadings.com/marg-e-tamanna-novel-by-mawra-talha-pdf/
# 📌 Final title: 'Marg-e-Tamanna Novel By Mawra Talha' for URL: https://urdureadings.com/marg-e-tamanna-novel-by-mawra-talha-pdf/
# 📌 Found title with selector 'h1.entry-title': 'Dard Gar Novel By Umme Maryam' for URL: https://urdureadings.com/dard-gar-novel-by-umme-maryam-pdf/
# 📌 Final title: 'Dard Gar Novel By Umme Maryam' for URL: https://urdureadings.com/dard-gar-novel-by-umme-maryam-pdf/
# 📌 Found title with selector 'h1.entry-title': 'Parsa Novel by Hiba Tehreem' for URL: https://urdureadings.com/parsa-novel-by-hiba-tehreem-pdf/
# 📌 Final title: 'Parsa Novel by Hiba Tehreem' for URL: https://urdureadings.com/parsa-novel-by-hiba-tehreem-pdf/
# 📌 Found title with selector 'h1.entry-title': 'Mera Sara Zang Utar Do Novel By Afshan Afridi' for URL: https://urdureadings.com/mera-sara-zang-utar-do-novel-by-afshan-afridi-pdf/
# 📌 Final title: 'Mera Sara Zang Utar Do Novel By Afshan Afridi' for URL: https://urdureadings.com/mera-sara-zang-utar-do-novel-by-afshan-afridi-pdf/
# 📌 Found title with selector 'h1.entry-title': 'Tum Aisi Shararat Mat Karna (Stories) By Subas Gul' for URL: https://urdureadings.com/tum-aisi-shararat-mat-karna-stories-by-subas-gul-pdf/
# 📌 Final title: 'Tum Aisi Shararat Mat Karna (Stories) By Subas Gul' for URL: https://urdureadings.com/tum-aisi-shararat-mat-karna-stories-by-subas-gul-pdf/
# 📌 Found title with selector 'h1.entry-title': 'Takay Da Tamasha (Stories) By Shazia Chaudhary' for URL: https://urdureadings.com/takay-da-tamasha-stories-by-shazia-chaudhary-pdf/
# 📌 Final title: 'Takay Da Tamasha (Stories) By Shazia Chaudhary' for URL: https://urdureadings.com/takay-da-tamasha-stories-by-shazia-chaudhary-pdf/
# 📌 Found title with selector 'h1.entry-title': 'Sarbaz Novel By Shamim Naveed' for URL: https://urdureadings.com/sarbaz-novel-by-shamim-naveed-pdf/
# 📌 Final title: 'Sarbaz Novel By Shamim Naveed' for URL: https://urdureadings.com/sarbaz-novel-by-shamim-naveed-pdf/
# 📌 Found title with selector 'h1.entry-title': 'Hari Hai Shakh-e-Tamana Abhi Novel By Aasia Mirza' for URL: https://urdureadings.com/hari-hai-shakh-e-tamana-abhi-novel-by-aasia-mirza-pdf/
# 📌 Final title: 'Hari Hai Shakh-e-Tamana Abhi Novel By Aasia Mirza' for URL: https://urdureadings.com/hari-hai-shakh-e-tamana-abhi-novel-by-aasia-mirza-pdf/
# 📌 Found title with selector 'h1.entry-title': 'Ek Haseen Khata Novel By Zohra Shaikh' for URL: https://urdureadings.com/ek-haseen-khata-novel-by-zohra-shaikh-pdf/
# 📌 Final title: 'Ek Haseen Khata Novel By Zohra Shaikh' for URL: https://urdureadings.com/ek-haseen-khata-novel-by-zohra-shaikh-pdf/
# 📌 Found title with selector 'h1.entry-title': 'Ashifta Dil Novel By Huria Malik' for URL: https://urdureadings.com/ashifta-dil-novel-by-huria-malik-pdf/
# 📌 Final title: 'Ashifta Dil Novel By Huria Malik' for URL: https://urdureadings.com/ashifta-dil-novel-by-huria-malik-pdf/
# 📌 Found title with selector 'h1.entry-title': 'Man Yaram Novel By Maha Gul' for URL: https://urdureadings.com/man-yaram-novel-by-maha-gul-pdf/
# 📌 Final title: 'Man Yaram Novel By Maha Gul' for URL: https://urdureadings.com/man-yaram-novel-by-maha-gul-pdf/
# 📌 Found title with selector 'h1.entry-title': 'Ain Ishq Novel By Iqra Fatima' for URL: https://urdureadings.com/ain-ishq-novel-by-iqra-fatima-pdf/
# 📌 Final title: 'Ain Ishq Novel By Iqra Fatima' for URL: https://urdureadings.com/ain-ishq-novel-by-iqra-fatima-pdf/
# 📌 Found title with selector 'h1.entry-title': 'Mitti Se Ishq Novel By Aleem Ul Haq Haqi' for URL: https://urdureadings.com/mitti-se-ishq-novel-by-aleem-ul-haq-haqi-pdf/
# 📌 Final title: 'Mitti Se Ishq Novel By Aleem Ul Haq Haqi' for URL: https://urdureadings.com/mitti-se-ishq-novel-by-aleem-ul-haq-haqi-pdf/
# 📌 Found title with selector 'h1.entry-title': 'Tujh Sang Zindagi Ke Rang Novel By Dur-e-Najaf' for URL: https://urdureadings.com/tujh-sang-zindagi-ke-rang-novel-by-dur-e-najaf-pdf/
# 📌 Final title: 'Tujh Sang Zindagi Ke Rang Novel By Dur-e-Najaf' for URL: https://urdureadings.com/tujh-sang-zindagi-ke-rang-novel-by-dur-e-najaf-pdf/
# 📌 Found title with selector 'h1.entry-title': 'Yaaram Novel By Sumaira Hameed' for URL: https://urdureadings.com/yaaram-novel-by-sumaira-hameed-download-pdf/
# 📌 Final title: 'Yaaram Novel By Sumaira Hameed' for URL: https://urdureadings.com/yaaram-novel-by-sumaira-hameed-download-pdf/
# 📌 Found title with selector 'h1.entry-title': 'Man o Salwa Novel By Umera Ahmed' for URL: https://urdureadings.com/man-o-salwa-novel-by-umera-ahmed/
# 📌 Final title: 'Man o Salwa Novel By Umera Ahmed' for URL: https://urdureadings.com/man-o-salwa-novel-by-umera-ahmed/
# 📌 Found title with selector 'h1.entry-title': 'Aks Novel By Umera Ahmed' for URL: https://urdureadings.com/aks-novel-by-umera-ahmed-pdf/
# 📌 Final title: 'Aks Novel By Umera Ahmed' for URL: https://urdureadings.com/aks-novel-by-umera-ahmed-pdf/
# 📌 Found title with selector 'h1.entry-title': 'Aur Kuch Khawab Novel By Ushna Kausar Sardar' for URL: https://urdureadings.com/aur-kuch-khawab-novel-by-ushna-kausar-sardar-pdf/
# 📌 Final title: 'Aur Kuch Khawab Novel By Ushna Kausar Sardar' for URL: https://urdureadings.com/aur-kuch-khawab-novel-by-ushna-kausar-sardar-pdf/
# 📌 Found title with selector 'h1.entry-title': 'Aks Novel by M.A Rahat' for URL: https://urdureadings.com/aks-novel-by-ma-rahat-pdf-download/
# 📌 Final title: 'Aks Novel by M.A Rahat' for URL: https://urdureadings.com/aks-novel-by-ma-rahat-pdf-download/
# 📌 Found title with selector 'h1.entry-title': 'Raja Gidh Novel By Bano Qudsia' for URL: https://urdureadings.com/raja-gidh-novel-by-bano-qudsia/
# 📌 Final title: 'Raja Gidh Novel By Bano Qudsia' for URL: https://urdureadings.com/raja-gidh-novel-by-bano-qudsia/
# 📌 Found title with selector 'h1.entry-title': 'Raaz Aankhein Teri Novel By Maha Gul' for URL: https://urdureadings.com/raaz-aankhein-teri-novel-by-maha-gul-pdf/
# 📌 Final title: 'Raaz Aankhein Teri Novel By Maha Gul' for URL: https://urdureadings.com/raaz-aankhein-teri-novel-by-maha-gul-pdf/
# 📌 Found title with selector 'h1.entry-title': 'Teri Sitamgari Novel By Abeeha Ali' for URL: https://urdureadings.com/teri-sitamgari-novel-by-abeeha-ali-pdf/
# 📌 Final title: 'Teri Sitamgari Novel By Abeeha Ali' for URL: https://urdureadings.com/teri-sitamgari-novel-by-abeeha-ali-pdf/
# 📌 Found title with selector 'h1.entry-title': 'Dana Pani Novel By Umera Ahmed' for URL: https://urdureadings.com/dana-pani-novel-by-umera-ahmed-pdf/
# 📌 Final title: 'Dana Pani Novel By Umera Ahmed' for URL: https://urdureadings.com/dana-pani-novel-by-umera-ahmed-pdf/
# 📌 Found title with selector 'h1.entry-title': 'La Hasil Novel By Umera Ahmed' for URL: https://urdureadings.com/la-hasil-novel-by-umera-ahmed-download-pdf/
# 📌 Final title: 'La Hasil Novel By Umera Ahmed' for URL: https://urdureadings.com/la-hasil-novel-by-umera-ahmed-download-pdf/
# 📌 Found title with selector 'h1.entry-title': 'Abdullah Novel By Hashim Nadeem' for URL: https://urdureadings.com/abdullah-novel-by-hashim-nadeem-pdf-download/
# 📌 Final title: 'Abdullah Novel By Hashim Nadeem' for URL: https://urdureadings.com/abdullah-novel-by-hashim-nadeem-pdf-download/
# 📌 Found title with selector 'h1.entry-title': 'Dil Bereham Novel by Mahi Rajpoot' for URL: https://urdureadings.com/dil-bereham-novel-by-mahi-rajpoot-pdf/
# 📌 Final title: 'Dil Bereham Novel by Mahi Rajpoot' for URL: https://urdureadings.com/dil-bereham-novel-by-mahi-rajpoot-pdf/
# 📌 Found title with selector 'h1.entry-title': 'Dasht-e-Wehshat Novel By Mehwish Ali' for URL: https://urdureadings.com/dasht-e-wehshat-novel-pdf/
# 📌 Final title: 'Dasht-e-Wehshat Novel By Mehwish Ali' for URL: https://urdureadings.com/dasht-e-wehshat-novel-pdf/
# 📌 Found title with selector 'h1.entry-title': 'Rooh-e-Yaram Novel By Areej Shah' for URL: https://urdureadings.com/rooh-e-yaram-novel-by-areej-shah-pdf/
# 📌 Final title: 'Rooh-e-Yaram Novel By Areej Shah' for URL: https://urdureadings.com/rooh-e-yaram-novel-by-areej-shah-pdf/
# 📌 Found title with selector 'h1.entry-title': 'Aanchal Mein Jalta Diya Novel By Neelam Riasat' for URL: https://urdureadings.com/aanchal-mein-jalta-diya-novel-by-neelam-riasat-pdf/
# 📌 Final title: 'Aanchal Mein Jalta Diya Novel By Neelam Riasat' for URL: https://urdureadings.com/aanchal-mein-jalta-diya-novel-by-neelam-riasat-pdf/
# 📌 Found title with selector 'h1.entry-title': 'Tu Meri Zindagi Hai Novel By Malisha Rana' for URL: https://urdureadings.com/tu-meri-zindagi-hai-novel-by-malisha-rana-pdf/
# 📌 Final title: 'Tu Meri Zindagi Hai Novel By Malisha Rana' for URL: https://urdureadings.com/tu-meri-zindagi-hai-novel-by-malisha-rana-pdf/
# 📌 Found title with selector 'h1.entry-title': 'Mohabbat Hayat Hoti Hai Novel By Meerab Hayat' for URL: https://urdureadings.com/mohabbat-hayat-hoti-hai-novel-pdf/
# 📌 Final title: 'Mohabbat Hayat Hoti Hai Novel By Meerab Hayat' for URL: https://urdureadings.com/mohabbat-hayat-hoti-hai-novel-pdf/
# 📌 Found title with selector 'h1.entry-title': 'Bhandhan Mohabbat Ka Novel By Areej Shah' for URL: https://urdureadings.com/bhandhan-mohabbat-ka-novel-by-areej-shah-pdf/
# 📌 Final title: 'Bhandhan Mohabbat Ka Novel By Areej Shah' for URL: https://urdureadings.com/bhandhan-mohabbat-ka-novel-by-areej-shah-pdf/
# 📌 Found title with selector 'h1.entry-title': 'Azazeel Novel (Complete) By Rabia Khan' for URL: https://urdureadings.com/azazeel-novel-complete-by-rabia-khan-pdf/
# 📌 Final title: 'Azazeel Novel (Complete) By Rabia Khan' for URL: https://urdureadings.com/azazeel-novel-complete-by-rabia-khan-pdf/
# 📌 Found title with selector 'h1.entry-title': 'Kuch Ishq Mein Rang-e-Junoon Bhi Tha Novel By Naila Tariq' for URL: https://urdureadings.com/kuch-ishq-mein-rang-e-junoon-bhi-tha-novel-by-naila-tariq-pdf/
# 📌 Final title: 'Kuch Ishq Mein Rang-e-Junoon Bhi Tha Novel By Naila Tariq' for URL: https://urdureadings.com/kuch-ishq-mein-rang-e-junoon-bhi-tha-novel-by-naila-tariq-pdf/
