# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import time
import xml.etree.ElementTree as ET
import os
import concurrent.futures
import random
from datetime import datetime

# 🚀 Google Drive Mount (for saving file)
from google.colab import drive
drive.mount('/content/drive')

# 📌 File Paths
SITEMAP_URL = "https://digestlibrary.com/post-sitemap7.xml"
SAVE_PATH_XLSX = "/content/drive/My Drive/Blogger_Novels.xlsx"
FAILED_LINKS_FILE = "/content/drive/My Drive/failed_links.txt"
PROGRESS_FILE = "/content/drive/My Drive/progress.txt"

# 🛡 Headers & Session
HEADERS = {"User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/121.0.0.0 Safari/537.36"}
session = requests.Session()
session.headers.update(HEADERS)

# 🔄 Resume Last Progress
last_index = 0
if os.path.exists(PROGRESS_FILE):
    with open(PROGRESS_FILE, "r") as f:
        last_index = int(f.read().strip())

# 📥 Step 1: Extract all post URLs from sitemap
response = session.get(SITEMAP_URL)
if response.status_code == 200:
    root = ET.fromstring(response.content)
    post_urls = [elem.text for elem in root.findall(".//{http://www.sitemaps.org/schemas/sitemap/0.9}loc")]
    print(f"✅ Found {len(post_urls)} posts to scrape.")
else:
    print("❌ Failed to fetch sitemap.")
    exit()

# ⏳ Function to estimate remaining time
def estimate_time(start_time, processed, total):
    elapsed_time = time.time() - start_time
    avg_time_per_post = elapsed_time / processed if processed > 0 else 0
    remaining_posts = total - processed
    estimated_remaining_time = remaining_posts * avg_time_per_post
    return time.strftime('%H:%M:%S', time.gmtime(estimated_remaining_time))

# 🔍 Step 2: Scrape Each Novel Post with Auto-Retry
def scrape_post(post_url):
    """ Extracts title and ALL download links from a Blogger post """
    retries = 5
    for attempt in range(retries):
        try:
            response = session.get(post_url, timeout=30)
            if response.status_code != 200:
                print(f"⚠ Retrying ({attempt+1}/{retries}) for: {post_url}")
                time.sleep(5)
                continue

            soup = BeautifulSoup(response.text, "html.parser")

            # Extract Title
            title = soup.find("h1")
            if not title:
                title = soup.find("h2")  # Sometimes titles are in h2

            title = title.text.strip() if title else "No Title Found"

            # Extract Download Links
            all_links = [a["href"] for a in soup.find_all("a", href=True)]
            google_drive_links = [link for link in all_links if "drive.google" in link]
            mediafire_links = [link for link in all_links if "mediafire" in link]

            return {
                "Title": title,
                "Google Drive Links": ", ".join(google_drive_links) if google_drive_links else "No Google Drive Link",
                "Mediafire Links": ", ".join(mediafire_links) if mediafire_links else "No Mediafire Link"
            }
        except requests.exceptions.RequestException as e:
            print(f"⚠ Attempt {attempt+1} failed for {post_url}: {e}")
        time.sleep(5)

    # ❌ Save failed link
    with open(FAILED_LINKS_FILE, "a") as f:
        f.write(post_url + "\n")

    return None  # Return None if all retries fail

# 📌 Step 3: Scrape Each Post & Save Data in Batches
novels_data = []
BATCH_SIZE = 100
start_time = time.time()

with concurrent.futures.ThreadPoolExecutor(max_workers=10) as executor:
    future_to_url = {executor.submit(scrape_post, post_urls[idx]): idx for idx in range(last_index, len(post_urls))}

    for count, future in enumerate(concurrent.futures.as_completed(future_to_url), start=1):
        idx = future_to_url[future]
        result = future.result()
        if result:
            novels_data.append(result)

        # ✅ Save every batch of 100 posts
        if len(novels_data) >= BATCH_SIZE:
            df = pd.DataFrame(novels_data)

            # 🔹 Append to existing Excel
            if os.path.exists(SAVE_PATH_XLSX):
                existing_df = pd.read_excel(SAVE_PATH_XLSX, engine='openpyxl')
                df = pd.concat([existing_df, df], ignore_index=True)

            df.to_excel(SAVE_PATH_XLSX, index=False, engine='openpyxl')

            novels_data = []  # Clear batch
            with open(PROGRESS_FILE, "w") as f:
                f.write(str(idx))

        # ⏳ Show estimated remaining time after every 50 posts
        if count % 50 == 0:
            remaining_time = estimate_time(start_time, count, len(post_urls) - last_index)
            print(f"⏳ Estimated time remaining: {remaining_time}")

        time.sleep(random.uniform(1, 2))  # Random delay

# 📥 Step 4: Final Save
if novels_data:
    df = pd.DataFrame(novels_data)

    # 🔹 Append to Excel
    if os.path.exists(SAVE_PATH_XLSX):
        existing_df = pd.read_excel(SAVE_PATH_XLSX, engine='openpyxl')
        df = pd.concat([existing_df, df], ignore_index=True)

    df.to_excel(SAVE_PATH_XLSX, index=False, engine='openpyxl')

# ✅ Delete progress file after successful completion
if os.path.exists(PROGRESS_FILE):
    os.remove(PROGRESS_FILE)

print(f"✅ Scraping complete! Data saved in '{SAVE_PATH_XLSX}' (Google Drive)")

# %% [markdown]
# I can see the issue you're facing. The Excel output from your script shows that the "Title" column for all entries is "Best Readers Library," which is likely the name of the blog rather than the individual novel titles. This is happening because the script isn't correctly extracting the unique titles for each post. Let's analyze the problem and fix it.

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import time
import xml.etree.ElementTree as ET
import os
import concurrent.futures
import random
from datetime import datetime

# 🚀 Google Drive Mount (for saving file)
from google.colab import drive
drive.mount('/content/drive')

# 📌 File Paths
SITEMAP_URL = "https://bestreaderslibrary.blogspot.com/sitemap.xml?page=2"
SAVE_PATH_XLSX = "/content/drive/My Drive/Blogger_Novels.xlsx"
FAILED_LINKS_FILE = "/content/drive/My Drive/failed_links.txt"
PROGRESS_FILE = "/content/drive/My Drive/progress.txt"

# 🛡 Headers & Session
HEADERS = {"User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/121.0.0.0 Safari/537.36"}
session = requests.Session()
session.headers.update(HEADERS)

# 🔄 Resume Last Progress
last_index = 0
if os.path.exists(PROGRESS_FILE):
    with open(PROGRESS_FILE, "r") as f:
        last_index = int(f.read().strip())

# 📥 Step 1: Extract all post URLs from sitemap
response = session.get(SITEMAP_URL)
if response.status_code == 200:
    root = ET.fromstring(response.content)
    post_urls = [elem.text for elem in root.findall(".//{http://www.sitemaps.org/schemas/sitemap/0.9}loc")]
    print(f"✅ Found {len(post_urls)} posts to scrape.")
else:
    print("❌ Failed to fetch sitemap.")
    exit()

# ⏳ Function to estimate remaining time
def estimate_time(start_time, processed, total):
    elapsed_time = time.time() - start_time
    avg_time_per_post = elapsed_time / processed if processed > 0 else 0
    remaining_posts = total - processed
    estimated_remaining_time = remaining_posts * avg_time_per_post
    return time.strftime('%H:%M:%S', time.gmtime(estimated_remaining_time))

# 🔍 Step 2: Scrape Each Novel Post with Auto-Retry
def scrape_post(post_url):
    """ Extracts title and ALL download links from a Blogger post """
    retries = 5
    for attempt in range(retries):
        try:
            response = session.get(post_url, timeout=30)
            if response.status_code != 200:
                print(f"⚠ Retrying ({attempt+1}/{retries}) for: {post_url}")
                time.sleep(5)
                continue

            soup = BeautifulSoup(response.text, "html.parser")

            # Extract Title (Updated Logic Based on HTML Snippet)
            # Look for h1 tag with class 'post-title' or 'entry-title'
            title = soup.find("h1", class_=["post-title", "entry-title"])
            if not title:
                # Fallback to h2 in case the structure varies
                title = soup.find("h2")
            if not title:
                # Fallback to h3 as a last resort
                title = soup.find("h3")

            title = title.text.strip() if title else "No Title Found"
            print(f"📝 Extracted title for {post_url}: {title}")  # Debug output to verify titles

            # Extract Download Links
            all_links = [a["href"] for a in soup.find_all("a", href=True)]
            google_drive_links = [link for link in all_links if "drive.google" in link]
            mediafire_links = [link for link in all_links if "mediafire" in link]

            return {
                "Title": title,
                "Google Drive Links": ", ".join(google_drive_links) if google_drive_links else "No Google Drive Link",
                "Mediafire Links": ", ".join(mediafire_links) if mediafire_links else "No Mediafire Link"
            }
        except requests.exceptions.RequestException as e:
            print(f"⚠ Attempt {attempt+1} failed for {post_url}: {e}")
        time.sleep(5)

    # ❌ Save failed link
    with open(FAILED_LINKS_FILE, "a") as f:
        f.write(post_url + "\n")

    return None  # Return None if all retries fail

# 📌 Step 3: Scrape Each Post & Save Data in Batches
novels_data = []
BATCH_SIZE = 100
start_time = time.time()

with concurrent.futures.ThreadPoolExecutor(max_workers=10) as executor:
    future_to_url = {executor.submit(scrape_post, post_urls[idx]): idx for idx in range(last_index, len(post_urls))}

    for count, future in enumerate(concurrent.futures.as_completed(future_to_url), start=1):
        idx = future_to_url[future]
        result = future.result()
        if result:
            novels_data.append(result)

        # ✅ Save every batch of 100 posts
        if len(novels_data) >= BATCH_SIZE:
            df = pd.DataFrame(novels_data)

            # 🔹 Append to existing Excel
            if os.path.exists(SAVE_PATH_XLSX):
                existing_df = pd.read_excel(SAVE_PATH_XLSX, engine='openpyxl')
                df = pd.concat([existing_df, df], ignore_index=True)

            df.to_excel(SAVE_PATH_XLSX, index=False, engine='openpyxl')

            novels_data = []  # Clear batch
            with open(PROGRESS_FILE, "w") as f:
                f.write(str(idx))

        # ⏳ Show estimated remaining time after every 50 posts
        if count % 50 == 0:
            remaining_time = estimate_time(start_time, count, len(post_urls) - last_index)
            print(f"⏳ Estimated time remaining: {remaining_time}")

        time.sleep(random.uniform(1, 2))  # Random delay

# 📥 Step 4: Final Save
if novels_data:
    df = pd.DataFrame(novels_data)

    # 🔹 Append to Excel
    if os.path.exists(SAVE_PATH_XLSX):
        existing_df = pd.read_excel(SAVE_PATH_XLSX, engine='openpyxl')
        df = pd.concat([existing_df, df], ignore_index=True)

    df.to_excel(SAVE_PATH_XLSX, index=False, engine='openpyxl')

# ✅ Delete progress file after successful completion
if os.path.exists(PROGRESS_FILE):
    os.remove(PROGRESS_FILE)

print(f"✅ Scraping complete! Data saved in '{SAVE_PATH_XLSX}' (Google Drive)")

# %% [markdown]
# use below

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import time
import xml.etree.ElementTree as ET
import os
import concurrent.futures
import random
from datetime import datetime
from threading import Lock
import re

# 🚀 Google Drive Mount (Optional)
try:
    from google.colab import drive
    drive.mount('/content/drive')
    SAVE_PATH_XLSX = "/content/drive/My Drive/Blogger_Novels.xlsx"
    FAILED_LINKS_FILE = "/content/drive/My Drive/failed_links.txt"
    PROGRESS_FILE = "/content/drive/My Drive/progress.txt"
    LOG_FILE = "/content/drive/My Drive/scrape_log.txt"
except ImportError:
    SAVE_PATH_XLSX = "Blogger_Novels.xlsx"
    FAILED_LINKS_FILE = "failed_links.txt"
    PROGRESS_FILE = "progress.txt"
    LOG_FILE = "scrape_log.txt"

# 📌 Headers & Session
HEADERS = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/121.0.0.0 Safari/537.36",
    "Accept": "text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,*/*;q=0.8",
    "Accept-Language": "en-US,en;q=0.5",
    "Connection": "keep-alive"
}
session = requests.Session()
session.headers.update(HEADERS)

# 🔄 Progress Lock
progress_lock = Lock()

# 📥 Step 1: Extract all post URLs from sitemap
SITEMAP_URL = "https://digestlibrary.com/post-sitemap6.xml"
try:
    response = session.get(SITEMAP_URL, timeout=30)
    if response.status_code == 200:
        root = ET.fromstring(response.content)
        post_urls = [elem.text for elem in root.findall(".//{http://www.sitemaps.org/schemas/sitemap/0.9}loc")]
        print(f"✅ Found {len(post_urls)} posts to scrape.")
    else:
        print(f"❌ Failed to fetch sitemap: HTTP {response.status_code}")
        exit()
except ET.ParseError:
    print("❌ Failed to parse sitemap XML.")
    exit()
except requests.exceptions.RequestException as e:
    print(f"❌ Sitemap request failed: {e}")
    exit()

# 🔄 Resume Last Progress
last_index = 0
if os.path.exists(PROGRESS_FILE):
    try:
        with open(PROGRESS_FILE, "r") as f:
            last_index = int(f.read().strip())
    except (ValueError, IOError):
        print("⚠ Could not read progress file. Starting from index 0.")

# ⏳ Function to estimate remaining time
def estimate_time(start_time, processed, total):
    elapsed_time = time.time() - start_time
    avg_time_per_post = elapsed_time / processed if processed > 0 else 0
    remaining_posts = total - processed
    estimated_remaining_time = remaining_posts * avg_time_per_post
    return time.strftime('%H:%M:%S', time.gmtime(estimated_remaining_time))

# 🔍 Function to resolve redirects
def resolve_redirect(url):
    try:
        response = session.head(url, allow_redirects=True, timeout=10)
        return response.url
    except requests.exceptions.RequestException:
        return url

# 🔍 Step 2: Scrape Each Novel Post with Auto-Retry
def scrape_post(post_url):
    retries = 5
    for attempt in range(retries):
        try:
            response = session.get(post_url, timeout=60)
            if response.status_code == 429:
                print(f"⚠ Rate limit hit for {post_url}. Waiting...")
                time.sleep(2 ** attempt * 10)
                continue
            if response.status_code != 200:
                print(f"⚠ Retrying ({attempt+1}/{retries}) for {post_url}: HTTP {response.status_code}")
                time.sleep(5)
                continue

            soup = BeautifulSoup(response.text, "html.parser")

            # Extract Title (unchanged, since titles are working)
            title_selectors = [
                "h1.entry-title",
                "h2.entry-title",
                "h1.post-title",
                "h2.post-title",
                "h3.entry-title",
                "h3.post-title",
                "div.post-title",
                "div.entry-title",
                "h1",
                "h2",
                "h3"
            ]
            title = None
            title_element = None
            for selector in title_selectors:
                title_elem = soup.select_one(selector)
                if title_elem:
                    title = title_elem.text.strip()
                    title_element = title_elem
                    print(f"📌 Found title with selector '{selector}': '{title}' for URL: {post_url}")
                    break

            if not title or "digest library" in title.lower():
                headers = soup.find_all(["h1", "h2", "h3"])
                for header in headers:
                    text = header.text.strip()
                    if "digest library" not in text.lower() and len(text) > 10 and not text.lower().startswith("home"):
                        title = text
                        title_element = header
                        print(f"📌 Fallback title found: '{title}' for URL: {post_url}")
                        break

            if not title or "digest library" in title.lower():
                title_tag = soup.find("title")
                if title_tag:
                    title = title_tag.text.strip()
                    if "digest library" in title.lower():
                        title = title.replace("Digest Library", "").replace("|", "").strip()
                    print(f"📌 Title from <title> tag: '{title}' for URL: {post_url}")

            title = title if title and "digest library" not in title.lower() else "No Title Found"
            print(f"📌 Final title: '{title}' for URL: {post_url}")

            # Extract Download Links
            # 1. Get all <a> tags with href
            all_links = [a["href"] for a in soup.find_all("a", href=True)]
            # 2. Get URLs from <button> tags or data attributes
            button_links = [button.get("onclick", "").strip("'").replace("window.location.href=", "")
                           for button in soup.find_all("button") if button.get("onclick")]
            # 3. Resolve redirects for all links
            all_links = [resolve_redirect(link) for link in all_links + button_links if link]

            # 4. Filter for known download domains
            download_domains = ["drive.google", "mediafire", "dropbox", "mega.nz"]
            google_drive_links = [link for link in all_links if "drive.google" in link]
            mediafire_links = [link for link in all_links if "mediafire" in link]
            other_links = [link for link in all_links if any(domain in link for domain in ["dropbox", "mega.nz"])]

            # 5. Search entire page content for raw URLs
            content_selectors = ["div.post-body", "div.entry-content", "div.post-content", "article", "div.post"]
            content = None
            for selector in content_selectors:
                content = soup.select_one(selector)
                if content:
                    break
            if not content:
                content = soup  # Fallback to entire page

            raw_urls = []
            text = content.get_text()
            url_pattern = r'https?://[^\s<>"]+|www\.[^\s<>"]+'
            raw_urls = re.findall(url_pattern, text)
            raw_urls = [url for url in raw_urls if any(domain in url.lower() for domain in download_domains)]

            # Combine links
            google_drive_links.extend([url for url in raw_urls if "drive.google" in url and url not in google_drive_links])
            mediafire_links.extend([url for url in raw_urls if "mediafire" in url and url not in mediafire_links])
            other_links.extend([url for url in raw_urls if any(domain in url for domain in ["dropbox", "mega.nz"]) and url not in other_links])

            # Log for debugging
            with open(LOG_FILE, "a") as f:
                f.write(f"{datetime.now()}: URL: {post_url}, Title: {title}\n")
                f.write(f"  All <a> hrefs: {all_links}\n")
                f.write(f"  Button links: {button_links}\n")
                f.write(f"  Raw URLs from content: {raw_urls}\n")
                f.write(f"  Google Drive Links: {google_drive_links}\n")
                f.write(f"  Mediafire Links: {mediafire_links}\n")
                f.write(f"  Other Links: {other_links}\n")
                if title_element:
                    parent = title_element.find_parent()
                    context = str(parent)[:200] if parent else "No parent"
                    f.write(f"  Title Context: {context}\n")
                # Log content snippet for debugging
                content_snippet = text[:200].replace('\n', ' ')
                f.write(f"  Content Snippet: {content_snippet}\n")

            return {
                "Title": title,
                "Google Drive Links": ", ".join(google_drive_links) if google_drive_links else "No Google Drive Link",
                "Mediafire Links": ", ".join(mediafire_links) if mediafire_links else "No Mediafire Link",
                "Other Links": ", ".join(other_links) if other_links else "No Other Links"
            }
        except requests.exceptions.RequestException as e:
            print(f"⚠ Attempt {attempt+1} failed for {post_url}: {e}")
            time.sleep(5)

    # ❌ Save failed link
    with open(FAILED_LINKS_FILE, "a") as f:
        f.write(post_url + "\n")
    return None

# 📌 Step 3: Scrape Each Post & Save Data in Batches
novels_data = []
BATCH_SIZE = 20
start_time = time.time()

with concurrent.futures.ThreadPoolExecutor(max_workers=5) as executor:
    future_to_url = {executor.submit(scrape_post, post_urls[idx]): idx for idx in range(last_index, len(post_urls))}

    for count, future in enumerate(concurrent.futures.as_completed(future_to_url), start=1):
        idx = future_to_url[future]
        result = future.result()
        if result:
            novels_data.append(result)

        # ✅ Save every batch of 100 posts
        if len(novels_data) >= BATCH_SIZE:
            df = pd.DataFrame(novels_data)
            try:
                if os.path.exists(SAVE_PATH_XLSX):
                    existing_df = pd.read_excel(SAVE_PATH_XLSX, engine='openpyxl')
                    df = pd.concat([existing_df, df], ignore_index=True)
                df.to_excel(SAVE_PATH_XLSX, index=False, engine='openpyxl')
                novels_data = []
                with progress_lock:
                    with open(PROGRESS_FILE, "w") as f:
                        f.write(str(idx))
            except (PermissionError, IOError) as e:
                print(f"❌ Cannot write to {SAVE_PATH_XLSX}: {e}")
                exit()

        # ⏳ Show estimated remaining time
        if count % 50 == 0:
            remaining_time = estimate_time(start_time, count, len(post_urls) - last_index)
            print(f"⏳ Estimated time remaining: {remaining_time}")

        time.sleep(random.uniform(1, 2))

# 📥 Step 4: Final Save
if novels_data:
    df = pd.DataFrame(novels_data)
    try:
        if os.path.exists(SAVE_PATH_XLSX):
            existing_df = pd.read_excel(SAVE_PATH_XLSX, engine='openpyxl')
            df = pd.concat([existing_df, df], ignore_index=True)
        df.to_excel(SAVE_PATH_XLSX, index=False, engine='openpyxl')
    except (PermissionError, IOError) as e:
        print(f"❌ Cannot write to {SAVE_PATH_XLSX}: {e}")
        exit()

# ✅ Delete progress file
if os.path.exists(PROGRESS_FILE):
    try:
        os.remove(PROGRESS_FILE)
    except OSError:
        print("⚠ Could not delete progress file.")

print(f"✅ Scraping complete! Data saved in '{SAVE_PATH_XLSX}'")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# ❌ Sitemap request failed: HTTPSConnectionPool(host='digestlibrary.com', port=443): Read timed out. (read timeout=30)
# 📌 Found title with selector 'h1': 'Digest Library' for URL: https://digestlibrary.com/2024/11/11/tu-hi-ishq-tu-hi-janoon-complete-by-saheba-firdous/
# 📌 Fallback title found: 'Tu hi ishq tu hi janoon complete by Saheba Firdous' for URL: https://digestlibrary.com/2024/11/11/tu-hi-ishq-tu-hi-janoon-complete-by-saheba-firdous/
# 📌 Final title: 'Tu hi ishq tu hi janoon complete by Saheba Firdous' for URL: https://digestlibrary.com/2024/11/11/tu-hi-ishq-tu-hi-janoon-complete-by-saheba-firdous/
# 📌 Found title with selector 'h1': 'Digest Library' for URL: https://digestlibrary.com/2023/03/27/hasil-e-tamanna-tum-hi-ho-by-shazia-mustafa/
# 📌 Fallback title found: 'Hasil e tamanna tum hi ho by Shazia Mustafa' for URL: https://digestlibrary.com/2023/03/27/hasil-e-tamanna-tum-hi-ho-by-shazia-mustafa/
# 📌 Final title: 'Hasil e tamanna tum hi ho by Shazia Mustafa' for URL: https://digestlibrary.com/2023/03/27/hasil-e-tamanna-tum-hi-ho-by-shazia-mustafa/
# ⚠ Attempt 1 failed for https://digestlibrary.com/2024/11/12/musafat-tamam-hui-by-shumaila-dilebad/: HTTPSConnectionPool(host='digestlibrary.com', port=443): Max retries exceeded with url: /2024/11/12/musafat-tamam-hui-by-shumaila-dilebad/ (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7d585aeee590>, 'Connection to digestlibrary.com timed out. (connect timeout=60)'))
# ⚠ Attempt 1 failed for https://digestlibrary.com/2024/11/12/zindagi-mehve-raqas-hai-complete-by-almees-jabbar/: HTTPSConnectionPool(host='digestlibrary.com', port=443): Max retries exceeded with url: /2024/11/12/zindagi-mehve-raqas-hai-complete-by-almees-jabbar/ (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7d585afb7490>, 'Connection to digestlibrary.com timed out. (connect timeout=60)'))
# ⚠ Attempt 1 failed for https://digestlibrary.com/2024/11/12/nakhal-e-wafa-epi_4-by-farah-bukhari/: HTTPSConnectionPool(host='digestlibrary.com', port=443): Max retries exceeded with url: /2024/11/12/nakhal-e-wafa-epi_4-by-farah-bukhari/ (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7d585a4c7110>, 'Connection to digestlibrary.com timed out. (connect timeout=60)'))
# 📌 Found title with selector 'h1': 'Digest Library' for URL: https://digestlibrary.com/2024/11/12/zindagi-mehve-raqas-hai-complete-by-almees-jabbar/
# 📌 Fallback title found: 'Zindagi mehve raqas hai complete by Almees Jabbar' for URL: https://digestlibrary.com/2024/11/12/zindagi-mehve-raqas-hai-complete-by-almees-jabbar/
# 📌 Final title: 'Zindagi mehve raqas hai complete by Almees Jabbar' for URL: https://digestlibrary.com/2024/11/12/zindagi-mehve-raqas-hai-complete-by-almees-jabbar/
# 📌 Found title with selector 'h1': 'Digest Library' for URL: https://digestlibrary.com/2024/11/12/nakhal-e-wafa-epi_4-by-farah-bukhari/
# 📌 Fallback title found: 'Nakhal e wafa epi_4 by Farah Bukhari' for URL: https://digestlibrary.com/2024/11/12/nakhal-e-wafa-epi_4-by-farah-bukhari/
# 📌 Final title: 'Nakhal e wafa epi_4 by Farah Bukhari' for URL: https://digestlibrary.com/2024/11/12/nakhal-e-wafa-epi_4-by-farah-bukhari/
# 📌 Found title with selector 'h1': 'Digest Library' for URL: https://digestlibrary.com/2024/11/12/musafat-tamam-hui-by-shumaila-dilebad/
# 📌 Fallback title found: 'Musafat tamam hui by Shumaila Dilebad' for URL: https://digestlibrary.com/2024/11/12/musafat-tamam-hui-by-shumaila-dilebad/
# 📌 Final title: 'Musafat tamam hui by Shumaila Dilebad' for URL: https://digestlibrary.com/2024/11/12/musafat-tamam-hui-by-shumaila-dilebad/
# ⚠ Attempt 1 failed for https://digestlibrary.com/2025/02/28/mere-gumshuda-2-by-umme-maryam/: HTTPSConnectionPool(host='digestlibrary.com', port=443): Max retries exceeded with url: /2025/02/28/mere-gumshuda-2-by-umme-maryam/ (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7d585472e350>, 'Connection to digestlibrary.com timed out. (connect timeout=60)'))
# ⚠ Attempt 1 failed for https://digestlibrary.com/2023/12/14/shua-digest-may-1994-complete-pdf/: HTTPSConnectionPool(host='digestlibrary.com', port=443): Max retries exceeded with url: /2023/12/14/shua-digest-may-1994-complete-pdf/ (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7d5854c67910>, 'Connection to digestlibrary.com timed out. (connect timeout=60)'))
# ⚠ Attempt 2 failed for https://digestlibrary.com/2025/02/28/mere-gumshuda-2-by-umme-maryam/: HTTPSConnectionPool(host='digestlibrary.com', port=443): Max retries exceeded with url: /2025/02/28/mere-gumshuda-2-by-umme-maryam/ (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7d585a7660d0>, 'Connection to digestlibrary.com timed out. (connect timeout=60)'))
# ⚠ Attempt 2 failed for https://digestlibrary.com/2023/12/14/shua-digest-may-1994-complete-pdf/: HTTPSConnectionPool(host='digestlibrary.com', port=443): Max retries exceeded with url: /2023/12/14/shua-digest-may-1994-complete-pdf/ (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7d5854798e50>, 'Connection to digestlibrary.com timed out. (connect timeout=60)'))
# ⚠ Attempt 1 failed for https://digestlibrary.com/2021/09/21/tumharay-leye-tmhari-wo-by-nighat-abdullah/: HTTPSConnectionPool(host='digestlibrary.com', port=443): Max retries exceeded with url: /2021/09/21/tumharay-leye-tmhari-wo-by-nighat-abdullah/ (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7d5854c6d750>, 'Connection to digestlibrary.com timed out. (connect timeout=60)'))
# ⚠ Attempt 1 failed for https://digestlibrary.com/2023/08/21/sitara-e-zeesat-by-misbah-awan/: HTTPSConnectionPool(host='digestlibrary.com', port=443): Max retries exceeded with url: /2023/08/21/sitara-e-zeesat-by-misbah-awan/ (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7d585a334050>, 'Connection to digestlibrary.com timed out. (connect timeout=60)'))
# ⚠ Attempt 1 failed for https://digestlibrary.com/2025/03/01/man-ki-dehleez-per-by-nabiha-naqvi/: HTTPSConnectionPool(host='digestlibrary.com', port=443): Max retries exceeded with url: /2025/03/01/man-ki-dehleez-per-by-nabiha-naqvi/ (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7d5854c65990>, 'Connection to digestlibrary.com timed out. (connect timeout=60)'))
# ⚠ Attempt 3 failed for https://digestlibrary.com/2025/02/28/mere-gumshuda-2-by-umme-maryam/: HTTPSConnectionPool(host='digestlibrary.com', port=443): Max retries exceeded with url: /2025/02/28/mere-gumshuda-2-by-umme-maryam/ (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7d585adc1d50>, 'Connection to digestlibrary.com timed out. (connect timeout=60)'))
# ⚠ Attempt 3 failed for https://digestlibrary.com/2023/12/14/shua-digest-may-1994-complete-pdf/: HTTPSConnectionPool(host='digestlibrary.com', port=443): Max retries exceeded with url: /2023/12/14/shua-digest-may-1994-complete-pdf/ (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7d585a7660d0>, 'Connection to digestlibrary.com timed out. (connect timeout=60)'))
# ⚠ Attempt 2 failed for https://digestlibrary.com/2021/09/21/tumharay-leye-tmhari-wo-by-nighat-abdullah/: HTTPSConnectionPool(host='digestlibrary.com', port=443): Max retries exceeded with url: /2021/09/21/tumharay-leye-tmhari-wo-by-nighat-abdullah/ (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7d5864616ad0>, 'Connection to digestlibrary.com timed out. (connect timeout=60)'))
# ⚠ Attempt 2 failed for https://digestlibrary.com/2023/08/21/sitara-e-zeesat-by-misbah-awan/: HTTPSConnectionPool(host='digestlibrary.com', port=443): Max retries exceeded with url: /2023/08/21/sitara-e-zeesat-by-misbah-awan/ (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7d58643ecf50>, 'Connection to digestlibrary.com timed out. (connect timeout=60)'))
# ⚠ Attempt 2 failed for https://digestlibrary.com/2025/03/01/man-ki-dehleez-per-by-nabiha-naqvi/: HTTPSConnectionPool(host='digestlibrary.com', port=443): Max retries exceeded with url: /2025/03/01/man-ki-dehleez-per-by-nabiha-naqvi/ (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7d585a4c4150>, 'Connection to digestlibrary.com timed out. (connect timeout=60)'))
# ⚠ Attempt 4 failed for https://digestlibrary.com/2025/02/28/mere-gumshuda-2-by-umme-maryam/: HTTPSConnectionPool(host='digestlibrary.com', port=443): Max retries exceeded with url: /2025/02/28/mere-gumshuda-2-by-umme-maryam/ (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7d585a5077d0>, 'Connection to digestlibrary.com timed out. (connect timeout=60)'))
# ⚠ Attempt 4 failed for https://digestlibrary.com/2023/12/14/shua-digest-may-1994-complete-pdf/: HTTPSConnectionPool(host='digestlibrary.com', port=443): Max retries exceeded with url: /2023/12/14/shua-digest-may-1994-complete-pdf/ (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7d585af1c590>, 'Connection to digestlibrary.com timed out. (connect timeout=60)'))
# ⚠ Attempt 3 failed for https://digestlibrary.com/2021/09/21/tumharay-leye-tmhari-wo-by-nighat-abdullah/: HTTPSConnectionPool(host='digestlibrary.com', port=443): Max retries exceeded with url: /2021/09/21/tumharay-leye-tmhari-wo-by-nighat-abdullah/ (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7d585a4c5d10>, 'Connection to digestlibrary.com timed out. (connect timeout=60)'))
# ⚠ Attempt 3 failed for https://digestlibrary.com/2023/08/21/sitara-e-zeesat-by-misbah-awan/: HTTPSConnectionPool(host='digestlibrary.com', port=443): Max retries exceeded with url: /2023/08/21/sitara-e-zeesat-by-misbah-awan/ (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7d585a358c90>, 'Connection to digestlibrary.com timed out. (connect timeout=60)'))
# ⚠ Attempt 3 failed for https://digestlibrary.com/2025/03/01/man-ki-dehleez-per-by-nabiha-naqvi/: HTTPSConnectionPool(host='digestlibrary.com', port=443): Max retries exceeded with url: /2025/03/01/man-ki-dehleez-per-by-nabiha-naqvi/ (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7d585a32d3d0>, 'Connection to digestlibrary.com timed out. (connect timeout=60)'))
# ⚠ Attempt 5 failed for https://digestlibrary.com/2025/02/28/mere-gumshuda-2-by-umme-maryam/: HTTPSConnectionPool(host='digestlibrary.com', port=443): Max retries exceeded with url: /2025/02/28/mere-gumshuda-2-by-umme-maryam/ (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7d585472e0d0>, 'Connection to digestlibrary.com timed out. (connect timeout=60)'))
# ⚠ Attempt 5 failed for https://digestlibrary.com/2023/12/14/shua-digest-may-1994-complete-pdf/: HTTPSConnectionPool(host='digestlibrary.com', port=443): Max retries exceeded with url: /2023/12/14/shua-digest-may-1994-complete-pdf/ (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7d585a4b60d0>, 'Connection to digestlibrary.com timed out. (connect timeout=60)'))
# ⚠ Attempt 4 failed for https://digestlibrary.com/2021/09/21/tumharay-leye-tmhari-wo-by-nighat-abdullah/: HTTPSConnectionPool(host='digestlibrary.com', port=443): Max retries exceeded with url: /2021/09/21/tumharay-leye-tmhari-wo-by-nighat-abdullah/ (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7d5854c53710>, 'Connection to digestlibrary.com timed out. (connect timeout=60)'))
# ⚠ Attempt 4 failed for https://digestlibrary.com/2023/08/21/sitara-e-zeesat-by-misbah-awan/: HTTPSConnectionPool(host='digestlibrary.com', port=443): Max retries exceeded with url: /2023/08/21/sitara-e-zeesat-by-misbah-awan/ (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7d585ade1c10>, 'Connection to digestlibrary.com timed out. (connect timeout=60)'))
# ⚠ Attempt 4 failed for https://digestlibrary.com/2025/03/01/man-ki-dehleez-per-by-nabiha-naqvi/: HTTPSConnectionPool(host='digestlibrary.com', port=443): Max retries exceeded with url: /2025/03/01/man-ki-dehleez-per-by-nabiha-naqvi/ (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7d5864129450>, 'Connection to digestlibrary.com timed out. (connect timeout=60)'))
# ⚠ Attempt 1 failed for https://digestlibrary.com/2025/03/01/ik-umar-ki-riazat-by-nighat-seema/: HTTPSConnectionPool(host='digestlibrary.com', port=443): Max retries exceeded with url: /2025/03/01/ik-umar-ki-riazat-by-nighat-seema/ (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7d58643e0b10>, 'Connection to digestlibrary.com timed out. (connect timeout=60)'))
# ⚠ Attempt 1 failed for https://digestlibrary.com/2025/03/01/hum-tum-aur-chand-by-humaira-shafi/: HTTPSConnectionPool(host='digestlibrary.com', port=443): Max retries exceeded with url: /2025/03/01/hum-tum-aur-chand-by-humaira-shafi/ (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7d585afa2f50>, 'Connection to digestlibrary.com timed out. (connect timeout=60)'))
# ⚠ Attempt 5 failed for https://digestlibrary.com/2021/09/21/tumharay-leye-tmhari-wo-by-nighat-abdullah/: HTTPSConnectionPool(host='digestlibrary.com', port=443): Max retries exceeded with url: /2021/09/21/tumharay-leye-tmhari-wo-by-nighat-abdullah/ (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7d585a9c7210>, 'Connection to digestlibrary.com timed out. (connect timeout=60)'))
# ⚠ Attempt 5 failed for https://digestlibrary.com/2023/08/21/sitara-e-zeesat-by-misbah-awan/: HTTPSConnectionPool(host='digestlibrary.com', port=443): Max retries exceeded with url: /2023/08/21/sitara-e-zeesat-by-misbah-awan/ (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7d585472e190>, 'Connection to digestlibrary.com timed out. (connect timeout=60)'))
# ⚠ Attempt 5 failed for https://digestlibrary.com/2025/03/01/man-ki-dehleez-per-by-nabiha-naqvi/: HTTPSConnectionPool(host='digestlibrary.com', port=443): Max retries exceeded with url: /2025/03/01/man-ki-dehleez-per-by-nabiha-naqvi/ (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7d585479a290>, 'Connection to digestlibrary.com timed out. (connect timeout=60)'))
# ⚠ Attempt 2 failed for https://digestlibrary.com/2025/03/01/ik-umar-ki-riazat-by-nighat-seema/: HTTPSConnectionPool(host='digestlibrary.com', port=443): Max retries exceeded with url: /2025/03/01/ik-umar-ki-riazat-by-nighat-seema/ (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7d585a4c5090>, 'Connection to digestlibrary.com timed out. (connect timeout=60)'))
# ⚠ Attempt 2 failed for https://digestlibrary.com/2025/03/01/hum-tum-aur-chand-by-humaira-shafi/: HTTPSConnectionPool(host='digestlibrary.com', port=443): Max retries exceeded with url: /2025/03/01/hum-tum-aur-chand-by-humaira-shafi/ (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7d5854799b10>, 'Connection to digestlibrary.com timed out. (connect timeout=60)'))
# ⚠ Attempt 1 failed for https://digestlibrary.com/2023/01/17/jeena-esi-ka-naam-hai-by-nuzhat-jabeen-zia/: HTTPSConnectionPool(host='digestlibrary.com', port=443): Max retries exceeded with url: /2023/01/17/jeena-esi-ka-naam-hai-by-nuzhat-jabeen-zia/ (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7d585a4c4850>, 'Connection to digestlibrary.com timed out. (connect timeout=60)'))
# ⚠ Attempt 1 failed for https://digestlibrary.com/2021/05/19/aey-chand-guwah-rehna-by-nuzhat-jabeen/: HTTPSConnectionPool(host='digestlibrary.com', port=443): Max retries exceeded with url: /2021/05/19/aey-chand-guwah-rehna-by-nuzhat-jabeen/ (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7d585479aa90>, 'Connection to digestlibrary.com timed out. (connect timeout=60)'))
# ⚠ Attempt 1 failed for https://digestlibrary.com/2025/03/01/nazdeek-ki-nazar-by-surriya-anjum/: HTTPSConnectionPool(host='digestlibrary.com', port=443): Max retries exceeded with url: /2025/03/01/nazdeek-ki-nazar-by-surriya-anjum/ (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7d585adcd510>, 'Connection to digestlibrary.com timed out. (connect timeout=60)'))
# ⚠ Attempt 3 failed for https://digestlibrary.com/2025/03/01/ik-umar-ki-riazat-by-nighat-seema/: HTTPSConnectionPool(host='digestlibrary.com', port=443): Max retries exceeded with url: /2025/03/01/ik-umar-ki-riazat-by-nighat-seema/ (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7d5864614fd0>, 'Connection to digestlibrary.com timed out. (connect timeout=60)'))
# ⚠ Attempt 3 failed for https://digestlibrary.com/2025/03/01/hum-tum-aur-chand-by-humaira-shafi/: HTTPSConnectionPool(host='digestlibrary.com', port=443): Max retries exceeded with url: /2025/03/01/hum-tum-aur-chand-by-humaira-shafi/ (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7d585adb64d0>, 'Connection to digestlibrary.com timed out. (connect timeout=60)'))
# ⚠ Attempt 2 failed for https://digestlibrary.com/2023/01/17/jeena-esi-ka-naam-hai-by-nuzhat-jabeen-zia/: HTTPSConnectionPool(host='digestlibrary.com', port=443): Max retries exceeded with url: /2023/01/17/jeena-esi-ka-naam-hai-by-nuzhat-jabeen-zia/ (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7d585ade30d0>, 'Connection to digestlibrary.com timed out. (connect timeout=60)'))
# ⚠ Attempt 2 failed for https://digestlibrary.com/2021/05/19/aey-chand-guwah-rehna-by-nuzhat-jabeen/: HTTPSConnectionPool(host='digestlibrary.com', port=443): Max retries exceeded with url: /2021/05/19/aey-chand-guwah-rehna-by-nuzhat-jabeen/ (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7d585a512150>, 'Connection to digestlibrary.com timed out. (connect timeout=60)'))
# ⚠ Attempt 2 failed for https://digestlibrary.com/2025/03/01/nazdeek-ki-nazar-by-surriya-anjum/: HTTPSConnectionPool(host='digestlibrary.com', port=443): Max retries exceeded with url: /2025/03/01/nazdeek-ki-nazar-by-surriya-anjum/ (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7d5854c6c9d0>, 'Connection to digestlibrary.com timed out. (connect timeout=60)'))
# ⚠ Attempt 4 failed for https://digestlibrary.com/2025/03/01/ik-umar-ki-riazat-by-nighat-seema/: HTTPSConnectionPool(host='digestlibrary.com', port=443): Max retries exceeded with url: /2025/03/01/ik-umar-ki-riazat-by-nighat-seema/ (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7d585aa19c50>, 'Connection to digestlibrary.com timed out. (connect timeout=60)'))
# ⚠ Attempt 4 failed for https://digestlibrary.com/2025/03/01/hum-tum-aur-chand-by-humaira-shafi/: HTTPSConnectionPool(host='digestlibrary.com', port=443): Max retries exceeded with url: /2025/03/01/hum-tum-aur-chand-by-humaira-shafi/ (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7d585adb6390>, 'Connection to digestlibrary.com timed out. (connect timeout=60)'))
# ⚠ Attempt 3 failed for https://digestlibrary.com/2023/01/17/jeena-esi-ka-naam-hai-by-nuzhat-jabeen-zia/: HTTPSConnectionPool(host='digestlibrary.com', port=443): Max retries exceeded with url: /2023/01/17/jeena-esi-ka-naam-hai-by-nuzhat-jabeen-zia/ (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7d585afa3150>, 'Connection to digestlibrary.com timed out. (connect timeout=60)'))
# ⚠ Attempt 3 failed for https://digestlibrary.com/2021/05/19/aey-chand-guwah-rehna-by-nuzhat-jabeen/: HTTPSConnectionPool(host='digestlibrary.com', port=443): Max retries exceeded with url: /2021/05/19/aey-chand-guwah-rehna-by-nuzhat-jabeen/ (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7d5854776310>, 'Connection to digestlibrary.com timed out. (connect timeout=60)'))
# ⚠ Attempt 3 failed for https://digestlibrary.com/2025/03/01/nazdeek-ki-nazar-by-surriya-anjum/: HTTPSConnectionPool(host='digestlibrary.com', port=443): Max retries exceeded with url: /2025/03/01/nazdeek-ki-nazar-by-surriya-anjum/ (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7d5854777250>, 'Connection to digestlibrary.com timed out. (connect timeout=60)'))
# ⚠ Attempt 5 failed for https://digestlibrary.com/2025/03/01/ik-umar-ki-riazat-by-nighat-seema/: HTTPSConnectionPool(host='digestlibrary.com', port=443): Max retries exceeded with url: /2025/03/01/ik-umar-ki-riazat-by-nighat-seema/ (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7d585ade1dd0>, 'Connection to digestlibrary.com timed out. (connect timeout=60)'))
# ⚠ Attempt 5 failed for https://digestlibrary.com/2025/03/01/hum-tum-aur-chand-by-humaira-shafi/: HTTPSConnectionPool(host='digestlibrary.com', port=443): Max retries exceeded with url: /2025/03/01/hum-tum-aur-chand-by-humaira-shafi/ (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7d585ad83210>, 'Connection to digestlibrary.com timed out. (connect timeout=60)'))
# ⚠ Attempt 4 failed for https://digestlibrary.com/2023/01/17/jeena-esi-ka-naam-hai-by-nuzhat-jabeen-zia/: HTTPSConnectionPool(host='digestlibrary.com', port=443): Max retries exceeded with url: /2023/01/17/jeena-esi-ka-naam-hai-by-nuzhat-jabeen-zia/ (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7d585a9c7e10>, 'Connection to digestlibrary.com timed out. (connect timeout=60)'))
# ⚠ Attempt 4 failed for https://digestlibrary.com/2021/05/19/aey-chand-guwah-rehna-by-nuzhat-jabeen/: HTTPSConnectionPool(host='digestlibrary.com', port=443): Max retries exceeded with url: /2021/05/19/aey-chand-guwah-rehna-by-nuzhat-jabeen/ (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7d5854c52490>, 'Connection to digestlibrary.com timed out. (connect timeout=60)'))
# ⚠ Attempt 4 failed for https://digestlibrary.com/2025/03/01/nazdeek-ki-nazar-by-surriya-anjum/: HTTPSConnectionPool(host='digestlibrary.com', port=443): Max retries exceeded with url: /2025/03/01/nazdeek-ki-nazar-by-surriya-anjum/ (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7d585477f8d0>, 'Connection to digestlibrary.com timed out. (connect timeout=60)'))
# ⚠ Attempt 1 failed for https://digestlibrary.com/2021/12/16/guwah-rafaqton-ka-halal-e-eid-by-saba-javed/: HTTPSConnectionPool(host='digestlibrary.com', port=443): Max retries exceeded with url: /2021/12/16/guwah-rafaqton-ka-halal-e-eid-by-saba-javed/ (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7d585a32de50>, 'Connection to digestlibrary.com timed out. (connect timeout=60)'))
# ⚠ Attempt 1 failed for https://digestlibrary.com/2021/01/04/num-palkyen-moje-hawa-by-saba-ajaved/: HTTPSConnectionPool(host='digestlibrary.com', port=443): Max retries exceeded with url: /2021/01/04/num-palkyen-moje-hawa-by-saba-ajaved/ (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7d5864617650>, 'Connection to digestlibrary.com timed out. (connect timeout=60)'))
# ⚠ Attempt 5 failed for https://digestlibrary.com/2023/01/17/jeena-esi-ka-naam-hai-by-nuzhat-jabeen-zia/: HTTPSConnectionPool(host='digestlibrary.com', port=443): Max retries exceeded with url: /2023/01/17/jeena-esi-ka-naam-hai-by-nuzhat-jabeen-zia/ (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7d5854c6dad0>, 'Connection to digestlibrary.com timed out. (connect timeout=60)'))
# ⚠ Attempt 5 failed for https://digestlibrary.com/2021/05/19/aey-chand-guwah-rehna-by-nuzhat-jabeen/: HTTPSConnectionPool(host='digestlibrary.com', port=443): Max retries exceeded with url: /2021/05/19/aey-chand-guwah-rehna-by-nuzhat-jabeen/ (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7d586609cd50>, 'Connection to digestlibrary.com timed out. (connect timeout=60)'))
# ⚠ Attempt 5 failed for https://digestlibrary.com/2025/03/01/nazdeek-ki-nazar-by-surriya-anjum/: HTTPSConnectionPool(host='digestlibrary.com', port=443): Max retries exceeded with url: /2025/03/01/nazdeek-ki-nazar-by-surriya-anjum/ (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7d585479bb10>, 'Connection to digestlibrary.com timed out. (connect timeout=60)'))
# ⚠ Attempt 2 failed for https://digestlibrary.com/2021/12/16/guwah-rafaqton-ka-halal-e-eid-by-saba-javed/: HTTPSConnectionPool(host='digestlibrary.com', port=443): Max retries exceeded with url: /2021/12/16/guwah-rafaqton-ka-halal-e-eid-by-saba-javed/ (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7d585477c690>, 'Connection to digestlibrary.com timed out. (connect timeout=60)'))
# ⚠ Attempt 2 failed for https://digestlibrary.com/2021/01/04/num-palkyen-moje-hawa-by-saba-ajaved/: HTTPSConnectionPool(host='digestlibrary.com', port=443): Max retries exceeded with url: /2021/01/04/num-palkyen-moje-hawa-by-saba-ajaved/ (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7d5854799d90>, 'Connection to digestlibrary.com timed out. (connect timeout=60)'))
# ⚠ Attempt 1 failed for https://digestlibrary.com/2025/03/01/ishq-chand-chakor-jesa-by-bint-e-sehar/: HTTPSConnectionPool(host='digestlibrary.com', port=443): Max retries exceeded with url: /2025/03/01/ishq-chand-chakor-jesa-by-bint-e-sehar/ (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7d586609c990>, 'Connection to digestlibrary.com timed out. (connect timeout=60)'))
# ⚠ Attempt 1 failed for https://digestlibrary.com/2021/01/16/safal-ghar-by-bushra-syed/: HTTPSConnectionPool(host='digestlibrary.com', port=443): Max retries exceeded with url: /2021/01/16/safal-ghar-by-bushra-syed/ (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7d585adccf50>, 'Connection to digestlibrary.com timed out. (connect timeout=60)'))
# ⚠ Attempt 1 failed for https://digestlibrary.com/2022/04/06/shua-digest-january-2000-complete-pdf/: HTTPSConnectionPool(host='digestlibrary.com', port=443): Max retries exceeded with url: /2022/04/06/shua-digest-january-2000-complete-pdf/ (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7d585479b150>, 'Connection to digestlibrary.com timed out. (connect timeout=60)'))
# ⚠ Attempt 3 failed for https://digestlibrary.com/2021/12/16/guwah-rafaqton-ka-halal-e-eid-by-saba-javed/: HTTPSConnectionPool(host='digestlibrary.com', port=443): Max retries exceeded with url: /2021/12/16/guwah-rafaqton-ka-halal-e-eid-by-saba-javed/ (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7d585477c490>, 'Connection to digestlibrary.com timed out. (connect timeout=60)'))
# ⚠ Attempt 3 failed for https://digestlibrary.com/2021/01/04/num-palkyen-moje-hawa-by-saba-ajaved/: HTTPSConnectionPool(host='digestlibrary.com', port=443): Max retries exceeded with url: /2021/01/04/num-palkyen-moje-hawa-by-saba-ajaved/ (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7d585477d790>, 'Connection to digestlibrary.com timed out. (connect timeout=60)'))
# ⚠ Attempt 2 failed for https://digestlibrary.com/2025/03/01/ishq-chand-chakor-jesa-by-bint-e-sehar/: HTTPSConnectionPool(host='digestlibrary.com', port=443): Max retries exceeded with url: /2025/03/01/ishq-chand-chakor-jesa-by-bint-e-sehar/ (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7d586453d510>, 'Connection to digestlibrary.com timed out. (connect timeout=60)'))
# ⚠ Attempt 2 failed for https://digestlibrary.com/2021/01/16/safal-ghar-by-bushra-syed/: HTTPSConnectionPool(host='digestlibrary.com', port=443): Max retries exceeded with url: /2021/01/16/safal-ghar-by-bushra-syed/ (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7d585a512650>, 'Connection to digestlibrary.com timed out. (connect timeout=60)'))
# ⚠ Attempt 2 failed for https://digestlibrary.com/2022/04/06/shua-digest-january-2000-complete-pdf/: HTTPSConnectionPool(host='digestlibrary.com', port=443): Max retries exceeded with url: /2022/04/06/shua-digest-january-2000-complete-pdf/ (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7d586609d4d0>, 'Connection to digestlibrary.com timed out. (connect timeout=60)'))
# ⚠ Attempt 4 failed for https://digestlibrary.com/2021/12/16/guwah-rafaqton-ka-halal-e-eid-by-saba-javed/: HTTPSConnectionPool(host='digestlibrary.com', port=443): Max retries exceeded with url: /2021/12/16/guwah-rafaqton-ka-halal-e-eid-by-saba-javed/ (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7d585aa18110>, 'Connection to digestlibrary.com timed out. (connect timeout=60)'))
# ⚠ Attempt 4 failed for https://digestlibrary.com/2021/01/04/num-palkyen-moje-hawa-by-saba-ajaved/: HTTPSConnectionPool(host='digestlibrary.com', port=443): Max retries exceeded with url: /2021/01/04/num-palkyen-moje-hawa-by-saba-ajaved/ (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7d585a4be3d0>, 'Connection to digestlibrary.com timed out. (connect timeout=60)'))
# ⚠ Attempt 3 failed for https://digestlibrary.com/2025/03/01/ishq-chand-chakor-jesa-by-bint-e-sehar/: HTTPSConnectionPool(host='digestlibrary.com', port=443): Max retries exceeded with url: /2025/03/01/ishq-chand-chakor-jesa-by-bint-e-sehar/ (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7d5854c6e890>, 'Connection to digestlibrary.com timed out. (connect timeout=60)'))
# ⚠ Attempt 3 failed for https://digestlibrary.com/2021/01/16/safal-ghar-by-bushra-syed/: HTTPSConnectionPool(host='digestlibrary.com', port=443): Max retries exceeded with url: /2021/01/16/safal-ghar-by-bushra-syed/ (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7d5854c83150>, 'Connection to digestlibrary.com timed out. (connect timeout=60)'))
# ⚠ Attempt 3 failed for https://digestlibrary.com/2022/04/06/shua-digest-january-2000-complete-pdf/: HTTPSConnectionPool(host='digestlibrary.com', port=443): Max retries exceeded with url: /2022/04/06/shua-digest-january-2000-complete-pdf/ (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7d585a32c410>, 'Connection to digestlibrary.com timed out. (connect timeout=60)'))
# ⚠ Attempt 5 failed for https://digestlibrary.com/2021/12/16/guwah-rafaqton-ka-halal-e-eid-by-saba-javed/: HTTPSConnectionPool(host='digestlibrary.com', port=443): Max retries exceeded with url: /2021/12/16/guwah-rafaqton-ka-halal-e-eid-by-saba-javed/ (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7d585aeee1d0>, 'Connection to digestlibrary.com timed out. (connect timeout=60)'))
# ⚠ Attempt 5 failed for https://digestlibrary.com/2021/01/04/num-palkyen-moje-hawa-by-saba-ajaved/: HTTPSConnectionPool(host='digestlibrary.com', port=443): Max retries exceeded with url: /2021/01/04/num-palkyen-moje-hawa-by-saba-ajaved/ (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7d58643eda50>, 'Connection to digestlibrary.com timed out. (connect timeout=60)'))
# ⚠ Attempt 1 failed for https://digestlibrary.com/2022/09/11/jis-bat-ko-khail-samjhte-ho-by-maha-malik/: HTTPSConnectionPool(host='digestlibrary.com', port=443): Max retries exceeded with url: /2022/09/11/jis-bat-ko-khail-samjhte-ho-by-maha-malik/ (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7d585a132210>, 'Connection to digestlibrary.com timed out. (connect timeout=60)'))
# ⚠ Attempt 4 failed for https://digestlibrary.com/2025/03/01/ishq-chand-chakor-jesa-by-bint-e-sehar/: HTTPSConnectionPool(host='digestlibrary.com', port=443): Max retries exceeded with url: /2025/03/01/ishq-chand-chakor-jesa-by-bint-e-sehar/ (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7d58643e0510>, 'Connection to digestlibrary.com timed out. (connect timeout=60)'))
# ⚠ Attempt 4 failed for https://digestlibrary.com/2021/01/16/safal-ghar-by-bushra-syed/: HTTPSConnectionPool(host='digestlibrary.com', port=443): Max retries exceeded with url: /2021/01/16/safal-ghar-by-bushra-syed/ (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7d585a9c7950>, 'Connection to digestlibrary.com timed out. (connect timeout=60)'))
# ⚠ Attempt 4 failed for https://digestlibrary.com/2022/04/06/shua-digest-january-2000-complete-pdf/: HTTPSConnectionPool(host='digestlibrary.com', port=443): Max retries exceeded with url: /2022/04/06/shua-digest-january-2000-complete-pdf/ (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7d585a32e010>, 'Connection to digestlibrary.com timed out. (connect timeout=60)'))
# ⚠ Attempt 1 failed for https://digestlibrary.com/2022/05/29/shua-digest-february-2000-complete-pdf/: HTTPSConnectionPool(host='digestlibrary.com', port=443): Max retries exceeded with url: /2022/05/29/shua-digest-february-2000-complete-pdf/ (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7d585a5115d0>, 'Connection to digestlibrary.com timed out. (connect timeout=60)'))
# ⚠ Attempt 1 failed for https://digestlibrary.com/2025/03/02/shua-digest-july-2021-complete-pdf/: HTTPSConnectionPool(host='digestlibrary.com', port=443): Max retries exceeded with url: /2025/03/02/shua-digest-july-2021-complete-pdf/ (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7d585a4c6d50>, 'Connection to digestlibrary.com timed out. (connect timeout=60)'))
# ⚠ Attempt 1 failed for https://digestlibrary.com/2024/11/13/ajab-guman-tha-wo-shakhas-by-yasmeen-nishat/: HTTPSConnectionPool(host='digestlibrary.com', port=443): Max retries exceeded with url: /2024/11/13/ajab-guman-tha-wo-shakhas-by-yasmeen-nishat/ (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7d58645d3750>, 'Connection to digestlibrary.com timed out. (connect timeout=60)'))
# ⚠ Attempt 2 failed for https://digestlibrary.com/2022/09/11/jis-bat-ko-khail-samjhte-ho-by-maha-malik/: HTTPSConnectionPool(host='digestlibrary.com', port=443): Max retries exceeded with url: /2022/09/11/jis-bat-ko-khail-samjhte-ho-by-maha-malik/ (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7d585a4c4d10>, 'Connection to digestlibrary.com timed out. (connect timeout=60)'))
# ⚠ Attempt 5 failed for https://digestlibrary.com/2025/03/01/ishq-chand-chakor-jesa-by-bint-e-sehar/: HTTPSConnectionPool(host='digestlibrary.com', port=443): Max retries exceeded with url: /2025/03/01/ishq-chand-chakor-jesa-by-bint-e-sehar/ (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7d5866032b10>, 'Connection to digestlibrary.com timed out. (connect timeout=60)'))
# ⚠ Attempt 5 failed for https://digestlibrary.com/2021/01/16/safal-ghar-by-bushra-syed/: HTTPSConnectionPool(host='digestlibrary.com', port=443): Max retries exceeded with url: /2021/01/16/safal-ghar-by-bushra-syed/ (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7d585adc2010>, 'Connection to digestlibrary.com timed out. (connect timeout=60)'))
# ⚠ Attempt 5 failed for https://digestlibrary.com/2022/04/06/shua-digest-january-2000-complete-pdf/: HTTPSConnectionPool(host='digestlibrary.com', port=443): Max retries exceeded with url: /2022/04/06/shua-digest-january-2000-complete-pdf/ (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7d585a5109d0>, 'Connection to digestlibrary.com timed out. (connect timeout=60)'))
# ⚠ Attempt 1 failed for https://digestlibrary.com/2024/11/13/kiran-digest-april-1997-complete-pdf/: HTTPSConnectionPool(host='digestlibrary.com', port=443): Max retries exceeded with url: /2024/11/13/kiran-digest-april-1997-complete-pdf/ (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7d5854777dd0>, 'Connection to digestlibrary.com timed out. (connect timeout=60)'))
# ⚠ Attempt 2 failed for https://digestlibrary.com/2022/05/29/shua-digest-february-2000-complete-pdf/: HTTPSConnectionPool(host='digestlibrary.com', port=443): Max retries exceeded with url: /2022/05/29/shua-digest-february-2000-complete-pdf/ (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7d5854c83290>, 'Connection to digestlibrary.com timed out. (connect timeout=60)'))
# ⚠ Attempt 2 failed for https://digestlibrary.com/2025/03/02/shua-digest-july-2021-complete-pdf/: HTTPSConnectionPool(host='digestlibrary.com', port=443): Max retries exceeded with url: /2025/03/02/shua-digest-july-2021-complete-pdf/ (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7d585aa1a2d0>, 'Connection to digestlibrary.com timed out. (connect timeout=60)'))
# ⚠ Attempt 1 failed for https://digestlibrary.com/2024/11/13/umeed-aur-aas-by-faiza-iftikhar/: HTTPSConnectionPool(host='digestlibrary.com', port=443): Max retries exceeded with url: /2024/11/13/umeed-aur-aas-by-faiza-iftikhar/ (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7d58662bfb90>, 'Connection to digestlibrary.com timed out. (connect timeout=60)'))
# ⚠ Attempt 2 failed for https://digestlibrary.com/2024/11/13/ajab-guman-tha-wo-shakhas-by-yasmeen-nishat/: HTTPSConnectionPool(host='digestlibrary.com', port=443): Max retries exceeded with url: /2024/11/13/ajab-guman-tha-wo-shakhas-by-yasmeen-nishat/ (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7d585afb5e10>, 'Connection to digestlibrary.com timed out. (connect timeout=60)'))
# ⚠ Attempt 3 failed for https://digestlibrary.com/2022/09/11/jis-bat-ko-khail-samjhte-ho-by-maha-malik/: HTTPSConnectionPool(host='digestlibrary.com', port=443): Max retries exceeded with url: /2022/09/11/jis-bat-ko-khail-samjhte-ho-by-maha-malik/ (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7d5854c82190>, 'Connection to digestlibrary.com timed out. (connect timeout=60)'))
# ⚠ Attempt 1 failed for https://digestlibrary.com/2021/10/23/mohabbat-dhanak-rang-orh-kr-by-ghazal-yasir-malik/: HTTPSConnectionPool(host='digestlibrary.com', port=443): Max retries exceeded with url: /2021/10/23/mohabbat-dhanak-rang-orh-kr-by-ghazal-yasir-malik/ (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7d5854777590>, 'Connection to digestlibrary.com timed out. (connect timeout=60)'))
# ⚠ Attempt 1 failed for https://digestlibrary.com/2021/02/01/zaat-e-be-sabat-by-nabila-aziz/: HTTPSConnectionPool(host='digestlibrary.com', port=443): Max retries exceeded with url: /2021/02/01/zaat-e-be-sabat-by-nabila-aziz/ (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7d585adcd910>, 'Connection to digestlibrary.com timed out. (connect timeout=60)'))
# ⚠ Attempt 1 failed for https://digestlibrary.com/2025/03/02/khwateen-digest-july-2018-complete-pdf/: HTTPSConnectionPool(host='digestlibrary.com', port=443): Max retries exceeded with url: /2025/03/02/khwateen-digest-july-2018-complete-pdf/ (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7d58643e0450>, 'Connection to digestlibrary.com timed out. (connect timeout=60)'))
# ⚠ Attempt 2 failed for https://digestlibrary.com/2024/11/13/kiran-digest-april-1997-complete-pdf/: HTTPSConnectionPool(host='digestlibrary.com', port=443): Max retries exceeded with url: /2024/11/13/kiran-digest-april-1997-complete-pdf/ (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7d585a4c6950>, 'Connection to digestlibrary.com timed out. (connect timeout=60)'))
# ⚠ Attempt 3 failed for https://digestlibrary.com/2022/05/29/shua-digest-february-2000-complete-pdf/: HTTPSConnectionPool(host='digestlibrary.com', port=443): Max retries exceeded with url: /2022/05/29/shua-digest-february-2000-complete-pdf/ (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7d585a5125d0>, 'Connection to digestlibrary.com timed out. (connect timeout=60)'))
# ⚠ Attempt 3 failed for https://digestlibrary.com/2025/03/02/shua-digest-july-2021-complete-pdf/: HTTPSConnectionPool(host='digestlibrary.com', port=443): Max retries exceeded with url: /2025/03/02/shua-digest-july-2021-complete-pdf/ (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7d5864616590>, 'Connection to digestlibrary.com timed out. (connect timeout=60)'))
# ⚠ Attempt 2 failed for https://digestlibrary.com/2024/11/13/umeed-aur-aas-by-faiza-iftikhar/: HTTPSConnectionPool(host='digestlibrary.com', port=443): Max retries exceeded with url: /2024/11/13/umeed-aur-aas-by-faiza-iftikhar/ (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7d5854c80990>, 'Connection to digestlibrary.com timed out. (connect timeout=60)'))
# ⚠ Attempt 3 failed for https://digestlibrary.com/2024/11/13/ajab-guman-tha-wo-shakhas-by-yasmeen-nishat/: HTTPSConnectionPool(host='digestlibrary.com', port=443): Max retries exceeded with url: /2024/11/13/ajab-guman-tha-wo-shakhas-by-yasmeen-nishat/ (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7d585a5069d0>, 'Connection to digestlibrary.com timed out. (connect timeout=60)'))
# ⚠ Attempt 4 failed for https://digestlibrary.com/2022/09/11/jis-bat-ko-khail-samjhte-ho-by-maha-malik/: HTTPSConnectionPool(host='digestlibrary.com', port=443): Max retries exceeded with url: /2022/09/11/jis-bat-ko-khail-samjhte-ho-by-maha-malik/ (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7d5854c6c8d0>, 'Connection to digestlibrary.com timed out. (connect timeout=60)'))
# ⚠ Attempt 2 failed for https://digestlibrary.com/2021/10/23/mohabbat-dhanak-rang-orh-kr-by-ghazal-yasir-malik/: HTTPSConnectionPool(host='digestlibrary.com', port=443): Max retries exceeded with url: /2021/10/23/mohabbat-dhanak-rang-orh-kr-by-ghazal-yasir-malik/ (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7d585a9c6c50>, 'Connection to digestlibrary.com timed out. (connect timeout=60)'))
# ⚠ Attempt 2 failed for https://digestlibrary.com/2021/02/01/zaat-e-be-sabat-by-nabila-aziz/: HTTPSConnectionPool(host='digestlibrary.com', port=443): Max retries exceeded with url: /2021/02/01/zaat-e-be-sabat-by-nabila-aziz/ (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7d585477e410>, 'Connection to digestlibrary.com timed out. (connect timeout=60)'))
# ⚠ Attempt 2 failed for https://digestlibrary.com/2025/03/02/khwateen-digest-july-2018-complete-pdf/: HTTPSConnectionPool(host='digestlibrary.com', port=443): Max retries exceeded with url: /2025/03/02/khwateen-digest-july-2018-complete-pdf/ (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7d585aeefa90>, 'Connection to digestlibrary.com timed out. (connect timeout=60)'))
# ⚠ Attempt 3 failed for https://digestlibrary.com/2024/11/13/kiran-digest-april-1997-complete-pdf/: HTTPSConnectionPool(host='digestlibrary.com', port=443): Max retries exceeded with url: /2024/11/13/kiran-digest-april-1997-complete-pdf/ (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7d586414d590>, 'Connection to digestlibrary.com timed out. (connect timeout=60)'))
# ⚠ Attempt 1 failed for https://digestlibrary.com/2023/01/04/zakham-e-safar-hai-muhtram-by-iffat-jiya/: HTTPSConnectionPool(host='digestlibrary.com', port=443): Max retries exceeded with url: /2023/01/04/zakham-e-safar-hai-muhtram-by-iffat-jiya/ (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7d585a9c7490>, 'Connection to digestlibrary.com timed out. (connect timeout=60)'))
# ⚠ Attempt 4 failed for https://digestlibrary.com/2022/05/29/shua-digest-february-2000-complete-pdf/: HTTPSConnectionPool(host='digestlibrary.com', port=443): Max retries exceeded with url: /2022/05/29/shua-digest-february-2000-complete-pdf/ (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7d5854777990>, 'Connection to digestlibrary.com timed out. (connect timeout=60)'))
# ⚠ Attempt 4 failed for https://digestlibrary.com/2025/03/02/shua-digest-july-2021-complete-pdf/: HTTPSConnectionPool(host='digestlibrary.com', port=443): Max retries exceeded with url: /2025/03/02/shua-digest-july-2021-complete-pdf/ (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7d58643e0610>, 'Connection to digestlibrary.com timed out. (connect timeout=60)'))
# ⚠ Attempt 3 failed for https://digestlibrary.com/2024/11/13/umeed-aur-aas-by-faiza-iftikhar/: HTTPSConnectionPool(host='digestlibrary.com', port=443): Max retries exceeded with url: /2024/11/13/umeed-aur-aas-by-faiza-iftikhar/ (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7d585a4bcfd0>, 'Connection to digestlibrary.com timed out. (connect timeout=60)'))
# ⚠ Attempt 4 failed for https://digestlibrary.com/2024/11/13/ajab-guman-tha-wo-shakhas-by-yasmeen-nishat/: HTTPSConnectionPool(host='digestlibrary.com', port=443): Max retries exceeded with url: /2024/11/13/ajab-guman-tha-wo-shakhas-by-yasmeen-nishat/ (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7d586603eb10>, 'Connection to digestlibrary.com timed out. (connect timeout=60)'))
# ⚠ Attempt 5 failed for https://digestlibrary.com/2022/09/11/jis-bat-ko-khail-samjhte-ho-by-maha-malik/: HTTPSConnectionPool(host='digestlibrary.com', port=443): Max retries exceeded with url: /2022/09/11/jis-bat-ko-khail-samjhte-ho-by-maha-malik/ (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7d58640f3650>, 'Connection to digestlibrary.com timed out. (connect timeout=60)'))
# ⚠ Attempt 3 failed for https://digestlibrary.com/2021/10/23/mohabbat-dhanak-rang-orh-kr-by-ghazal-yasir-malik/: HTTPSConnectionPool(host='digestlibrary.com', port=443): Max retries exceeded with url: /2021/10/23/mohabbat-dhanak-rang-orh-kr-by-ghazal-yasir-malik/ (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7d586609df90>, 'Connection to digestlibrary.com timed out. (connect timeout=60)'))
# ⚠ Attempt 3 failed for https://digestlibrary.com/2021/02/01/zaat-e-be-sabat-by-nabila-aziz/: HTTPSConnectionPool(host='digestlibrary.com', port=443): Max retries exceeded with url: /2021/02/01/zaat-e-be-sabat-by-nabila-aziz/ (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7d5854c6c790>, 'Connection to digestlibrary.com timed out. (connect timeout=60)'))
# ⚠ Attempt 3 failed for https://digestlibrary.com/2025/03/02/khwateen-digest-july-2018-complete-pdf/: HTTPSConnectionPool(host='digestlibrary.com', port=443): Max retries exceeded with url: /2025/03/02/khwateen-digest-july-2018-complete-pdf/ (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7d586609dc50>, 'Connection to digestlibrary.com timed out. (connect timeout=60)'))
# ⚠ Attempt 4 failed for https://digestlibrary.com/2024/11/13/kiran-digest-april-1997-complete-pdf/: HTTPSConnectionPool(host='digestlibrary.com', port=443): Max retries exceeded with url: /2024/11/13/kiran-digest-april-1997-complete-pdf/ (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7d58938bc150>, 'Connection to digestlibrary.com timed out. (connect timeout=60)'))
# ⚠ Attempt 2 failed for https://digestlibrary.com/2023/01/04/zakham-e-safar-hai-muhtram-by-iffat-jiya/: HTTPSConnectionPool(host='digestlibrary.com', port=443): Max retries exceeded with url: /2023/01/04/zakham-e-safar-hai-muhtram-by-iffat-jiya/ (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7d585adcea90>, 'Connection to digestlibrary.com timed out. (connect timeout=60)'))
# ...
# ⚠ Attempt 4 failed for https://digestlibrary.com/2025/03/02/teri-chah-mai-by-nabiha-naqvi/: HTTPSConnectionPool(host='digestlibrary.com', port=443): Max retries exceeded with url: /2025/03/02/teri-chah-mai-by-nabiha-naqvi/ (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7d5866032e50>, 'Connection to digestlibrary.com timed out. (connect timeout=60)'))
# ⚠ Attempt 3 failed for https://digestlibrary.com/2021/01/04/sans-sakin-thi-by-nimrah-ahmad/: HTTPSConnectionPool(host='digestlibrary.com', port=443): Max retries exceeded with url: /2021/01/04/sans-sakin-thi-by-nimrah-ahmad/ (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7d585adcd910>, 'Connection to digestlibrary.com timed out. (connect timeout=60)'))
# ⚠ Attempt 4 failed for https://digestlibrary.com/2022/09/12/naveed-e-mohabbat-den-tumhen-by-sana-zafar/: HTTPSConnectionPool(host='digestlibrary.com', port=443): Max retries exceeded with url: /2022/09/12/naveed-e-mohabbat-den-tumhen-by-sana-zafar/ (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7d585ade3b90>, 'Connection to digestlibrary.com timed out. (connect timeout=60)'))
# ⚠ Attempt 5 failed for https://digestlibrary.com/2024/11/13/fasal-e-bahar-mai-by-sadia-raees-khan/: HTTPSConnectionPool(host='digestlibrary.com', port=443): Max retries exceeded with url: /2024/11/13/fasal-e-bahar-mai-by-sadia-raees-khan/ (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7d585a4c4750>, 'Connection to digestlibrary.com timed out. (connect timeout=60)'))
# ⚠ Attempt 3 failed for https://digestlibrary.com/2021/01/25/humnay-dil-ko-roka-tha-by-maryam-aziz/: HTTPSConnectionPool(host='digestlibrary.com', port=443): Max retries exceeded with url: /2021/01/25/humnay-dil-ko-roka-tha-by-maryam-aziz/ (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7d585a32cc90>, 'Connection to digestlibrary.com timed out. (connect timeout=60)'))
# ⚠ Attempt 3 failed for https://digestlibrary.com/2021/07/05/dupehri-ke-geet-by-sidratul-muntaha/: HTTPSConnectionPool(host='digestlibrary.com', port=443): Max retries exceeded with url: /2021/07/05/dupehri-ke-geet-by-sidratul-muntaha/ (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7d5854c80190>, 'Connection to digestlibrary.com timed out. (connect timeout=60)'))
# ⚠ Attempt 3 failed for https://digestlibrary.com/2025/03/02/ma-ul-malook-epi_18-by-nighat-seema/: HTTPSConnectionPool(host='digestlibrary.com', port=443): Max retries exceeded with url: /2025/03/02/ma-ul-malook-epi_18-by-nighat-seema/ (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7d585477e450>, 'Connection to digestlibrary.com timed out. (connect timeout=60)'))
# ⚠ Attempt 4 failed for https://digestlibrary.com/2022/03/09/rang-raiz-mere-complete-by-iffat-sehar-tahir/: HTTPSConnectionPool(host='digestlibrary.com', port=443): Max retries exceeded with url: /2022/03/09/rang-raiz-mere-complete-by-iffat-sehar-tahir/ (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7d585472d790>, 'Connection to digestlibrary.com timed out. (connect timeout=60)'))
# ⚠ Attempt 2 failed for https://digestlibrary.com/2024/11/13/shua-digest-december-2007-complete-pdf/: HTTPSConnectionPool(host='digestlibrary.com', port=443): Max retries exceeded with url: /2024/11/13/shua-digest-december-2007-complete-pdf/ (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7d58938becd0>, 'Connection to digestlibrary.com timed out. (connect timeout=60)'))
# ⚠ Attempt 5 failed for https://digestlibrary.com/2025/03/02/khaiti-by-umme-iman-qazi/: HTTPSConnectionPool(host='digestlibrary.com', port=443): Max retries exceeded with url: /2025/03/02/khaiti-by-umme-iman-qazi/ (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7d5893928a10>, 'Connection to digestlibrary.com timed out. (connect timeout=60)'))
# ⚠ Attempt 5 failed for https://digestlibrary.com/2025/03/02/teri-chah-mai-by-nabiha-naqvi/: HTTPSConnectionPool(host='digestlibrary.com', port=443): Max retries exceeded with url: /2025/03/02/teri-chah-mai-by-nabiha-naqvi/ (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7d58547749d0>, 'Connection to digestlibrary.com timed out. (connect timeout=60)'))
# ⚠ Attempt 4 failed for https://digestlibrary.com/2021/01/04/sans-sakin-thi-by-nimrah-ahmad/: HTTPSConnectionPool(host='digestlibrary.com', port=443): Max retries exceeded with url: /2021/01/04/sans-sakin-thi-by-nimrah-ahmad/ (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7d585a511410>, 'Connection to digestlibrary.com timed out. (connect timeout=60)'))
# ⚠ Attempt 5 failed for https://digestlibrary.com/2022/09/12/naveed-e-mohabbat-den-tumhen-by-sana-zafar/: HTTPSConnectionPool(host='digestlibrary.com', port=443): Max retries exceeded with url: /2022/09/12/naveed-e-mohabbat-den-tumhen-by-sana-zafar/ (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7d58643e0150>, 'Connection to digestlibrary.com timed out. (connect timeout=60)'))
# ⚠ Attempt 1 failed for https://digestlibrary.com/2024/11/13/shua-digest-november-2007-complete-pdf/: HTTPSConnectionPool(host='digestlibrary.com', port=443): Max retries exceeded with url: /2024/11/13/shua-digest-november-2007-complete-pdf/ (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7d585a9c73d0>, 'Connection to digestlibrary.com timed out. (connect timeout=60)'))
# ⚠ Attempt 4 failed for https://digestlibrary.com/2021/01/25/humnay-dil-ko-roka-tha-by-maryam-aziz/: HTTPSConnectionPool(host='digestlibrary.com', port=443): Max retries exceeded with url: /2021/01/25/humnay-dil-ko-roka-tha-by-maryam-aziz/ (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7d585a358510>, 'Connection to digestlibrary.com timed out. (connect timeout=60)'))
# ⚠ Attempt 4 failed for https://digestlibrary.com/2021/07/05/dupehri-ke-geet-by-sidratul-muntaha/: HTTPSConnectionPool(host='digestlibrary.com', port=443): Max retries exceeded with url: /2021/07/05/dupehri-ke-geet-by-sidratul-muntaha/ (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7d58645d3150>, 'Connection to digestlibrary.com timed out. (connect timeout=60)'))
# ⚠ Attempt 4 failed for https://digestlibrary.com/2025/03/02/ma-ul-malook-epi_18-by-nighat-seema/: HTTPSConnectionPool(host='digestlibrary.com', port=443): Max retries exceeded with url: /2025/03/02/ma-ul-malook-epi_18-by-nighat-seema/ (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7d5866091c10>, 'Connection to digestlibrary.com timed out. (connect timeout=60)'))
# ⚠ Attempt 5 failed for https://digestlibrary.com/2022/03/09/rang-raiz-mere-complete-by-iffat-sehar-tahir/: HTTPSConnectionPool(host='digestlibrary.com', port=443): Max retries exceeded with url: /2022/03/09/rang-raiz-mere-complete-by-iffat-sehar-tahir/ (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7d586414c8d0>, 'Connection to digestlibrary.com timed out. (connect timeout=60)'))
# ⚠ Attempt 3 failed for https://digestlibrary.com/2024/11/13/shua-digest-december-2007-complete-pdf/: HTTPSConnectionPool(host='digestlibrary.com', port=443): Max retries exceeded with url: /2024/11/13/shua-digest-december-2007-complete-pdf/ (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7d585adb5290>, 'Connection to digestlibrary.com timed out. (connect timeout=60)'))
# ⚠ Attempt 1 failed for https://digestlibrary.com/2021/02/28/chand-ghagan-or-chandni-by-iqra-sagheer-ahmad/: HTTPSConnectionPool(host='digestlibrary.com', port=443): Max retries exceeded with url: /2021/02/28/chand-ghagan-or-chandni-by-iqra-sagheer-ahmad/ (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7d585472de90>, 'Connection to digestlibrary.com timed out. (connect timeout=60)'))
# ⚠ Attempt 1 failed for https://digestlibrary.com/2022/06/01/mohabbat-aisa-naghma-hai-complete-by-iqra-sagheer-ahmad/: HTTPSConnectionPool(host='digestlibrary.com', port=443): Max retries exceeded with url: /2022/06/01/mohabbat-aisa-naghma-hai-complete-by-iqra-sagheer-ahmad/ (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7d5854c53a50>, 'Connection to digestlibrary.com timed out. (connect timeout=60)'))
# ⚠ Attempt 5 failed for https://digestlibrary.com/2021/01/04/sans-sakin-thi-by-nimrah-ahmad/: HTTPSConnectionPool(host='digestlibrary.com', port=443): Max retries exceeded with url: /2021/01/04/sans-sakin-thi-by-nimrah-ahmad/ (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7d585afddf50>, 'Connection to digestlibrary.com timed out. (connect timeout=60)'))
# ⚠ Attempt 1 failed for https://digestlibrary.com/2024/11/13/mausam-badalne-se-by-asia-razzaqi/: HTTPSConnectionPool(host='digestlibrary.com', port=443): Max retries exceeded with url: /2024/11/13/mausam-badalne-se-by-asia-razzaqi/ (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7d585aee2b90>, 'Connection to digestlibrary.com timed out. (connect timeout=60)'))
# ⚠ Attempt 2 failed for https://digestlibrary.com/2024/11/13/shua-digest-november-2007-complete-pdf/: HTTPSConnectionPool(host='digestlibrary.com', port=443): Max retries exceeded with url: /2024/11/13/shua-digest-november-2007-complete-pdf/ (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7d58643e2ad0>, 'Connection to digestlibrary.com timed out. (connect timeout=60)'))
# ⚠ Attempt 5 failed for https://digestlibrary.com/2021/01/25/humnay-dil-ko-roka-tha-by-maryam-aziz/: HTTPSConnectionPool(host='digestlibrary.com', port=443): Max retries exceeded with url: /2021/01/25/humnay-dil-ko-roka-tha-by-maryam-aziz/ (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7d585472e2d0>, 'Connection to digestlibrary.com timed out. (connect timeout=60)'))
# ⚠ Attempt 5 failed for https://digestlibrary.com/2021/07/05/dupehri-ke-geet-by-sidratul-muntaha/: HTTPSConnectionPool(host='digestlibrary.com', port=443): Max retries exceeded with url: /2021/07/05/dupehri-ke-geet-by-sidratul-muntaha/ (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7d585a336090>, 'Connection to digestlibrary.com timed out. (connect timeout=60)'))
# ⚠ Attempt 5 failed for https://digestlibrary.com/2025/03/02/ma-ul-malook-epi_18-by-nighat-seema/: HTTPSConnectionPool(host='digestlibrary.com', port=443): Max retries exceeded with url: /2025/03/02/ma-ul-malook-epi_18-by-nighat-seema/ (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7d58662bfb90>, 'Connection to digestlibrary.com timed out. (connect timeout=60)'))
# ⚠ Attempt 1 failed for https://digestlibrary.com/2024/11/13/kiran-digest-january-2021-complete-pdf/: HTTPSConnectionPool(host='digestlibrary.com', port=443): Max retries exceeded with url: /2024/11/13/kiran-digest-january-2021-complete-pdf/ (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7d5854c81090>, 'Connection to digestlibrary.com timed out. (connect timeout=60)'))
# ⚠ Attempt 4 failed for https://digestlibrary.com/2024/11/13/shua-digest-december-2007-complete-pdf/: HTTPSConnectionPool(host='digestlibrary.com', port=443): Max retries exceeded with url: /2024/11/13/shua-digest-december-2007-complete-pdf/ (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7d585a34fc50>, 'Connection to digestlibrary.com timed out. (connect timeout=60)'))
# ⚠ Attempt 2 failed for https://digestlibrary.com/2021/02/28/chand-ghagan-or-chandni-by-iqra-sagheer-ahmad/: HTTPSConnectionPool(host='digestlibrary.com', port=443): Max retries exceeded with url: /2021/02/28/chand-ghagan-or-chandni-by-iqra-sagheer-ahmad/ (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7d58643ee290>, 'Connection to digestlibrary.com timed out. (connect timeout=60)'))
# ⚠ Attempt 2 failed for https://digestlibrary.com/2022/06/01/mohabbat-aisa-naghma-hai-complete-by-iqra-sagheer-ahmad/: HTTPSConnectionPool(host='digestlibrary.com', port=443): Max retries exceeded with url: /2022/06/01/mohabbat-aisa-naghma-hai-complete-by-iqra-sagheer-ahmad/ (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7d5854c6d850>, 'Connection to digestlibrary.com timed out. (connect timeout=60)'))
# ⚠ Attempt 1 failed for https://digestlibrary.com/2024/11/13/soorma-by-nazeer-fatima/: HTTPSConnectionPool(host='digestlibrary.com', port=443): Max retries exceeded with url: /2024/11/13/soorma-by-nazeer-fatima/ (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7d585a9cc910>, 'Connection to digestlibrary.com timed out. (connect timeout=60)'))
# ⚠ Attempt 2 failed for https://digestlibrary.com/2024/11/13/mausam-badalne-se-by-asia-razzaqi/: HTTPSConnectionPool(host='digestlibrary.com', port=443): Max retries exceeded with url: /2024/11/13/mausam-badalne-se-by-asia-razzaqi/ (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7d585a511910>, 'Connection to digestlibrary.com timed out. (connect timeout=60)'))
# ⚠ Attempt 3 failed for https://digestlibrary.com/2024/11/13/shua-digest-november-2007-complete-pdf/: HTTPSConnectionPool(host='digestlibrary.com', port=443): Max retries exceeded with url: /2024/11/13/shua-digest-november-2007-complete-pdf/ (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7d586609d390>, 'Connection to digestlibrary.com timed out. (connect timeout=60)'))
# ⚠ Attempt 1 failed for https://digestlibrary.com/2021/02/26/zeesat-ki-sham-se-pehlay-by-iqra-sagheer-ahmad/: HTTPSConnectionPool(host='digestlibrary.com', port=443): Max retries exceeded with url: /2021/02/26/zeesat-ki-sham-se-pehlay-by-iqra-sagheer-ahmad/ (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7d58547854d0>, 'Connection to digestlibrary.com timed out. (connect timeout=60)'))
# ⚠ Attempt 1 failed for https://digestlibrary.com/2021/02/14/zidagi-khak-na-thi-by-umme-mariam/: HTTPSConnectionPool(host='digestlibrary.com', port=443): Max retries exceeded with url: /2021/02/14/zidagi-khak-na-thi-by-umme-mariam/ (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7d585aeb7790>, 'Connection to digestlibrary.com timed out. (connect timeout=60)'))
# ⚠ Attempt 1 failed for https://digestlibrary.com/2021/02/03/baharon-k-sang-sang-by-iqra-sagheer-ahmad/: HTTPSConnectionPool(host='digestlibrary.com', port=443): Max retries exceeded with url: /2021/02/03/baharon-k-sang-sang-by-iqra-sagheer-ahmad/ (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7d586609c1d0>, 'Connection to digestlibrary.com timed out. (connect timeout=60)'))
# ⚠ Attempt 2 failed for https://digestlibrary.com/2024/11/13/kiran-digest-january-2021-complete-pdf/: HTTPSConnectionPool(host='digestlibrary.com', port=443): Max retries exceeded with url: /2024/11/13/kiran-digest-january-2021-complete-pdf/ (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7d585a4c5e10>, 'Connection to digestlibrary.com timed out. (connect timeout=60)'))
# ⚠ Attempt 5 failed for https://digestlibrary.com/2024/11/13/shua-digest-december-2007-complete-pdf/: HTTPSConnectionPool(host='digestlibrary.com', port=443): Max retries exceeded with url: /2024/11/13/shua-digest-december-2007-complete-pdf/ (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7d586603fc90>, 'Connection to digestlibrary.com timed out. (connect timeout=60)'))

# %% [markdown]
# # New Section

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import time
import xml.etree.ElementTree as ET
import os
import concurrent.futures
import random
from datetime import datetime
from threading import Lock
import re
from functools import lru_cache  # For caching redirects
import logging  # For efficient logging

# 🚀 Google Drive Mount (Optional)
try:
    from google.colab import drive
    drive.mount('/content/drive')
    SAVE_PATH_XLSX = "/content/drive/My Drive/Blogger_Novels.xlsx"
    FAILED_LINKS_FILE = "/content/drive/My Drive/failed_links.txt"
    PROGRESS_FILE = "/content/drive/My Drive/progress.txt"
    LOG_FILE = "/content/drive/My Drive/scrape_log.txt"
except ImportError:
    SAVE_PATH_XLSX = "Blogger_Novels.xlsx"
    FAILED_LINKS_FILE = "failed_links.txt"
    PROGRESS_FILE = "progress.txt"
    LOG_FILE = "scrape_log.txt"

# 📌 Setup Logging
logging.basicConfig(
    filename=LOG_FILE,
    level=logging.INFO,
    format="%(asctime)s: %(message)s",
    filemode="a"
)
logger = logging.getLogger()

# 📌 Headers & Session
HEADERS = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/121.0.0.0 Safari/537.36",
    "Accept": "text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,*/*;q=0.8",
    "Accept-Language": "en-US,en;q=0.5",
    "Connection": "keep-alive"
}
session = requests.Session()
session.headers.update(HEADERS)

# 🔄 Progress Lock
progress_lock = Lock()

# 📥 Step 1: Extract all post URLs from sitemap
SITEMAP_URL = "https://digestlibrary.com/post-sitemap7.xml"
try:
    response = session.get(SITEMAP_URL, timeout=30)
    if response.status_code == 200:
        root = ET.fromstring(response.content)
        post_urls = [elem.text for elem in root.findall(".//{http://www.sitemaps.org/schemas/sitemap/0.9}loc")]
        print(f"✅ Found {len(post_urls)} posts to scrape.")
    else:
        print(f"❌ Failed to fetch sitemap: HTTP {response.status_code}")
        exit()
except ET.ParseError:
    print("❌ Failed to parse sitemap XML.")
    exit()
except requests.exceptions.RequestException as e:
    print(f"❌ Sitemap request failed: {e}")
    exit()

# 🔄 Resume Last Progress
last_index = 0
if os.path.exists(PROGRESS_FILE):
    try:
        with open(PROGRESS_FILE, "r") as f:
            last_index = int(f.read().strip())
    except (ValueError, IOError):
        print("⚠ Could not read progress file. Starting from index 0.")

# ⏳ Function to estimate remaining time
def estimate_time(start_time, processed, total):
    elapsed_time = time.time() - start_time
    avg_time_per_post = elapsed_time / processed if processed > 0 else 0
    remaining_posts = total - processed
    estimated_remaining_time = remaining_posts * avg_time_per_post
    return time.strftime('%H:%M:%S', time.gmtime(estimated_remaining_time))

# 🔍 Cache redirect resolutions
@lru_cache(maxsize=1000)
def resolve_redirect(url):
    try:
        response = session.head(url, allow_redirects=True, timeout=5)  # Faster timeout
        return response.url
    except requests.exceptions.RequestException:
        return url

# 🔍 Step 2: Scrape Each Novel Post with Auto-Retry
def scrape_post(post_url):
    retries = 3  # Reduced retries for speed
    for attempt in range(retries):
        try:
            response = session.get(post_url, timeout=30)  # Reduced timeout
            if response.status_code == 429:
                print(f"⚠ Rate limit hit for {post_url}. Waiting...")
                time.sleep(2 ** attempt * 5)  # Reduced backoff
                continue
            if response.status_code in (404, 410):  # Skip non-recoverable errors
                logger.info(f"Skipped {post_url}: HTTP {response.status_code}")
                return None
            if response.status_code != 200:
                print(f"⚠ Retrying ({attempt+1}/{retries}) for {post_url}: HTTP {response.status_code}")
                time.sleep(3)
                continue

            # Use lxml parser for speed
            soup = BeautifulSoup(response.text, "lxml")

            # Extract Title
            title_selectors = [
                "h1.entry-title",
                "h2.entry-title",
                "h1.post-title",
                "h2.post-title",
                "h3.entry-title",
                "h3.post-title",
                "div.post-title",
                "div.entry-title",
                "h1",
                "h2",
                "h3"
            ]
            title = None
            title_element = None
            for selector in title_selectors:
                title_elem = soup.select_one(selector)
                if title_elem:
                    title = title_elem.text.strip()
                    title_element = title_elem
                    print(f"📌 Found title with selector '{selector}': '{title}' for URL: {post_url}")
                    break

            if not title or "digest library" in title.lower():
                headers = soup.find_all(["h1", "h2", "h3"], limit=5)  # Limit search
                for header in headers:
                    text = header.text.strip()
                    if "digest library" not in text.lower() and len(text) > 10 and not text.lower().startswith("home"):
                        title = text
                        title_element = header
                        print(f"📌 Fallback title found: '{title}' for URL: {post_url}")
                        break

            if not title or "digest library" in title.lower():
                title_tag = soup.find("title")
                if title_tag:
                    title = title_tag.text.strip()
                    if "digest library" in title.lower():
                        title = title.replace("Digest Library", "").replace("|", "").strip()
                    print(f"📌 Title from <title> tag: '{title}' for URL: {post_url}")

            title = title if title and "digest library" in title.lower() else "No Title Found"
            print(f"📌 Final title: '{title}' for URL: {post_url}")

            # Extract Download Links
            # Focus on post content
            content = soup.select_one("div.post-body, div.entry-content, div.post-content, article, div.post")
            if not content:
                content = soup

            # Get <a> tags (limit to 50 to avoid navigation links)
            all_links = [a["href"] for a in content.find_all("a", href=True, limit=50)]
            # Get <button> links
            button_links = [button.get("onclick", "").strip("'").replace("window.location.href=", "")
                           for button in content.find_all("button") if button.get("onclick")]
            # Resolve redirects
            all_links = [resolve_redirect(link) for link in all_links + button_links if link]

            # Filter download links
            download_domains = ["drive.google", "mediafire", "dropbox", "mega.nz"]
            google_drive_links = [link for link in all_links if "drive.google" in link]
            mediafire_links = [link for link in all_links if "mediafire" in link]
            other_links = [link for link in all_links if any(domain in link for domain in ["dropbox", "mega.nz"])]

            # Search content text only if no links found
            if not (google_drive_links or mediafire_links or other_links):
                text = content.get_text(separator=" ", strip=True)
                url_pattern = r'https?://[^\s<>"]{10,500}'  # Optimized regex
                raw_urls = re.findall(url_pattern, text, re.IGNORECASE)
                raw_urls = [url for url in raw_urls if any(domain in url.lower() for domain in download_domains)]
                google_drive_links.extend([url for url in raw_urls if "drive.google" in url and url not in google_drive_links])
                mediafire_links.extend([url for url in raw_urls if "mediafire" in url and url not in mediafire_links])
                other_links.extend([url for url in raw_urls if any(domain in url for domain in ["dropbox", "mega.nz"]) and url not in other_links])

            # Log efficiently
            log_entry = (
                f"URL: {post_url}, Title: {title}\n"
                f"  Google Drive Links: {google_drive_links}\n"
                f"  Mediafire Links: {mediafire_links}\n"
                f"  Other Links: {other_links}\n"
            )
            logger.info(log_entry)

            return {
                "Title": title,
                "Google Drive Links": ", ".join(google_drive_links) if google_drive_links else "No Google Drive Link",
                "Mediafire Links": ", ".join(mediafire_links) if mediafire_links else "No Mediafire Link",
                "Other Links": ", ".join(other_links) if other_links else "No Other Links"
            }
        except requests.exceptions.RequestException as e:
            print(f"⚠ Attempt {attempt+1} failed for {post_url}: {e}")
            time.sleep(3)

    # ❌ Save failed link
    with open(FAILED_LINKS_FILE, "a") as f:
        f.write(post_url + "\n")
    return None

# 📌 Step 3: Scrape Each Post & Save Data in Batches
novels_data = []
BATCH_SIZE = 500  # Increased for fewer writes
start_time = time.time()

with concurrent.futures.ThreadPoolExecutor(max_workers=10) as executor:  # Increased workers
    future_to_url = {executor.submit(scrape_post, post_url): idx for idx, post_url in enumerate(post_urls[last_index:], last_index)}

    for count, future in enumerate(concurrent.futures.as_completed(future_to_url), start=1):
        idx = future_to_url[future]
        result = future.result()
        if result:
            novels_data.append(result)

        # ✅ Save every batch
        if len(novels_data) >= BATCH_SIZE:
            df = pd.DataFrame(novels_data)
            try:
                if os.path.exists(SAVE_PATH_XLSX):
                    existing_df = pd.read_excel(SAVE_PATH_XLSX, engine='openpyxl')
                    df = pd.concat([existing_df, df], ignore_index=True)
                df.to_excel(SAVE_PATH_XLSX, index=False, engine='openpyxl')
                novels_data = []
                with progress_lock:
                    with open(PROGRESS_FILE, "w") as f:
                        f.write(str(idx))
            except (PermissionError, IOError) as e:
                print(f"❌ Cannot write to {SAVE_PATH_XLSX}: {e}")
                exit()

        # ⏳ Show progress
        if count % 50 == 0:
            remaining_time = estimate_time(start_time, count, len(post_urls) - last_index)
            print(f"⏳ Processed {count}/{len(post_urls) - last_index} posts, Estimated time remaining: {remaining_time}")

# 📥 Step 4: Final Save
if novels_data:
    df = pd.DataFrame(novels_data)
    try:
        if os.path.exists(SAVE_PATH_XLSX):
            existing_df = pd.read_excel(SAVE_PATH_XLSX, engine='openpyxl')
            df = pd.concat([existing_df, df], ignore_index=True)
        df.to_excel(SAVE_PATH_XLSX, index=False, engine='openpyxl')
    except (PermissionError, IOError) as e:
        print(f"❌ Cannot write to {SAVE_PATH_XLSX}: {e}")
        exit()

# ✅ Delete progress file
if os.path.exists(PROGRESS_FILE):
    try:
        os.remove(PROGRESS_FILE)
    except OSError:
        print("⚠ Could not delete progress file.")

print(f"✅ Scraping complete! Data saved in '{SAVE_PATH_XLSX}'")
# Out:
# 📌 Found title with selector 'h1': 'Digest Library' for URL: https://digestlibrary.com/2024/10/12/jasoosi-digest-october-2024-complete-pdf/
# 📌 Fallback title found: 'Jasoosi digest October 2024 complete pdf' for URL: https://digestlibrary.com/2024/10/12/jasoosi-digest-october-2024-complete-pdf/
# 📌 Final title: 'No Title Found' for URL: https://digestlibrary.com/2024/10/12/jasoosi-digest-october-2024-complete-pdf/
# ⚠ Attempt 1 failed for https://digestlibrary.com/2025/03/03/shafa-epi_2-nd-last-by-eesha-hussain/: HTTPSConnectionPool(host='digestlibrary.com', port=443): Max retries exceeded with url: /2025/03/03/shafa-epi_2-nd-last-by-eesha-hussain/ (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7dd54c2ff3d0>, 'Connection to digestlibrary.com timed out. (connect timeout=30)'))
# ⚠ Attempt 1 failed for https://digestlibrary.com/2025/03/04/shafa-epi-_1-by-eesha-hussain/: HTTPSConnectionPool(host='digestlibrary.com', port=443): Max retries exceeded with url: /2025/03/04/shafa-epi-_1-by-eesha-hussain/ (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7dd54c30e410>, 'Connection to digestlibrary.com timed out. (connect timeout=30)'))
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# 📌 Found title with selector 'h1': 'Digest Library' for URL: https://digestlibrary.com/2021/02/20/tawaaf-e-ishq-by-sumaira-hameed/
# 📌 Fallback title found: 'Tawaaf e ishq by Sumaira Hameed' for URL: https://digestlibrary.com/2021/02/20/tawaaf-e-ishq-by-sumaira-hameed/
# 📌 Final title: 'No Title Found' for URL: https://digestlibrary.com/2021/02/20/tawaaf-e-ishq-by-sumaira-hameed/
# ⚠ Attempt 1 failed for https://digestlibrary.com/2025/03/04/shafa-complete-by-eesha-hussain/: HTTPSConnectionPool(host='digestlibrary.com', port=443): Max retries exceeded with url: /2025/03/04/shafa-complete-by-eesha-hussain/ (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7dd54c30ff90>, 'Connection to digestlibrary.com timed out. (connect timeout=30)'))
# 📌 Found title with selector 'h1': 'Digest Library' for URL: https://digestlibrary.com/2024/10/16/suspense-digest-october-2024-complete-pdf/
# 📌 Fallback title found: 'Suspense digest October 2024 complete pdf' for URL: https://digestlibrary.com/2024/10/16/suspense-digest-october-2024-complete-pdf/
# 📌 Final title: 'No Title Found' for URL: https://digestlibrary.com/2024/10/16/suspense-digest-october-2024-complete-pdf/
# ⚠ Attempt 1 failed for https://digestlibrary.com/2025/03/04/mohabbat-mautbar-thehri-by-rashida-riffat/: HTTPSConnectionPool(host='digestlibrary.com', port=443): Max retries exceeded with url: /2025/03/04/mohabbat-mautbar-thehri-by-rashida-riffat/ (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7dd53fd27fd0>, 'Connection to digestlibrary.com timed out. (connect timeout=30)'))
# ✅ Found 1000 posts to scrape.
# 📌 Found title with selector 'h1': 'Digest Library' for URL: https://digestlibrary.com/2025/02/26/khoobsurat-khuwab-by-asia-razzaqi/
# 📌 Fallback title found: 'Khoobsurat khuwab by Asia Razzaqi' for URL: https://digestlibrary.com/2025/02/26/khoobsurat-khuwab-by-asia-razzaqi/
# 📌 Final title: 'No Title Found' for URL: https://digestlibrary.com/2025/02/26/khoobsurat-khuwab-by-asia-razzaqi/
# 📌 Found title with selector 'h1': 'Digest Library' for URL: https://digestlibrary.com/2025/03/03/shafa-epi_2-nd-last-by-eesha-hussain/
# 📌 Fallback title found: 'Shafa epi_2 nd last by Eesha Hussain' for URL: https://digestlibrary.com/2025/03/03/shafa-epi_2-nd-last-by-eesha-hussain/
# 📌 Final title: 'No Title Found' for URL: https://digestlibrary.com/2025/03/03/shafa-epi_2-nd-last-by-eesha-hussain/
# 📌 Found title with selector 'h1': 'Digest Library' for URL: https://digestlibrary.com/2021/08/07/aayeno-ke-dais-mai-by-samra-bukhari/
# 📌 Fallback title found: 'Aayeno ke dais mai by Samra Bukhari' for URL: https://digestlibrary.com/2021/08/07/aayeno-ke-dais-mai-by-samra-bukhari/
# 📌 Final title: 'No Title Found' for URL: https://digestlibrary.com/2021/08/07/aayeno-ke-dais-mai-by-samra-bukhari/
# 📌 Found title with selector 'h1': 'Digest Library' for URL: https://digestlibrary.com/2022/03/12/shua-digest-december-complete-2020/
# 📌 Fallback title found: 'Shua digest December complete 2020' for URL: https://digestlibrary.com/2022/03/12/shua-digest-december-complete-2020/
# 📌 Final title: 'No Title Found' for URL: https://digestlibrary.com/2022/03/12/shua-digest-december-complete-2020/
# 📌 Found title with selector 'h1': 'Digest Library' for URL: https://digestlibrary.com/2025/02/26/reet-piyar-aur-hum-by-sidra-hayat/
# 📌 Fallback title found: 'Reet piyar aur hum by Sidra Hayat' for URL: https://digestlibrary.com/2025/02/26/reet-piyar-aur-hum-by-sidra-hayat/
# 📌 Final title: 'No Title Found' for URL: https://digestlibrary.com/2025/02/26/reet-piyar-aur-hum-by-sidra-hayat/
# ⚠ Attempt 1 failed for https://digestlibrary.com/2021/06/09/tere-sang-haseen-hai-rehguzar-by-shehzadi-abbas/: HTTPSConnectionPool(host='digestlibrary.com', port=443): Max retries exceeded with url: /2021/06/09/tere-sang-haseen-hai-rehguzar-by-shehzadi-abbas/ (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7dd53fe37f10>, 'Connection to digestlibrary.com timed out. (connect timeout=30)'))
# 📌 Found title with selector 'h1': 'Digest Library' for URL: https://digestlibrary.com/2021/01/14/zindagi-kitni-khubsoorat-hai-by-maryam-aziz/
# 📌 Fallback title found: 'Zindagi kitni khubsoorat hai by Maryam Aziz' for URL: https://digestlibrary.com/2021/01/14/zindagi-kitni-khubsoorat-hai-by-maryam-aziz/
# 📌 Final title: 'No Title Found' for URL: https://digestlibrary.com/2021/01/14/zindagi-kitni-khubsoorat-hai-by-maryam-aziz/
# 📌 Found title with selector 'h1': 'Digest Library' for URL: https://digestlibrary.com/2022/06/21/shua-digest-april-2003-complete-pdf/
# 📌 Fallback title found: 'Shua digest April 2003 complete pdf' for URL: https://digestlibrary.com/2022/06/21/shua-digest-april-2003-complete-pdf/
# 📌 Final title: 'No Title Found' for URL: https://digestlibrary.com/2022/06/21/shua-digest-april-2003-complete-pdf/
# 📌 Found title with selector 'h1': 'Digest Library' for URL: https://digestlibrary.com/2024/09/13/suspense-digest-september-2024-complete-pdf/
# 📌 Fallback title found: 'Suspense digest September 2024 complete pdf' for URL: https://digestlibrary.com/2024/09/13/suspense-digest-september-2024-complete-pdf/
# 📌 Final title: 'No Title Found' for URL: https://digestlibrary.com/2024/09/13/suspense-digest-september-2024-complete-pdf/
# ⚠ Attempt 1 failed for https://digestlibrary.com/2025/03/04/shua-digest-august-2021-complete-pdf/: HTTPSConnectionPool(host='digestlibrary.com', port=443): Max retries exceeded with url: /2025/03/04/shua-digest-august-2021-complete-pdf/ (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7dd544480490>, 'Connection to digestlibrary.com timed out. (connect timeout=30)'))
# ⚠ Attempt 1 failed for https://digestlibrary.com/2025/03/04/sajan-tujh-sang-eid-meri-by-nazia-kanwal-nazi/: HTTPSConnectionPool(host='digestlibrary.com', port=443): Max retries exceeded with url: /2025/03/04/sajan-tujh-sang-eid-meri-by-nazia-kanwal-nazi/ (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7dd54c2ff7d0>, 'Connection to digestlibrary.com timed out. (connect timeout=30)'))
# 📌 Found title with selector 'h1': 'Digest Library' for URL: https://digestlibrary.com/2023/08/26/shua-digest-january-2003-complete-pdf/
# 📌 Fallback title found: 'Shua digest January 2003 complete pdf' for URL: https://digestlibrary.com/2023/08/26/shua-digest-january-2003-complete-pdf/
# 📌 Final title: 'No Title Found' for URL: https://digestlibrary.com/2023/08/26/shua-digest-january-2003-complete-pdf/
# 📌 Found title with selector 'h1': 'Digest Library' for URL: https://digestlibrary.com/2025/03/04/mohabbat-mautbar-thehri-by-rashida-riffat/
# 📌 Fallback title found: 'Mohabbat mautbar thehri by Rashida Riffat' for URL: https://digestlibrary.com/2025/03/04/mohabbat-mautbar-thehri-by-rashida-riffat/
# 📌 Final title: 'No Title Found' for URL: https://digestlibrary.com/2025/03/04/mohabbat-mautbar-thehri-by-rashida-riffat/
# ⚠ Attempt 1 failed for https://digestlibrary.com/2025/03/04/shanakhat-by-mahwish-talib/: HTTPSConnectionPool(host='digestlibrary.com', port=443): Max retries exceeded with url: /2025/03/04/shanakhat-by-mahwish-talib/ (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7dd54c223950>, 'Connection to digestlibrary.com timed out. (connect timeout=30)'))
# 📌 Found title with selector 'h1': 'Digest Library' for URL: https://digestlibrary.com/2024/08/28/suspense-digest-august-2024-complete-pdf/
# 📌 Fallback title found: 'Suspense digest August 2024 complete pdf' for URL: https://digestlibrary.com/2024/08/28/suspense-digest-august-2024-complete-pdf/
# 📌 Final title: 'No Title Found' for URL: https://digestlibrary.com/2024/08/28/suspense-digest-august-2024-complete-pdf/
# 📌 Found title with selector 'h1': 'Digest Library' for URL: https://digestlibrary.com/2025/02/27/hadsa-by-qurratulain-khuram-hashmi/
# 📌 Fallback title found: 'Hadsa by Quratulain Khuram Hashmi' for URL: https://digestlibrary.com/2025/02/27/hadsa-by-qurratulain-khuram-hashmi/
# 📌 Final title: 'No Title Found' for URL: https://digestlibrary.com/2025/02/27/hadsa-by-qurratulain-khuram-hashmi/
# 📌 Found title with selector 'h1': 'Digest Library' for URL: https://digestlibrary.com/2025/03/04/jasoosi-digest-july-2024-complete-pdf/
# 📌 Fallback title found: 'Jasoosi digest July 2024 complete pdf' for URL: https://digestlibrary.com/2025/03/04/jasoosi-digest-july-2024-complete-pdf/
# 📌 Final title: 'No Title Found' for URL: https://digestlibrary.com/2025/03/04/jasoosi-digest-july-2024-complete-pdf/
# 📌 Found title with selector 'h1': 'Digest Library' for URL: https://digestlibrary.com/2025/01/03/dhoop-dareech-epi_2-by-maryam-aziz/
# 📌 Fallback title found: 'Dhoop dareecha epi_2 by Maryam Aziz' for URL: https://digestlibrary.com/2025/01/03/dhoop-dareech-epi_2-by-maryam-aziz/
# 📌 Final title: 'No Title Found' for URL: https://digestlibrary.com/2025/01/03/dhoop-dareech-epi_2-by-maryam-aziz/
# 📌 Found title with selector 'h1': 'Digest Library' for URL: https://digestlibrary.com/2025/03/05/qasoor-uska-nahi-mera-hai-by-farzana-mughal/
# 📌 Fallback title found: 'Qasoor uska nahi mera hai by Farzana Mughal' for URL: https://digestlibrary.com/2025/03/05/qasoor-uska-nahi-mera-hai-by-farzana-mughal/
# 📌 Final title: 'No Title Found' for URL: https://digestlibrary.com/2025/03/05/qasoor-uska-nahi-mera-hai-by-farzana-mughal/
# 📌 Found title with selector 'h1': 'Digest Library' for URL: https://digestlibrary.com/2025/02/28/tu-hi-tha-muqadar-by-zar-jabeen/
# 📌 Fallback title found: 'Tu hi tha muqadar by Zar Jabeen' for URL: https://digestlibrary.com/2025/02/28/tu-hi-tha-muqadar-by-zar-jabeen/
# 📌 Final title: 'No Title Found' for URL: https://digestlibrary.com/2025/02/28/tu-hi-tha-muqadar-by-zar-jabeen/
# 📌 Found title with selector 'h1': 'Digest Library' for URL: https://digestlibrary.com/2021/01/19/hisar-e-mohabbat-complete-by-faiza-iftikhar/
# 📌 Fallback title found: 'Hisar e mohabbat complete by Faiza Iftikhar' for URL: https://digestlibrary.com/2021/01/19/hisar-e-mohabbat-complete-by-faiza-iftikhar/
# 📌 Final title: 'No Title Found' for URL: https://digestlibrary.com/2021/01/19/hisar-e-mohabbat-complete-by-faiza-iftikhar/
# 📌 Found title with selector 'h1': 'Digest Library' for URL: https://digestlibrary.com/2025/03/05/shua-digest-march-2025-complete-pdf/
# 📌 Fallback title found: 'Shua digest March 2025 complete pdf' for URL: https://digestlibrary.com/2025/03/05/shua-digest-march-2025-complete-pdf/
# 📌 Final title: 'No Title Found' for URL: https://digestlibrary.com/2025/03/05/shua-digest-march-2025-complete-pdf/
# 📌 Found title with selector 'h1': 'Digest Library' for URL: https://digestlibrary.com/2021/09/15/kese-kahun-apnay-jiya-ki-by-umme-maryam/
# 📌 Fallback title found: 'Kese kahun apnay jiya ki by Umme Maryam' for URL: https://digestlibrary.com/2021/09/15/kese-kahun-apnay-jiya-ki-by-umme-maryam/
# 📌 Final title: 'No Title Found' for URL: https://digestlibrary.com/2021/09/15/kese-kahun-apnay-jiya-ki-by-umme-maryam/
# 📌 Found title with selector 'h1': 'Digest Library' for URL: https://digestlibrary.com/2023/04/17/zindagi-phoolon-ki-eid-by-shazia-mustafa/
# 📌 Fallback title found: 'Zindagi phoolon ki Eid by Shazia Mustafa' for URL: https://digestlibrary.com/2023/04/17/zindagi-phoolon-ki-eid-by-shazia-mustafa/
# 📌 Final title: 'No Title Found' for URL: https://digestlibrary.com/2023/04/17/zindagi-phoolon-ki-eid-by-shazia-mustafa/
# 📌 Found title with selector 'h1': 'Digest Library' for URL: https://digestlibrary.com/2022/04/10/aagaye-hain-nikhar-ke-mausam-by-shazia-chaudhary/
# 📌 Fallback title found: 'Aagaye hain nikhar ke mausam by Shazia Chaudhary' for URL: https://digestlibrary.com/2022/04/10/aagaye-hain-nikhar-ke-mausam-by-shazia-chaudhary/
# 📌 Final title: 'No Title Found' for URL: https://digestlibrary.com/2022/04/10/aagaye-hain-nikhar-ke-mausam-by-shazia-chaudhary/
# 📌 Found title with selector 'h1': 'Digest Library' for URL: https://digestlibrary.com/2025/02/28/aik-rewayet-by-samra-bukhari/
# 📌 Fallback title found: 'Aik rewayet by Samra Bukhari' for URL: https://digestlibrary.com/2025/02/28/aik-rewayet-by-samra-bukhari/
# 📌 Final title: 'No Title Found' for URL: https://digestlibrary.com/2025/02/28/aik-rewayet-by-samra-bukhari/
# 📌 Found title with selector 'h1': 'Digest Library' for URL: https://digestlibrary.com/2021/01/07/koi-lamha-khuwab-nahi-hota-by-umera-ahmad/
# 📌 Fallback title found: 'Koi lamha khuwab nahi hota by Umera Ahmad' for URL: https://digestlibrary.com/2021/01/07/koi-lamha-khuwab-nahi-hota-by-umera-ahmad/
# 📌 Final title: 'No Title Found' for URL: https://digestlibrary.com/2021/01/07/koi-lamha-khuwab-nahi-hota-by-umera-ahmad/
# 📌 Found title with selector 'h1': 'Digest Library' for URL: https://digestlibrary.com/2021/11/01/chah-ke-dr-per-by-samra-bukhari/
# 📌 Fallback title found: 'Chah ke dr per by Samra Bukhari' for URL: https://digestlibrary.com/2021/11/01/chah-ke-dr-per-by-samra-bukhari/
# 📌 Final title: 'No Title Found' for URL: https://digestlibrary.com/2021/11/01/chah-ke-dr-per-by-samra-bukhari/
# 📌 Found title with selector 'h1': 'Digest Library' for URL: https://digestlibrary.com/2025/03/06/lo-hum-ne-haar-mani-by-nuzhat-jabeen/
# 📌 Fallback title found: 'Lo hum ne haar mani by Nuzhat Jabeen' for URL: https://digestlibrary.com/2025/03/06/lo-hum-ne-haar-mani-by-nuzhat-jabeen/
# 📌 Final title: 'No Title Found' for URL: https://digestlibrary.com/2025/03/06/lo-hum-ne-haar-mani-by-nuzhat-jabeen/
# 📌 Found title with selector 'h1': 'Digest Library' for URL: https://digestlibrary.com/2025/02/28/khwateen-digest-november-1996-complete-pdf/
# 📌 Fallback title found: 'Khwateen digest November 1996 complete pdf' for URL: https://digestlibrary.com/2025/02/28/khwateen-digest-november-1996-complete-pdf/
# 📌 Final title: 'No Title Found' for URL: https://digestlibrary.com/2025/02/28/khwateen-digest-november-1996-complete-pdf/
# 📌 Found title with selector 'h1': 'Digest Library' for URL: https://digestlibrary.com/2025/03/06/roshani-bhi-khushbu-bhi-by-asia-mirza/
# 📌 Fallback title found: 'Roshani bhi khushbu bhi by Asia Mirza' for URL: https://digestlibrary.com/2025/03/06/roshani-bhi-khushbu-bhi-by-asia-mirza/
# 📌 Final title: 'No Title Found' for URL: https://digestlibrary.com/2025/03/06/roshani-bhi-khushbu-bhi-by-asia-mirza/
# 📌 Found title with selector 'h1': 'Digest Library' for URL: https://digestlibrary.com/2025/02/28/aik-ujala-khuwabon-jesa-by-umme-maryam/
# 📌 Fallback title found: 'Aik ujala khuwabon jesa by Umme Maryam' for URL: https://digestlibrary.com/2025/02/28/aik-ujala-khuwabon-jesa-by-umme-maryam/
# 📌 Final title: 'No Title Found' for URL: https://digestlibrary.com/2025/02/28/aik-ujala-khuwabon-jesa-by-umme-maryam/
# 📌 Found title with selector 'h1': 'Digest Library' for URL: https://digestlibrary.com/2025/02/27/chalo-bant-len-hum-zindagi-by-tallat-nizami/
# 📌 Fallback title found: 'Chalo bant len hum Zindagi by Tallat Nizami' for URL: https://digestlibrary.com/2025/02/27/chalo-bant-len-hum-zindagi-by-tallat-nizami/
# 📌 Final title: 'No Title Found' for URL: https://digestlibrary.com/2025/02/27/chalo-bant-len-hum-zindagi-by-tallat-nizami/
# 📌 Found title with selector 'h1': 'Digest Library' for URL: https://digestlibrary.com/2025/02/27/tum-udas-mat-hua-karo-by-sadia-aziz-afridi/
# 📌 Fallback title found: 'Tum udas mat hua karo by Sadia Aziz Afridi' for URL: https://digestlibrary.com/2025/02/27/tum-udas-mat-hua-karo-by-sadia-aziz-afridi/
# 📌 Final title: 'No Title Found' for URL: https://digestlibrary.com/2025/02/27/tum-udas-mat-hua-karo-by-sadia-aziz-afridi/
# 📌 Found title with selector 'h1': 'Digest Library' for URL: https://digestlibrary.com/2021/09/08/talash-e-zaat-ka-safar-by-jabeen-cheema/
# 📌 Fallback title found: 'Talash e zaat ka safar by Jabeen Cheema' for URL: https://digestlibrary.com/2021/09/08/talash-e-zaat-ka-safar-by-jabeen-cheema/
# 📌 Final title: 'No Title Found' for URL: https://digestlibrary.com/2021/09/08/talash-e-zaat-ka-safar-by-jabeen-cheema/
# 📌 Found title with selector 'h1': 'Digest Library' for URL: https://digestlibrary.com/2025/02/27/be-wafa-se-wafa-by-zumar-naeem-ajar/
# 📌 Fallback title found: 'Be wafa se wafa by Zumar Naeem Ajar' for URL: https://digestlibrary.com/2025/02/27/be-wafa-se-wafa-by-zumar-naeem-ajar/
# 📌 Final title: 'No Title Found' for URL: https://digestlibrary.com/2025/02/27/be-wafa-se-wafa-by-zumar-naeem-ajar/
# 📌 Found title with selector 'h1': 'Digest Library' for URL: https://digestlibrary.com/2021/01/19/kuch-rang-naye-hain-by-shazia-chaudhary/
# 📌 Fallback title found: 'Kuch rang naye hain by Shazia Chaudhary' for URL: https://digestlibrary.com/2021/01/19/kuch-rang-naye-hain-by-shazia-chaudhary/
# 📌 Final title: 'No Title Found' for URL: https://digestlibrary.com/2021/01/19/kuch-rang-naye-hain-by-shazia-chaudhary/
# 📌 Found title with selector 'h1': 'Digest Library' for URL: https://digestlibrary.com/2025/02/28/khuwabon-ne-raste-badal-leye-by-shama-jabeen/
# 📌 Fallback title found: 'Khuwabon ne raste badal leye by Shama Jabeen' for URL: https://digestlibrary.com/2025/02/28/khuwabon-ne-raste-badal-leye-by-shama-jabeen/
# 📌 Final title: 'No Title Found' for URL: https://digestlibrary.com/2025/02/28/khuwabon-ne-raste-badal-leye-by-shama-jabeen/
# 📌 Found title with selector 'h1': 'Digest Library' for URL: https://digestlibrary.com/2025/02/28/mere-gumshuda-2-by-umme-maryam/
# 📌 Fallback title found: 'Mere gumshuda (2) by Umme Maryam' for URL: https://digestlibrary.com/2025/02/28/mere-gumshuda-2-by-umme-maryam/
# 📌 Final title: 'No Title Found' for URL: https://digestlibrary.com/2025/02/28/mere-gumshuda-2-by-umme-maryam/
# 📌 Found title with selector 'h1': 'Digest Library' for URL: https://digestlibrary.com/2021/01/15/happy-new-year-by-nabila-abar-raja/
# 📌 Fallback title found: 'Happy new year by Nabila Abar Raja' for URL: https://digestlibrary.com/2021/01/15/happy-new-year-by-nabila-abar-raja/
# 📌 Final title: 'No Title Found' for URL: https://digestlibrary.com/2021/01/15/happy-new-year-by-nabila-abar-raja/
# 📌 Found title with selector 'h1': 'Digest Library' for URL: https://digestlibrary.com/2021/02/08/chand-mere-angan-ka-by-iffat-sehar-tahir/
# 📌 Fallback title found: 'Chand mere angan ka by Iffat Sehar Tahir' for URL: https://digestlibrary.com/2021/02/08/chand-mere-angan-ka-by-iffat-sehar-tahir/
# 📌 Final title: 'No Title Found' for URL: https://digestlibrary.com/2021/02/08/chand-mere-angan-ka-by-iffat-sehar-tahir/
# ⚠ Attempt 1 failed for https://digestlibrary.com/2025/02/27/sunehra-jaal-by-sajida-baig/: HTTPSConnectionPool(host='digestlibrary.com', port=443): Max retries exceeded with url: /2025/02/27/sunehra-jaal-by-sajida-baig/ (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7dd53f6527d0>, 'Connection to digestlibrary.com timed out. (connect timeout=30)'))
# ⚠ Attempt 1 failed for https://digestlibrary.com/2021/03/18/mujhay-itbar-e-wafa-milay-by-nabila-abar-raja/: HTTPSConnectionPool(host='digestlibrary.com', port=443): Max retries exceeded with url: /2021/03/18/mujhay-itbar-e-wafa-milay-by-nabila-abar-raja/ (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7dd53f63cdd0>, 'Connection to digestlibrary.com timed out. (connect timeout=30)'))
# ⚠ Attempt 1 failed for https://digestlibrary.com/2020/12/27/woh-ik-lamha-e-mohabbat-by-sumaira-shareef-toor/: HTTPSConnectionPool(host='digestlibrary.com', port=443): Max retries exceeded with url: /2020/12/27/woh-ik-lamha-e-mohabbat-by-sumaira-shareef-toor/ (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7dd53f653e10>, 'Connection to digestlibrary.com timed out. (connect timeout=30)'))
# ⚠ Attempt 1 failed for https://digestlibrary.com/2021/07/05/khazan-rasida-pattay-by-abida-younas/: HTTPSConnectionPool(host='digestlibrary.com', port=443): Max retries exceeded with url: /2021/07/05/khazan-rasida-pattay-by-abida-younas/ (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7dd53f3869d0>, 'Connection to digestlibrary.com timed out. (connect timeout=30)'))
# ⚠ Attempt 2 failed for https://digestlibrary.com/2025/03/04/shafa-epi-_1-by-eesha-hussain/: HTTPSConnectionPool(host='digestlibrary.com', port=443): Max retries exceeded with url: /2025/03/04/shafa-epi-_1-by-eesha-hussain/ (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7dd54e523d90>, 'Connection to digestlibrary.com timed out. (connect timeout=30)'))
# ⚠ Attempt 2 failed for https://digestlibrary.com/2025/03/04/shafa-complete-by-eesha-hussain/: HTTPSConnectionPool(host='digestlibrary.com', port=443): Max retries exceeded with url: /2025/03/04/shafa-complete-by-eesha-hussain/ (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7dd54e5f93d0>, 'Connection to digestlibrary.com timed out. (connect timeout=30)'))
# 📌 Found title with selector 'h1': 'Digest Library' for URL: https://digestlibrary.com/2025/02/27/sunehra-jaal-by-sajida-baig/
# 📌 Fallback title found: 'Sunehra jaal by Sajida Baig' for URL: https://digestlibrary.com/2025/02/27/sunehra-jaal-by-sajida-baig/
# 📌 Final title: 'No Title Found' for URL: https://digestlibrary.com/2025/02/27/sunehra-jaal-by-sajida-baig/
# 📌 Found title with selector 'h1': 'Digest Library' for URL: https://digestlibrary.com/2020/12/27/woh-ik-lamha-e-mohabbat-by-sumaira-shareef-toor/
# 📌 Fallback title found: 'Woh ik Lamha e Mohabbat by Sumaira Shareef Toor' for URL: https://digestlibrary.com/2020/12/27/woh-ik-lamha-e-mohabbat-by-sumaira-shareef-toor/
# 📌 Final title: 'No Title Found' for URL: https://digestlibrary.com/2020/12/27/woh-ik-lamha-e-mohabbat-by-sumaira-shareef-toor/
# 📌 Found title with selector 'h1': 'Digest Library' for URL: https://digestlibrary.com/2021/07/05/khazan-rasida-pattay-by-abida-younas/
# 📌 Fallback title found: 'Khazan rasida pattay by Abida Younas' for URL: https://digestlibrary.com/2021/07/05/khazan-rasida-pattay-by-abida-younas/
# 📌 Final title: 'No Title Found' for URL: https://digestlibrary.com/2021/07/05/khazan-rasida-pattay-by-abida-younas/
# 📌 Found title with selector 'h1': 'Digest Library' for URL: https://digestlibrary.com/2025/03/04/shafa-epi-_1-by-eesha-hussain/
# 📌 Fallback title found: 'Shafa epi _1 by Eesha Hussain' for URL: https://digestlibrary.com/2025/03/04/shafa-epi-_1-by-eesha-hussain/
# 📌 Final title: 'No Title Found' for URL: https://digestlibrary.com/2025/03/04/shafa-epi-_1-by-eesha-hussain/
# ⚠ Attempt 2 failed for https://digestlibrary.com/2021/06/09/tere-sang-haseen-hai-rehguzar-by-shehzadi-abbas/: HTTPSConnectionPool(host='digestlibrary.com', port=443): Max retries exceeded with url: /2021/06/09/tere-sang-haseen-hai-rehguzar-by-shehzadi-abbas/ (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7dd53ff6f010>, 'Connection to digestlibrary.com timed out. (connect timeout=30)'))
# ⚠ Attempt 2 failed for https://digestlibrary.com/2025/03/04/shua-digest-august-2021-complete-pdf/: HTTPSConnectionPool(host='digestlibrary.com', port=443): Max retries exceeded with url: /2025/03/04/shua-digest-august-2021-complete-pdf/ (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7dd53ff6ed10>, 'Connection to digestlibrary.com timed out. (connect timeout=30)'))
# ⚠ Attempt 2 failed for https://digestlibrary.com/2025/03/04/sajan-tujh-sang-eid-meri-by-nazia-kanwal-nazi/: HTTPSConnectionPool(host='digestlibrary.com', port=443): Max retries exceeded with url: /2025/03/04/sajan-tujh-sang-eid-meri-by-nazia-kanwal-nazi/ (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7dd54c1f2e50>, 'Connection to digestlibrary.com timed out. (connect timeout=30)'))
# 📌 Found title with selector 'h1': 'Digest Library' for URL: https://digestlibrary.com/2021/03/18/mujhay-itbar-e-wafa-milay-by-nabila-abar-raja/
# 📌 Fallback title found: 'Mujhay itbar e wafa milay by Nabila Abar Raja' for URL: https://digestlibrary.com/2021/03/18/mujhay-itbar-e-wafa-milay-by-nabila-abar-raja/
# 📌 Final title: 'No Title Found' for URL: https://digestlibrary.com/2021/03/18/mujhay-itbar-e-wafa-milay-by-nabila-abar-raja/
# 📌 Found title with selector 'h1': 'Digest Library' for URL: https://digestlibrary.com/2023/12/14/shua-digest-may-1994-complete-pdf/
# 📌 Fallback title found: 'Shua digest May 1994 complete pdf' for URL: https://digestlibrary.com/2023/12/14/shua-digest-may-1994-complete-pdf/
# 📌 Final title: 'No Title Found' for URL: https://digestlibrary.com/2023/12/14/shua-digest-may-1994-complete-pdf/
# ⚠ Attempt 2 failed for https://digestlibrary.com/2025/03/04/shanakhat-by-mahwish-talib/: HTTPSConnectionPool(host='digestlibrary.com', port=443): Max retries exceeded with url: /2025/03/04/shanakhat-by-mahwish-talib/ (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7dd54455de10>, 'Connection to digestlibrary.com timed out. (connect timeout=30)'))
# 📌 Found title with selector 'h1': 'Digest Library' for URL: https://digestlibrary.com/2021/01/04/num-palkyen-moje-hawa-by-saba-ajaved/
# 📌 Fallback title found: 'Num palkyen moje hawa by Saba ajaved' for URL: https://digestlibrary.com/2021/01/04/num-palkyen-moje-hawa-by-saba-ajaved/
# 📌 Final title: 'No Title Found' for URL: https://digestlibrary.com/2021/01/04/num-palkyen-moje-hawa-by-saba-ajaved/
# 📌 Found title with selector 'h1': 'Digest Library' for URL: https://digestlibrary.com/2025/03/01/ishq-chand-chakor-jesa-by-bint-e-sehar/
# 📌 Fallback title found: 'Ishq chand chakor jesa by Bint e Sehar' for URL: https://digestlibrary.com/2025/03/01/ishq-chand-chakor-jesa-by-bint-e-sehar/
# 📌 Final title: 'No Title Found' for URL: https://digestlibrary.com/2025/03/01/ishq-chand-chakor-jesa-by-bint-e-sehar/
# ⚠ Attempt 3 failed for https://digestlibrary.com/2025/03/04/shafa-complete-by-eesha-hussain/: HTTPSConnectionPool(host='digestlibrary.com', port=443): Max retries exceeded with url: /2025/03/04/shafa-complete-by-eesha-hussain/ (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7dd544926590>, 'Connection to digestlibrary.com timed out. (connect timeout=30)'))
# 📌 Found title with selector 'h1': 'Digest Library' for URL: https://digestlibrary.com/2021/01/16/safal-ghar-by-bushra-syed/
# 📌 Fallback title found: 'Safal ghar by Bushra Syed' for URL: https://digestlibrary.com/2021/01/16/safal-ghar-by-bushra-syed/
# 📌 Final title: 'No Title Found' for URL: https://digestlibrary.com/2021/01/16/safal-ghar-by-bushra-syed/
# ⚠ Attempt 3 failed for https://digestlibrary.com/2021/06/09/tere-sang-haseen-hai-rehguzar-by-shehzadi-abbas/: HTTPSConnectionPool(host='digestlibrary.com', port=443): Max retries exceeded with url: /2021/06/09/tere-sang-haseen-hai-rehguzar-by-shehzadi-abbas/ (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7dd544a34910>, 'Connection to digestlibrary.com timed out. (connect timeout=30)'))
# ⚠ Attempt 3 failed for https://digestlibrary.com/2025/03/04/shua-digest-august-2021-complete-pdf/: HTTPSConnectionPool(host='digestlibrary.com', port=443): Max retries exceeded with url: /2025/03/04/shua-digest-august-2021-complete-pdf/ (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7dd544a358d0>, 'Connection to digestlibrary.com timed out. (connect timeout=30)'))
# ⚠ Attempt 3 failed for https://digestlibrary.com/2025/03/04/sajan-tujh-sang-eid-meri-by-nazia-kanwal-nazi/: HTTPSConnectionPool(host='digestlibrary.com', port=443): Max retries exceeded with url: /2025/03/04/sajan-tujh-sang-eid-meri-by-nazia-kanwal-nazi/ (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7dd544a35c50>, 'Connection to digestlibrary.com timed out. (connect timeout=30)'))
# ⚠ Attempt 1 failed for https://digestlibrary.com/2021/09/21/tumharay-leye-tmhari-wo-by-nighat-abdullah/: HTTPSConnectionPool(host='digestlibrary.com', port=443): Max retries exceeded with url: /2021/09/21/tumharay-leye-tmhari-wo-by-nighat-abdullah/ (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7dd53fc15750>, 'Connection to digestlibrary.com timed out. (connect timeout=30)'))
# ⚠ Attempt 1 failed for https://digestlibrary.com/2023/08/21/sitara-e-zeesat-by-misbah-awan/: HTTPSConnectionPool(host='digestlibrary.com', port=443): Max retries exceeded with url: /2023/08/21/sitara-e-zeesat-by-misbah-awan/ (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7dd544cf9c90>, 'Connection to digestlibrary.com timed out. (connect timeout=30)'))
# ⚠ Attempt 1 failed for https://digestlibrary.com/2025/03/01/man-ki-dehleez-per-by-nabiha-naqvi/: HTTPSConnectionPool(host='digestlibrary.com', port=443): Max retries exceeded with url: /2025/03/01/man-ki-dehleez-per-by-nabiha-naqvi/ (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7dd54e50e110>, 'Connection to digestlibrary.com timed out. (connect timeout=30)'))
# ⚠ Attempt 1 failed for https://digestlibrary.com/2021/06/17/dil-tainu-day-baithay-by-durr-e-suman/: HTTPSConnectionPool(host='digestlibrary.com', port=443): Max retries exceeded with url: /2021/06/17/dil-tainu-day-baithay-by-durr-e-suman/ (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7dd544a37710>, 'Connection to digestlibrary.com timed out. (connect timeout=30)'))
# 📌 Found title with selector 'h1': 'Digest Library' for URL: https://digestlibrary.com/2021/03/09/bin-roye-ansoo-by-farhat-ishtiaq/
# 📌 Fallback title found: 'Bin roye ansoo complete by Farhat Ishtiaq' for URL: https://digestlibrary.com/2021/03/09/bin-roye-ansoo-by-farhat-ishtiaq/
# 📌 Final title: 'No Title Found' for URL: https://digestlibrary.com/2021/03/09/bin-roye-ansoo-by-farhat-ishtiaq/
# ⚠ Attempt 1 failed for https://digestlibrary.com/2025/03/01/ik-umar-ki-riazat-by-nighat-seema/: HTTPSConnectionPool(host='digestlibrary.com', port=443): Max retries exceeded with url: /2025/03/01/ik-umar-ki-riazat-by-nighat-seema/ (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7dd544a21990>, 'Connection to digestlibrary.com timed out. (connect timeout=30)'))
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: digestlibrary.com. Connection pool size: 10
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: digestlibrary.com. Connection pool size: 10
# 📌 Found title with selector 'h1': 'Digest Library' for URL: https://digestlibrary.com/2022/04/06/shua-digest-january-2000-complete-pdf/
# 📌 Fallback title found: 'Shua digest January 2000 complete pdf' for URL: https://digestlibrary.com/2022/04/06/shua-digest-january-2000-complete-pdf/
# 📌 Final title: 'No Title Found' for URL: https://digestlibrary.com/2022/04/06/shua-digest-january-2000-complete-pdf/
# ⚠ Attempt 1 failed for https://digestlibrary.com/2025/03/06/mohabbat-khuwab-rang-epi_1-by-farhat-ansari/: HTTPSConnectionPool(host='digestlibrary.com', port=443): Max retries exceeded with url: /2025/03/06/mohabbat-khuwab-rang-epi_1-by-farhat-ansari/ (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7dd544a298d0>, 'Connection to digestlibrary.com timed out. (connect timeout=30)'))
# ⚠ Attempt 1 failed for https://digestlibrary.com/2025/03/01/hum-tum-aur-chand-by-humaira-shafi/: HTTPSConnectionPool(host='digestlibrary.com', port=443): Max retries exceeded with url: /2025/03/01/hum-tum-aur-chand-by-humaira-shafi/ (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7dd544925c90>, 'Connection to digestlibrary.com timed out. (connect timeout=30)'))
# ⚠ Attempt 1 failed for https://digestlibrary.com/2025/03/06/badban-khulne-se-pehle-by-nighat-abdullah/: HTTPSConnectionPool(host='digestlibrary.com', port=443): Max retries exceeded with url: /2025/03/06/badban-khulne-se-pehle-by-nighat-abdullah/ (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7dd53ffd5fd0>, 'Connection to digestlibrary.com timed out. (connect timeout=30)'))
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: digestlibrary.com. Connection pool size: 10
# ⚠ Attempt 1 failed for https://digestlibrary.com/2023/01/17/jeena-esi-ka-naam-hai-by-nuzhat-jabeen-zia/: HTTPSConnectionPool(host='digestlibrary.com', port=443): Max retries exceeded with url: /2023/01/17/jeena-esi-ka-naam-hai-by-nuzhat-jabeen-zia/ (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7dd544a20ad0>, 'Connection to digestlibrary.com timed out. (connect timeout=30)'))
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: digestlibrary.com. Connection pool size: 10
# ⚠ Attempt 3 failed for https://digestlibrary.com/2025/03/04/shanakhat-by-mahwish-talib/: HTTPSConnectionPool(host='digestlibrary.com', port=443): Max retries exceeded with url: /2025/03/04/shanakhat-by-mahwish-talib/ (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7dd5449a5c90>, 'Connection to digestlibrary.com timed out. (connect timeout=30)'))
# ⚠ Attempt 1 failed for https://digestlibrary.com/2023/02/02/kundan-by-nadia-fatima-rizvi/: HTTPSConnectionPool(host='digestlibrary.com', port=443): Max retries exceeded with url: /2023/02/02/kundan-by-nadia-fatima-rizvi/ (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7dd544109690>, 'Connection to digestlibrary.com timed out. (connect timeout=30)'))
# 📌 Found title with selector 'h1': 'Digest Library' for URL: https://digestlibrary.com/2025/03/07/shua-digest-september-2021-complete-pdf/
# 📌 Fallback title found: 'Shua digest September 2021 complete pdf' for URL: https://digestlibrary.com/2025/03/07/shua-digest-september-2021-complete-pdf/
# 📌 Final title: 'No Title Found' for URL: https://digestlibrary.com/2025/03/07/shua-digest-september-2021-complete-pdf/
# 📌 Found title with selector 'h1': 'Digest Library' for URL: https://digestlibrary.com/2021/09/21/tumharay-leye-tmhari-wo-by-nighat-abdullah/
# 📌 Fallback title found: 'Tumharay leye tmhari wo by Nighat Abdullah' for URL: https://digestlibrary.com/2021/09/21/tumharay-leye-tmhari-wo-by-nighat-abdullah/
# 📌 Final title: 'No Title Found' for URL: https://digestlibrary.com/2021/09/21/tumharay-leye-tmhari-wo-by-nighat-abdullah/
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: digestlibrary.com. Connection pool size: 10
# 📌 Found title with selector 'h1': 'Digest Library' for URL: https://digestlibrary.com/2021/02/17/ishq-safar-ki-dhool-by-arshia-rajpoot/
# 📌 Fallback title found: 'Ishq safar ki dhool by Arshia Rajpoot' for URL: https://digestlibrary.com/2021/02/17/ishq-safar-ki-dhool-by-arshia-rajpoot/
# 📌 Final title: 'No Title Found' for URL: https://digestlibrary.com/2021/02/17/ishq-safar-ki-dhool-by-arshia-rajpoot/
# 📌 Found title with selector 'h1': 'Digest Library' for URL: https://digestlibrary.com/2022/05/29/shua-digest-february-2000-complete-pdf/
# 📌 Fallback title found: 'Shua digest February 2000 complete pdf' for URL: https://digestlibrary.com/2022/05/29/shua-digest-february-2000-complete-pdf/
# 📌 Final title: 'No Title Found' for URL: https://digestlibrary.com/2022/05/29/shua-digest-february-2000-complete-pdf/
# 📌 Found title with selector 'h1': 'Digest Library' for URL: https://digestlibrary.com/2025/03/07/sahil-epi_6_7-by-asma-ashraf/
# 📌 Fallback title found: 'Sahil epi_6_7 by Asma Ashraf' for URL: https://digestlibrary.com/2025/03/07/sahil-epi_6_7-by-asma-ashraf/
# 📌 Final title: 'No Title Found' for URL: https://digestlibrary.com/2025/03/07/sahil-epi_6_7-by-asma-ashraf/
# 📌 Found title with selector 'h1': 'Digest Library' for URL: https://digestlibrary.com/2025/03/07/eid-1966-mai-by-saira-raza/
# 📌 Fallback title found: 'Eid 1966 mai by Saira Raza' for URL: https://digestlibrary.com/2025/03/07/eid-1966-mai-by-saira-raza/
# 📌 Final title: 'No Title Found' for URL: https://digestlibrary.com/2025/03/07/eid-1966-mai-by-saira-raza/
# 📌 Found title with selector 'h1': 'Digest Library' for URL: https://digestlibrary.com/2023/08/21/sitara-e-zeesat-by-misbah-awan/
# 📌 Fallback title found: 'Sitara e zeesat by Misbah Awan' for URL: https://digestlibrary.com/2023/08/21/sitara-e-zeesat-by-misbah-awan/
# 📌 Final title: 'No Title Found' for URL: https://digestlibrary.com/2023/08/21/sitara-e-zeesat-by-misbah-awan/
# 📌 Found title with selector 'h1': 'Digest Library' for URL: https://digestlibrary.com/2025/03/01/man-ki-dehleez-per-by-nabiha-naqvi/
# 📌 Fallback title found: 'Man ki dehleez per by Nabiha Naqvi' for URL: https://digestlibrary.com/2025/03/01/man-ki-dehleez-per-by-nabiha-naqvi/
# 📌 Final title: 'No Title Found' for URL: https://digestlibrary.com/2025/03/01/man-ki-dehleez-per-by-nabiha-naqvi/
# 📌 Found title with selector 'h1': 'Digest Library' for URL: https://digestlibrary.com/2021/06/17/dil-tainu-day-baithay-by-durr-e-suman/
# 📌 Fallback title found: 'Dil tainu day baithay by Durr e Suman' for URL: https://digestlibrary.com/2021/06/17/dil-tainu-day-baithay-by-durr-e-suman/
# 📌 Final title: 'No Title Found' for URL: https://digestlibrary.com/2021/06/17/dil-tainu-day-baithay-by-durr-e-suman/
# 📌 Found title with selector 'h1': 'Digest Library' for URL: https://digestlibrary.com/2025/03/01/ik-umar-ki-riazat-by-nighat-seema/
# 📌 Fallback title found: 'Ik umar ki riazat by Nighat Seema' for URL: https://digestlibrary.com/2025/03/01/ik-umar-ki-riazat-by-nighat-seema/
# 📌 Final title: 'No Title Found' for URL: https://digestlibrary.com/2025/03/01/ik-umar-ki-riazat-by-nighat-seema/
# 📌 Found title with selector 'h1': 'Digest Library' for URL: https://digestlibrary.com/2025/03/01/hum-tum-aur-chand-by-humaira-shafi/
# 📌 Fallback title found: 'Hum tum aur chand by Humaira Shafi' for URL: https://digestlibrary.com/2025/03/01/hum-tum-aur-chand-by-humaira-shafi/
# 📌 Final title: 'No Title Found' for URL: https://digestlibrary.com/2025/03/01/hum-tum-aur-chand-by-humaira-shafi/
# 📌 Found title with selector 'h1': 'Digest Library' for URL: https://digestlibrary.com/2023/01/17/jeena-esi-ka-naam-hai-by-nuzhat-jabeen-zia/
# 📌 Fallback title found: 'Jeena esi ka naam hai by Nuzhat Jabeen Zia' for URL: https://digestlibrary.com/2023/01/17/jeena-esi-ka-naam-hai-by-nuzhat-jabeen-zia/
# 📌 Final title: 'No Title Found' for URL: https://digestlibrary.com/2023/01/17/jeena-esi-ka-naam-hai-by-nuzhat-jabeen-zia/
# 📌 Found title with selector 'h1': 'Digest Library' for URL: https://digestlibrary.com/2025/03/02/shua-digest-july-2021-complete-pdf/
# 📌 Fallback title found: 'Shua digest July 2021 complete pdf' for URL: https://digestlibrary.com/2025/03/02/shua-digest-july-2021-complete-pdf/
# 📌 Final title: 'No Title Found' for URL: https://digestlibrary.com/2025/03/02/shua-digest-july-2021-complete-pdf/
# 📌 Found title with selector 'h1': 'Digest Library' for URL: https://digestlibrary.com/2021/02/18/mur-aa-k-mol-na-jayen-by-shugufta-bhatti/
# 📌 Fallback title found: 'Mur aa k mol na jayen by Shagufta Bhatti' for URL: https://digestlibrary.com/2021/02/18/mur-aa-k-mol-na-jayen-by-shugufta-bhatti/
# 📌 Final title: 'No Title Found' for URL: https://digestlibrary.com/2021/02/18/mur-aa-k-mol-na-jayen-by-shugufta-bhatti/
# ⚠ Attempt 1 failed for https://digestlibrary.com/2021/05/19/aey-chand-guwah-rehna-by-nuzhat-jabeen/: HTTPSConnectionPool(host='digestlibrary.com', port=443): Max retries exceeded with url: /2021/05/19/aey-chand-guwah-rehna-by-nuzhat-jabeen/ (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7dd53f0c1890>, 'Connection to digestlibrary.com timed out. (connect timeout=30)'))
# ⚠ Attempt 1 failed for https://digestlibrary.com/2025/03/01/nazdeek-ki-nazar-by-surriya-anjum/: HTTPSConnectionPool(host='digestlibrary.com', port=443): Max retries exceeded with url: /2025/03/01/nazdeek-ki-nazar-by-surriya-anjum/ (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7dd5441061d0>, 'Connection to digestlibrary.com timed out. (connect timeout=30)'))
# ⚠ Attempt 1 failed for https://digestlibrary.com/2021/12/16/guwah-rafaqton-ka-halal-e-eid-by-saba-javed/: HTTPSConnectionPool(host='digestlibrary.com', port=443): Max retries exceeded with url: /2021/12/16/guwah-rafaqton-ka-halal-e-eid-by-saba-javed/ (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7dd53fc5bd10>, 'Connection to digestlibrary.com timed out. (connect timeout=30)'))
# ⚠ Attempt 1 failed for https://digestlibrary.com/2024/07/16/jan-e-jana-by-iqra-sagheer-ahmad/: HTTPSConnectionPool(host='digestlibrary.com', port=443): Max retries exceeded with url: /2024/07/16/jan-e-jana-by-iqra-sagheer-ahmad/ (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7dd544a23910>, 'Connection to digestlibrary.com timed out. (connect timeout=30)'))
# 📌 Found title with selector 'h1': 'Digest Library' for URL: https://digestlibrary.com/2021/02/05/mohabbat-abr-e-rehmat-by-hira-batool/
# 📌 Fallback title found: 'Mohabbat abr e rehmat by Hira Batool' for URL: https://digestlibrary.com/2021/02/05/mohabbat-abr-e-rehmat-by-hira-batool/
# 📌 Final title: 'No Title Found' for URL: https://digestlibrary.com/2021/02/05/mohabbat-abr-e-rehmat-by-hira-batool/
# 📌 Found title with selector 'h1': 'Digest Library' for URL: https://digestlibrary.com/2023/03/26/tu-meri-eid-ka-chand-by-rabia-iftikhar/
# 📌 Fallback title found: 'Tum meri Eid k chand by Rabia Iftikhar' for URL: https://digestlibrary.com/2023/03/26/tu-meri-eid-ka-chand-by-rabia-iftikhar/
# 📌 Final title: 'No Title Found' for URL: https://digestlibrary.com/2023/03/26/tu-meri-eid-ka-chand-by-rabia-iftikhar/
# 📌 Found title with selector 'h1': 'Digest Library' for URL: https://digestlibrary.com/2021/10/23/mohabbat-dhanak-rang-orh-kr-by-ghazal-yasir-malik/
# 📌 Fallback title found: 'Mohabbat ki dhanak orh kr by Ghazal Yasir Malik' for URL: https://digestlibrary.com/2021/10/23/mohabbat-dhanak-rang-orh-kr-by-ghazal-yasir-malik/
# 📌 Final title: 'No Title Found' for URL: https://digestlibrary.com/2021/10/23/mohabbat-dhanak-rang-orh-kr-by-ghazal-yasir-malik/
# 📌 Found title with selector 'h1': 'Digest Library' for URL: https://digestlibrary.com/2021/02/01/zaat-e-be-sabat-by-nabila-aziz/
# 📌 Fallback title found: 'Zaat e be sabat by Nabila Aziz' for URL: https://digestlibrary.com/2021/02/01/zaat-e-be-sabat-by-nabila-aziz/
# 📌 Final title: 'No Title Found' for URL: https://digestlibrary.com/2021/02/01/zaat-e-be-sabat-by-nabila-aziz/
# 📌 Found title with selector 'h1': 'Digest Library' for URL: https://digestlibrary.com/2021/10/07/cake-candle-queen-by-munam-malik/
# 📌 Fallback title found: 'Cake candle Queen by Munam Malik' for URL: https://digestlibrary.com/2021/10/07/cake-candle-queen-by-munam-malik/
# 📌 Final title: 'No Title Found' for URL: https://digestlibrary.com/2021/10/07/cake-candle-queen-by-munam-malik/
# 📌 Found title with selector 'h1': 'Digest Library' for URL: https://digestlibrary.com/2025/03/08/khushbu-ka-dareecha-khula-by-alia-hira/
# 📌 Fallback title found: 'Khushbu ka dareecha khula by Alia Hira' for URL: https://digestlibrary.com/2025/03/08/khushbu-ka-dareecha-khula-by-alia-hira/
# 📌 Final title: 'No Title Found' for URL: https://digestlibrary.com/2025/03/08/khushbu-ka-dareecha-khula-by-alia-hira/
# 📌 Found title with selector 'h1': 'Digest Library' for URL: https://digestlibrary.com/2025/03/02/ma-ul-malook-epi_18-by-nighat-seema/
# 📌 Fallback title found: 'Ma ul Malook epi_18 by Nighat Seema' for URL: https://digestlibrary.com/2025/03/02/ma-ul-malook-epi_18-by-nighat-seema/
# 📌 Final title: 'No Title Found' for URL: https://digestlibrary.com/2025/03/02/ma-ul-malook-epi_18-by-nighat-seema/
# 📌 Found title with selector 'h1': 'Digest Library' for URL: https://digestlibrary.com/2022/04/11/har-roz-eid-sanam-by-rehana-aftab/
# 📌 Fallback title found: 'Har roz Eid sanam by Rehana Aftab' for URL: https://digestlibrary.com/2022/04/11/har-roz-eid-sanam-by-rehana-aftab/
# 📌 Final title: 'No Title Found' for URL: https://digestlibrary.com/2022/04/11/har-roz-eid-sanam-by-rehana-aftab/
# 📌 Found title with selector 'h1': 'Digest Library' for URL: https://digestlibrary.com/2021/02/28/chand-ghagan-or-chandni-by-iqra-sagheer-ahmad/
# 📌 Fallback title found: 'Chand ghagan or chandni by Iqra Sagheer Ahmad' for URL: https://digestlibrary.com/2021/02/28/chand-ghagan-or-chandni-by-iqra-sagheer-ahmad/
# 📌 Final title: 'No Title Found' for URL: https://digestlibrary.com/2021/02/28/chand-ghagan-or-chandni-by-iqra-sagheer-ahmad/
# 📌 Found title with selector 'h1': 'Digest Library' for URL: https://digestlibrary.com/2022/05/21/wafa-hai-husn-e-mohabbat-by-shehzadi-abbas-khilji/
# 📌 Fallback title found: 'Wafa hai husn e mohabbat by Shehzadi Abbas Khilji' for URL: https://digestlibrary.com/2022/05/21/wafa-hai-husn-e-mohabbat-by-shehzadi-abbas-khilji/
# 📌 Final title: 'No Title Found' for URL: https://digestlibrary.com/2022/05/21/wafa-hai-husn-e-mohabbat-by-shehzadi-abbas-khilji/
# 📌 Found title with selector 'h1': 'Digest Library' for URL: https://digestlibrary.com/2024/09/04/mohabbat-panchwan-mausam-complete-by-nosheen-fiaz/
# 📌 Fallback title found: 'Mohabbat panchwan mausam complete by Nosheen Fiaz' for URL: https://digestlibrary.com/2024/09/04/mohabbat-panchwan-mausam-complete-by-nosheen-fiaz/
# 📌 Final title: 'No Title Found' for URL: https://digestlibrary.com/2024/09/04/mohabbat-panchwan-mausam-complete-by-nosheen-fiaz/
# 📌 Found title with selector 'h1': 'Digest Library' for URL: https://digestlibrary.com/2022/06/01/mohabbat-aisa-naghma-hai-complete-by-iqra-sagheer-ahmad/
# 📌 Fallback title found: 'Mohabbat aisa naghma hai complete by Iqra Sagheer Ahmad' for URL: https://digestlibrary.com/2022/06/01/mohabbat-aisa-naghma-hai-complete-by-iqra-sagheer-ahmad/
# 📌 Final title: 'No Title Found' for URL: https://digestlibrary.com/2022/06/01/mohabbat-aisa-naghma-hai-complete-by-iqra-sagheer-ahmad/
# 📌 Found title with selector 'h1': 'Digest Library' for URL: https://digestlibrary.com/2021/02/26/zeesat-ki-sham-se-pehlay-by-iqra-sagheer-ahmad/
# 📌 Fallback title found: 'Zeesat ki sham se pehlay by Iqra Sagheer Ahmad' for URL: https://digestlibrary.com/2021/02/26/zeesat-ki-sham-se-pehlay-by-iqra-sagheer-ahmad/
# 📌 Final title: 'No Title Found' for URL: https://digestlibrary.com/2021/02/26/zeesat-ki-sham-se-pehlay-by-iqra-sagheer-ahmad/
# 📌 Found title with selector 'h1': 'Digest Library' for URL: https://digestlibrary.com/2021/02/14/zidagi-khak-na-thi-by-umme-mariam/
# 📌 Fallback title found: 'Zindagi khak na thi by Umme Maryam' for URL: https://digestlibrary.com/2021/02/14/zidagi-khak-na-thi-by-umme-mariam/
# 📌 Final title: 'No Title Found' for URL: https://digestlibrary.com/2021/02/14/zidagi-khak-na-thi-by-umme-mariam/
# 📌 Found title with selector 'h1': 'Digest Library' for URL: https://digestlibrary.com/2021/02/03/baharon-k-sang-sang-by-iqra-sagheer-ahmad/
# 📌 Fallback title found: 'Baharon k sang sang by Iqra Sagheer Ahmad' for URL: https://digestlibrary.com/2021/02/03/baharon-k-sang-sang-by-iqra-sagheer-ahmad/
# 📌 Final title: 'No Title Found' for URL: https://digestlibrary.com/2021/02/03/baharon-k-sang-sang-by-iqra-sagheer-ahmad/
# ...
# 📌 Found title with selector 'h1': 'Digest Library' for URL: https://digestlibrary.com/2021/12/22/main-hari-piya-by-nida-ali-abbas/
# 📌 Fallback title found: 'Main hari piya by Nida Ali Abbas' for URL: https://digestlibrary.com/2021/12/22/main-hari-piya-by-nida-ali-abbas/
# 📌 Final title: 'No Title Found' for URL: https://digestlibrary.com/2021/12/22/main-hari-piya-by-nida-ali-abbas/
# 📌 Found title with selector 'h1': 'Digest Library' for URL: https://digestlibrary.com/2025/03/15/teri-chah-mai-by-fakhra-gul/
# 📌 Fallback title found: 'Teri chah mai by Fakhra Gul' for URL: https://digestlibrary.com/2025/03/15/teri-chah-mai-by-fakhra-gul/
# 📌 Final title: 'No Title Found' for URL: https://digestlibrary.com/2025/03/15/teri-chah-mai-by-fakhra-gul/
# 📌 Found title with selector 'h1': 'Digest Library' for URL: https://digestlibrary.com/2025/03/12/jaan-e-hayat-by-sawera-falak/
# 📌 Fallback title found: 'Jaan e hayat by Sawera Falak' for URL: https://digestlibrary.com/2025/03/12/jaan-e-hayat-by-sawera-falak/
# 📌 Final title: 'No Title Found' for URL: https://digestlibrary.com/2025/03/12/jaan-e-hayat-by-sawera-falak/
# 📌 Found title with selector 'h1': 'Digest Library' for URL: https://digestlibrary.com/2021/02/22/meri-eid-tum-ho-by-memoona-khursheed/
# 📌 Fallback title found: 'Meri Eid tum ho by Memoona Khursheed' for URL: https://digestlibrary.com/2021/02/22/meri-eid-tum-ho-by-memoona-khursheed/
# 📌 Final title: 'No Title Found' for URL: https://digestlibrary.com/2021/02/22/meri-eid-tum-ho-by-memoona-khursheed/
# ⚠ Attempt 1 failed for https://digestlibrary.com/2025/03/13/taash-ghar-epi_34-by-aimal-raza/: HTTPSConnectionPool(host='digestlibrary.com', port=443): Max retries exceeded with url: /2025/03/13/taash-ghar-epi_34-by-aimal-raza/ (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7dd544b45890>, 'Connection to digestlibrary.com timed out. (connect timeout=30)'))
# ⚠ Attempt 1 failed for https://digestlibrary.com/2025/03/13/chand-hatheli-per-by-nuzhat-jabeen-zia/: HTTPSConnectionPool(host='digestlibrary.com', port=443): Max retries exceeded with url: /2025/03/13/chand-hatheli-per-by-nuzhat-jabeen-zia/ (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7dd54457db10>, 'Connection to digestlibrary.com timed out. (connect timeout=30)'))
# ⚠ Attempt 2 failed for https://digestlibrary.com/2023/09/13/naveed-e-sehar-by-atiqa-ayub/: HTTPSConnectionPool(host='digestlibrary.com', port=443): Max retries exceeded with url: /2023/09/13/naveed-e-sehar-by-atiqa-ayub/ (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7dd54457ce50>, 'Connection to digestlibrary.com timed out. (connect timeout=30)'))
# ⚠ Attempt 1 failed for https://digestlibrary.com/2025/03/13/chand-hatheli-per-by-nuzhat-jabeen-zia/: HTTPSConnectionPool(host='digestlibrary.com', port=443): Max retries exceeded with url: /2025/03/13/chand-hatheli-per-by-nuzhat-jabeen-zia/ (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7dd57b497050>, 'Connection to digestlibrary.com timed out. (connect timeout=30)'))
# 📌 Found title with selector 'h1': 'Digest Library' for URL: https://digestlibrary.com/2021/03/02/eid-tumharay-sang-piya-by-rehana-aftab/
# 📌 Fallback title found: 'Eid tumharay sang piya by Rehana Aftab' for URL: https://digestlibrary.com/2021/03/02/eid-tumharay-sang-piya-by-rehana-aftab/
# 📌 Final title: 'No Title Found' for URL: https://digestlibrary.com/2021/03/02/eid-tumharay-sang-piya-by-rehana-aftab/
# 📌 Found title with selector 'h1': 'Digest Library' for URL: https://digestlibrary.com/2024/09/24/tu-nahi-baton-jesa-complete-by-fozia-yasmeen-2/
# 📌 Fallback title found: 'Tu nahi baton jesa complete by Fozia Yasmeen' for URL: https://digestlibrary.com/2024/09/24/tu-nahi-baton-jesa-complete-by-fozia-yasmeen-2/
# 📌 Final title: 'No Title Found' for URL: https://digestlibrary.com/2024/09/24/tu-nahi-baton-jesa-complete-by-fozia-yasmeen-2/
# 📌 Found title with selector 'h1': 'Digest Library' for URL: https://digestlibrary.com/2023/09/13/naveed-e-sehar-by-atiqa-ayub/
# 📌 Fallback title found: 'Naveed e sehar by Atiqa Ayub' for URL: https://digestlibrary.com/2023/09/13/naveed-e-sehar-by-atiqa-ayub/
# 📌 Final title: 'No Title Found' for URL: https://digestlibrary.com/2023/09/13/naveed-e-sehar-by-atiqa-ayub/
# 📌 Found title with selector 'h1': 'Digest Library' for URL: https://digestlibrary.com/2025/03/15/qamar-un-nisa-ki-kahani-by-nighat-seema/
# 📌 Fallback title found: 'Qamar Un Nisa ki Kahani by Nighat Seema' for URL: https://digestlibrary.com/2025/03/15/qamar-un-nisa-ki-kahani-by-nighat-seema/
# 📌 Final title: 'No Title Found' for URL: https://digestlibrary.com/2025/03/15/qamar-un-nisa-ki-kahani-by-nighat-seema/
# 📌 Found title with selector 'h1': 'Digest Library' for URL: https://digestlibrary.com/2025/03/15/qamar-un-nisa-ki-kahani-by-nighat-seema/
# 📌 Fallback title found: 'Qamar Un Nisa ki Kahani by Nighat Seema' for URL: https://digestlibrary.com/2025/03/15/qamar-un-nisa-ki-kahani-by-nighat-seema/
# 📌 Final title: 'No Title Found' for URL: https://digestlibrary.com/2025/03/15/qamar-un-nisa-ki-kahani-by-nighat-seema/
# ⚠ Attempt 1 failed for https://digestlibrary.com/2020/12/26/rang-khushboo-hawa-badil-by-afshan-afreedi/: HTTPSConnectionPool(host='digestlibrary.com', port=443): Max retries exceeded with url: /2020/12/26/rang-khushboo-hawa-badil-by-afshan-afreedi/ (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7dd57b49bed0>, 'Connection to digestlibrary.com timed out. (connect timeout=30)'))
# 📌 Found title with selector 'h1': 'Digest Library' for URL: https://digestlibrary.com/2025/03/15/tu-chand-mere-aagan-ka-by-roheela-khan/
# 📌 Fallback title found: 'Tu chand mere aagan ka by Roheela Khan' for URL: https://digestlibrary.com/2025/03/15/tu-chand-mere-aagan-ka-by-roheela-khan/
# 📌 Final title: 'No Title Found' for URL: https://digestlibrary.com/2025/03/15/tu-chand-mere-aagan-ka-by-roheela-khan/
# 📌 Found title with selector 'h1': 'Digest Library' for URL: https://digestlibrary.com/2025/03/15/tu-chand-mere-aagan-ka-by-roheela-khan/
# 📌 Fallback title found: 'Tu chand mere aagan ka by Roheela Khan' for URL: https://digestlibrary.com/2025/03/15/tu-chand-mere-aagan-ka-by-roheela-khan/
# 📌 Final title: 'No Title Found' for URL: https://digestlibrary.com/2025/03/15/tu-chand-mere-aagan-ka-by-roheela-khan/
# 📌 Found title with selector 'h1': 'Digest Library' for URL: https://digestlibrary.com/2023/06/22/behtay-panion-ke-khuwab-by-rahat-jabeen/
# 📌 Fallback title found: 'Behtay panion ke khuwab by Rahat Jabeen' for URL: https://digestlibrary.com/2023/06/22/behtay-panion-ke-khuwab-by-rahat-jabeen/
# 📌 Final title: 'No Title Found' for URL: https://digestlibrary.com/2023/06/22/behtay-panion-ke-khuwab-by-rahat-jabeen/
# 📌 Found title with selector 'h1': 'Digest Library' for URL: https://digestlibrary.com/2021/02/21/jab-woh-milay-series-by-saira-raza/
# 📌 Fallback title found: 'Jab woh milay complete series by Saira Raza' for URL: https://digestlibrary.com/2021/02/21/jab-woh-milay-series-by-saira-raza/
# 📌 Final title: 'No Title Found' for URL: https://digestlibrary.com/2021/02/21/jab-woh-milay-series-by-saira-raza/
# 📌 Found title with selector 'h1': 'Digest Library' for URL: https://digestlibrary.com/2025/03/15/kaheen-deep-jalay-kaheen-dil-by-sadia-aziz-afridi/
# 📌 Fallback title found: 'Kaheen deep jalay kaheen dil by Sadia Aziz Afridi' for URL: https://digestlibrary.com/2025/03/15/kaheen-deep-jalay-kaheen-dil-by-sadia-aziz-afridi/
# 📌 Final title: 'No Title Found' for URL: https://digestlibrary.com/2025/03/15/kaheen-deep-jalay-kaheen-dil-by-sadia-aziz-afridi/
# 📌 Found title with selector 'h1': 'Digest Library' for URL: https://digestlibrary.com/2023/06/22/behtay-panion-ke-khuwab-by-rahat-jabeen/
# 📌 Fallback title found: 'Behtay panion ke khuwab by Rahat Jabeen' for URL: https://digestlibrary.com/2023/06/22/behtay-panion-ke-khuwab-by-rahat-jabeen/
# 📌 Final title: 'No Title Found' for URL: https://digestlibrary.com/2023/06/22/behtay-panion-ke-khuwab-by-rahat-jabeen/
# 📌 Found title with selector 'h1': 'Digest Library' for URL: https://digestlibrary.com/2025/03/15/kaheen-deep-jalay-kaheen-dil-by-sadia-aziz-afridi/
# 📌 Fallback title found: 'Kaheen deep jalay kaheen dil by Sadia Aziz Afridi' for URL: https://digestlibrary.com/2025/03/15/kaheen-deep-jalay-kaheen-dil-by-sadia-aziz-afridi/
# 📌 Final title: 'No Title Found' for URL: https://digestlibrary.com/2025/03/15/kaheen-deep-jalay-kaheen-dil-by-sadia-aziz-afridi/
# ⚠ Attempt 1 failed for https://digestlibrary.com/2021/02/17/hum-ko-hai-teri-nazar-mai-rehna-by-maryam-aziz/: HTTPSConnectionPool(host='digestlibrary.com', port=443): Max retries exceeded with url: /2021/02/17/hum-ko-hai-teri-nazar-mai-rehna-by-maryam-aziz/ (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7dd53f596050>, 'Connection to digestlibrary.com timed out. (connect timeout=30)'))
# 📌 Found title with selector 'h1': 'Digest Library' for URL: https://digestlibrary.com/2021/05/03/eid-ka-chand-by-alia-hira/
# 📌 Fallback title found: 'Eid ka chand by Alia Hira' for URL: https://digestlibrary.com/2021/05/03/eid-ka-chand-by-alia-hira/
# 📌 Final title: 'No Title Found' for URL: https://digestlibrary.com/2021/05/03/eid-ka-chand-by-alia-hira/
# 📌 Found title with selector 'h1': 'Digest Library' for URL: https://digestlibrary.com/2021/05/03/eid-ka-chand-by-alia-hira/
# 📌 Fallback title found: 'Eid ka chand by Alia Hira' for URL: https://digestlibrary.com/2021/05/03/eid-ka-chand-by-alia-hira/
# 📌 Final title: 'No Title Found' for URL: https://digestlibrary.com/2021/05/03/eid-ka-chand-by-alia-hira/
# ⚠ Attempt 3 failed for https://digestlibrary.com/2024/08/28/suspense-digest-august-2024-complete-pdf/: HTTPSConnectionPool(host='digestlibrary.com', port=443): Max retries exceeded with url: /2024/08/28/suspense-digest-august-2024-complete-pdf/ (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7dd544961550>, 'Connection to digestlibrary.com timed out. (connect timeout=30)'))
# 📌 Found title with selector 'h1': 'Digest Library' for URL: https://digestlibrary.com/2021/01/04/ab-inkar-ka-mausam-nhi-by-nabila-abar-raja/
# 📌 Fallback title found: 'Ab inkar ka mausam nhi by Nabila Abar Raja' for URL: https://digestlibrary.com/2021/01/04/ab-inkar-ka-mausam-nhi-by-nabila-abar-raja/
# 📌 Final title: 'No Title Found' for URL: https://digestlibrary.com/2021/01/04/ab-inkar-ka-mausam-nhi-by-nabila-abar-raja/
# ⚠ Attempt 2 failed for https://digestlibrary.com/2025/03/11/suspense-digest-march-2025-complete-pdf/: HTTPSConnectionPool(host='digestlibrary.com', port=443): Max retries exceeded with url: /2025/03/11/suspense-digest-march-2025-complete-pdf/ (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7dd53fa25d10>, 'Connection to digestlibrary.com timed out. (connect timeout=30)'))
# ⚠ Attempt 1 failed for https://digestlibrary.com/2025/03/14/sabaq-by-samra-bukhari/: HTTPSConnectionPool(host='digestlibrary.com', port=443): Max retries exceeded with url: /2025/03/14/sabaq-by-samra-bukhari/ (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7dd53fda6950>, 'Connection to digestlibrary.com timed out. (connect timeout=30)'))
# ⚠ Attempt 1 failed for https://digestlibrary.com/2025/03/14/letter-box-by-asia-raees-khan/: HTTPSConnectionPool(host='digestlibrary.com', port=443): Max retries exceeded with url: /2025/03/14/letter-box-by-asia-raees-khan/ (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7dd53fda7ed0>, 'Connection to digestlibrary.com timed out. (connect timeout=30)'))
# ⚠ Attempt 1 failed for https://digestlibrary.com/2025/03/14/sabaq-by-samra-bukhari/: HTTPSConnectionPool(host='digestlibrary.com', port=443): Max retries exceeded with url: /2025/03/14/sabaq-by-samra-bukhari/ (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7dd544962090>, 'Connection to digestlibrary.com timed out. (connect timeout=30)'))
# ⚠ Attempt 1 failed for https://digestlibrary.com/2025/03/14/letter-box-by-asia-raees-khan/: HTTPSConnectionPool(host='digestlibrary.com', port=443): Max retries exceeded with url: /2025/03/14/letter-box-by-asia-raees-khan/ (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7dd53fa258d0>, 'Connection to digestlibrary.com timed out. (connect timeout=30)'))
# ⚠ Attempt 3 failed for https://digestlibrary.com/2025/03/05/shua-digest-march-2025-complete-pdf/: HTTPSConnectionPool(host='digestlibrary.com', port=443): Max retries exceeded with url: /2025/03/05/shua-digest-march-2025-complete-pdf/ (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7dd53f543ed0>, 'Connection to digestlibrary.com timed out. (connect timeout=30)'))
# ⚠ Attempt 3 failed for https://digestlibrary.com/2022/04/16/kaanch-ke-garonday-complete-by-nighat-abdullah/: HTTPSConnectionPool(host='digestlibrary.com', port=443): Max retries exceeded with url: /2022/04/16/kaanch-ke-garonday-complete-by-nighat-abdullah/ (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7dd5448dee10>, 'Connection to digestlibrary.com timed out. (connect timeout=30)'))
# ⚠ Attempt 3 failed for https://digestlibrary.com/2025/03/12/nakhal-e-wafa-epi_7-by-farah-bukhari/: HTTPSConnectionPool(host='digestlibrary.com', port=443): Max retries exceeded with url: /2025/03/12/nakhal-e-wafa-epi_7-by-farah-bukhari/ (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7dd53f554290>, 'Connection to digestlibrary.com timed out. (connect timeout=30)'))
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-2-3beb4c900fc3> in <cell line: 0>()
#     222
# --> 223     for count, future in enumerate(concurrent.futures.as_completed(future_to_url), start=1):
#     224         idx = future_to_url[future]
#
# /usr/lib/python3.11/concurrent/futures/_base.py in as_completed(fs, timeout)
#     242
# --> 243             waiter.event.wait(wait_timeout)
#     244
#
# /usr/lib/python3.11/threading.py in wait(self, timeout)
#     628             if not signaled:
# --> 629                 signaled = self._cond.wait(timeout)
#     630             return signaled
#
# /usr/lib/python3.11/threading.py in wait(self, timeout)
#     326             if timeout is None:
# --> 327                 waiter.acquire()
#     328                 gotit = True
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-2-3beb4c900fc3> in <cell line: 0>()
#     218 start_time = time.time()
#     219
# --> 220 with concurrent.futures.ThreadPoolExecutor(max_workers=10) as executor:  # Increased workers
#     221     future_to_url = {executor.submit(scrape_post, post_url): idx for idx, post_url in enumerate(post_urls[last_index:], last_index)}
#     222
#
# /usr/lib/python3.11/concurrent/futures/_base.py in __exit__(self, exc_type, exc_val, exc_tb)
#     645
#     646     def __exit__(self, exc_type, exc_val, exc_tb):
# --> 647         self.shutdown(wait=True)
#     648         return False
#     649
#
# /usr/lib/python3.11/concurrent/futures/thread.py in shutdown(self, wait, cancel_futures)
#     233         if wait:
#     234             for t in self._threads:
# --> 235                 t.join()
#     236     shutdown.__doc__ = _base.Executor.shutdown.__doc__
#
# /usr/lib/python3.11/threading.py in join(self, timeout)
#    1117
#    1118         if timeout is None:
# -> 1119             self._wait_for_tstate_lock()
#    1120         else:
#    1121             # the behavior of a negative timeout isn't documented, but
#
# /usr/lib/python3.11/threading.py in _wait_for_tstate_lock(self, block, timeout)
#    1137
#    1138         try:
# -> 1139             if lock.acquire(block, timeout):
#    1140                 lock.release()
#    1141                 self._stop()
#
# KeyboardInterrupt:

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import time
import xml.etree.ElementTree as ET
import os
import concurrent.futures
import random
from datetime import datetime
from threading import Lock
import re
import logging
from urllib.parse import urlparse

# 🚀 Setup Logging
logging.basicConfig(
    filename="scrape_log.txt",
    level=logging.INFO,
    format="%(asctime)s: %(levelname)s: %(message)s"
)

# 📌 Google Drive Mount (Optional)
try:
    from google.colab import drive
    drive.mount('/content/drive')
    SAVE_PATH_XLSX = "/content/drive/My Drive/Blogger_Novels.xlsx"
    FAILED_LINKS_FILE = "/content/drive/My Drive/failed_links.txt"
    PROGRESS_FILE = "/content/drive/My Drive/progress.txt"
except ImportError:
    SAVE_PATH_XLSX = "Blogger_Novels.xlsx"
    FAILED_LINKS_FILE = "failed_links.txt"
    PROGRESS_FILE = "progress.txt"

# 📌 Headers & Session
HEADERS = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/121.0.0.0 Safari/537.36",
    "Accept": "text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,*/*;q=0.8",
    "Accept-Language": "en-US,en;q=0.5",
    "Connection": "keep-alive"
}
session = requests.Session()
session.headers.update(HEADERS)

# 🔄 Progress Lock
progress_lock = Lock()

# 📥 Step 1: Extract all post URLs from sitemap
SITEMAP_URL = "https://digestlibrary.com/post-sitemap7.xml"
try:
    response = session.get(SITEMAP_URL, timeout=30)
    if response.status_code == 200:
        root = ET.fromstring(response.content)
        post_urls = [elem.text for elem in root.findall(".//{http://www.sitemaps.org/schemas/sitemap/0.9}loc")]
        logging.info(f"Found {len(post_urls)} posts to scrape.")
    else:
        logging.error(f"Failed to fetch sitemap: HTTP {response.status_code}")
        exit()
except ET.ParseError:
    logging.error("Failed to parse sitemap XML.")
    exit()
except requests.exceptions.RequestException as e:
    logging.error(f"Sitemap request failed: {e}")
    exit()

# 🔄 Resume Last Progress
last_index = 0
if os.path.exists(PROGRESS_FILE):
    try:
        with open(PROGRESS_FILE, "r") as f:
            last_index = int(f.read().strip())
        logging.info(f"Resuming from index {last_index}")
    except (ValueError, IOError) as e:
        logging.warning(f"Could not read progress file: {e}. Starting from index 0.")

# ⏳ Function to estimate remaining time
def estimate_time(start_time, processed, total):
    elapsed_time = time.time() - start_time
    avg_time_per_post = elapsed_time / processed if processed > 0 else 0
    remaining_posts = total - processed
    estimated_remaining_time = remaining_posts * avg_time_per_post
    return time.strftime('%H:%M:%S', time.gmtime(estimated_remaining_time))

# 🔍 Function to resolve redirects
def resolve_redirect(url):
    try:
        response = session.head(url, allow_redirects=True, timeout=10)
        return response.url
    except requests.exceptions.RequestException:
        return url

# 🔍 Step 2: Scrape Each Novel Post with Auto-Retry
def scrape_post(post_url):
    retries = 5
    for attempt in range(retries):
        try:
            response = session.get(post_url, timeout=60)
            if response.status_code == 429:
                logging.warning(f"Rate limit hit for {post_url}. Waiting...")
                time.sleep(2 ** attempt * 10)
                continue
            if response.status_code != 200:
                logging.warning(f"Retrying ({attempt+1}/{retries}) for {post_url}: HTTP {response.status_code}")
                time.sleep(5)
                continue

            soup = BeautifulSoup(response.text, "html.parser")

            # Extract Title
            title_selectors = [
                "h1.entry-title", "h2.entry-title", "h1.post-title", "h2.post-title",
                "h3.entry-title", "h3.post-title", "div.post-title", "div.entry-title",
                "h1", "h2", "h3"
            ]
            title = None
            title_element = None
            for selector in title_selectors:
                title_elem = soup.select_one(selector)
                if title_elem:
                    title = title_elem.text.strip()
                    title_element = title_elem
                    logging.info(f"Found title with selector '{selector}': '{title}' for URL: {post_url}")
                    break

            if not title or "digest library" in title.lower():
                headers = soup.find_all(["h1", "h2", "h3"])
                for header in headers:
                    text = header.text.strip()
                    if "digest library" not in text.lower() and len(text) > 10 and not text.lower().startswith("home"):
                        title = text
                        title_element = header
                        logging.info(f"Fallback title found: '{title}' for URL: {post_url}")
                        break

            if not title or "digest library" in title.lower():
                title_tag = soup.find("title")
                if title_tag:
                    title = title_tag.text.strip().replace("Digest Library", "").replace("|", "").strip()
                    logging.info(f"Title from <title> tag: '{title}' for URL: {post_url}")

            title = title if title and "digest library" not in title.lower() else "No Title Found"
            logging.info(f"Final title: '{title}' for URL: {post_url}")

            # Extract Download Links
            all_links = [a["href"] for a in soup.find_all("a", href=True)]
            button_links = [button.get("onclick", "").strip("'").replace("window.location.href=", "")
                           for button in soup.find_all("button") if button.get("onclick")]
            all_links = [resolve_redirect(link) for link in all_links + button_links if link]

            download_domains = ["drive.google", "mediafire", "dropbox", "mega.nz"]
            google_drive_links = [link for link in all_links if "drive.google" in link]
            mediafire_links = [link for link in all_links if "mediafire" in link]
            other_links = [link for link in all_links if any(domain in link for domain in ["dropbox", "mega.nz"])]

            content_selectors = ["div.post-body", "div.entry-content", "div.post-content", "article", "div.post"]
            content = None
            for selector in content_selectors:
                content = soup.select_one(selector)
                if content:
                    break
            if not content:
                content = soup

            raw_urls = []
            text = content.get_text()
            url_pattern = r'https?://[^\s<>"]+|www\.[^\s<>"]+'
            raw_urls = re.findall(url_pattern, text)
            raw_urls = [url for url in raw_urls if any(domain in url.lower() for domain in download_domains)]

            google_drive_links.extend([url for url in raw_urls if "drive.google" in url and url not in google_drive_links])
            mediafire_links.extend([url for url in raw_urls if "mediafire" in url and url not in mediafire_links])
            other_links.extend([url for url in raw_urls if any(domain in url for domain in ["dropbox", "mega.nz"]) and url not in other_links])

            logging.debug(f"URL: {post_url}, Title: {title}")
            logging.debug(f"All <a> hrefs: {all_links}")
            logging.debug(f"Button links: {button_links}")
            logging.debug(f"Raw URLs from content: {raw_urls}")
            logging.debug(f"Google Drive Links: {google_drive_links}")
            logging.debug(f"Mediafire Links: {mediafire_links}")
            logging.debug(f"Other Links: {other_links}")
            if title_element:
                parent = title_element.find_parent()
                context = str(parent)[:200] if parent else "No parent"
                logging.debug(f"Title Context: {context}")
            content_snippet = text[:200].replace('\n', ' ')
            logging.debug(f"Content Snippet: {content_snippet}")

            return {
                "Title": title,
                "Google Drive Links": ", ".join(google_drive_links) if google_drive_links else "No Google Drive Link",
                "Mediafire Links": ", ".join(mediafire_links) if mediafire_links else "No Mediafire Link",
                "Other Links": ", ".join(other_links) if other_links else "No Other Links"
            }
        except requests.exceptions.RequestException as e:
            logging.warning(f"Attempt {attempt+1} failed for {post_url}: {e}")
            time.sleep(5)

    logging.error(f"Failed to scrape {post_url} after {retries} attempts")
    with open(FAILED_LINKS_FILE, "a") as f:
        f.write(post_url + "\n")
    return None

# 📌 Step 3: Scrape Each Post & Save Data in Batches
novels_data = []
BATCH_SIZE = 150
start_time = time.time()

with concurrent.futures.ThreadPoolExecutor(max_workers=5) as executor:  # Reduced workers
    future_to_url = {executor.submit(scrape_post, post_urls[idx]): idx for idx in range(last_index, len(post_urls))}

    for count, future in enumerate(concurrent.futures.as_completed(future_to_url), start=1):
        idx = future_to_url[future]
        result = future.result()
        if result:
            novels_data.append(result)

        if len(novels_data) >= BATCH_SIZE:
            df = pd.DataFrame(novels_data)
            try:
                with pd.ExcelWriter(SAVE_PATH_XLSX, mode='a' if os.path.exists(SAVE_PATH_XLSX) else 'w', engine='openpyxl') as writer:
                    df.to_excel(writer, index=False)
                novels_data = []
                with progress_lock:
                    with open(PROGRESS_FILE, "w") as f:
                        f.write(str(idx))
                logging.info(f"Saved batch at index {idx}")
            except (PermissionError, IOError) as e:
                logging.error(f"Cannot write to {SAVE_PATH_XLSX}: {e}. Saving to temp file.")
                df.to_excel("temp_novels.xlsx", index=False, engine='openpyxl')

        if count % 50 == 0:
            remaining_time = estimate_time(start_time, count, len(post_urls) - last_index)
            logging.info(f"Processed {count} posts. Estimated time remaining: {remaining_time}")

        time.sleep(random.uniform(2, 5))  # Increased delay range

# 📥 Step 4: Final Save
if novels_data:
    df = pd.DataFrame(novels_data)
    try:
        with pd.ExcelWriter(SAVE_PATH_XLSX, mode='a' if os.path.exists(SAVE_PATH_XLSX) else 'w', engine='openpyxl') as writer:
            df.to_excel(writer, index=False)
        logging.info("Final data saved.")
    except (PermissionError, IOError) as e:
        logging.error(f"Cannot write to {SAVE_PATH_XLSX}: {e}. Saving to temp file.")
        df.to_excel("temp_novels.xlsx", index=False, engine='openpyxl')

# ✅ Delete progress file only if all posts processed
if last_index + len(post_urls) >= len(post_urls):
    if os.path.exists(PROGRESS_FILE):
        try:
            os.remove(PROGRESS_FILE)
            logging.info("Progress file deleted.")
        except OSError as e:
            logging.warning(f"Could not delete progress file: {e}")

logging.info(f"Scraping complete! Data saved in '{SAVE_PATH_XLSX}'")
print(f"✅ Scraping complete! Data saved in '{SAVE_PATH_XLSX}'")
# Out:
# Mounted at /content/drive

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import time
import xml.etree.ElementTree as ET
import os
import concurrent.futures
import random
import logging
from requests.adapters import HTTPAdapter
from urllib3.util.retry import Retry
import backoff
from datetime import datetime

# 🚀 Google Drive Mount (for saving file)
try:
    from google.colab import drive
    drive.mount('/content/drive')
    BASE_PATH = "/content/drive/My Drive"
except ImportError:
    BASE_PATH = os.getcwd()  # Fallback to local directory if not in Colab

# 📌 File Paths
SITEMAP_URL = "https://digestlibrary.com/post-sitemap2.xml"
SAVE_PATH_XLSX = os.path.join(BASE_PATH, "Blogger_Novels.xlsx")
FAILED_LINKS_FILE = os.path.join(BASE_PATH, "failed_links.txt")
PROGRESS_FILE = os.path.join(BASE_PATH, "progress.txt")

# 🛡 Headers & Session
HEADERS = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/121.0.0.0 Safari/537.36"
}
session = requests.Session()
adapter = HTTPAdapter(pool_connections=20, pool_maxsize=20)  # Increase connection pool size
session.mount("http://", adapter)
session.mount("https://", adapter)
session.headers.update(HEADERS)

# 🔧 Logging Setup
logging.basicConfig(
    level=logging.INFO,
    format="%(asctime)s - %(levelname)s - %(message)s",
    handlers=[
        logging.FileHandler(os.path.join(BASE_PATH, "scrape_log.txt")),
        logging.StreamHandler()
    ]
)
logger = logging.getLogger(__name__)

# 🔄 Resume Last Progress
last_index = 0
if os.path.exists(PROGRESS_FILE):
    with open(PROGRESS_FILE, "r") as f:
        last_index = int(f.read().strip())
    logger.info(f"Resuming from index {last_index}")

# 📥 Step 1: Extract all post URLs from sitemap
try:
    response = session.get(SITEMAP_URL, timeout=30)
    response.raise_for_status()
    root = ET.fromstring(response.content)
    post_urls = [elem.text for elem in root.findall(".//{http://www.sitemaps.org/schemas/sitemap/0.9}loc")]
    logger.info(f"✅ Found {len(post_urls)} posts to scrape.")
except (requests.exceptions.RequestException, ET.ParseError) as e:
    logger.error(f"❌ Failed to fetch or parse sitemap: {e}")
    exit()

# ⏳ Function to estimate remaining time
def estimate_time(start_time, processed, total):
    elapsed_time = time.time() - start_time
    avg_time_per_post = elapsed_time / processed if processed > 0 else 0
    remaining_posts = total - processed
    estimated_remaining_time = remaining_posts * avg_time_per_post
    return time.strftime('%H:%M:%S', time.gmtime(estimated_remaining_time))

# 🔍 Step 2: Scrape Each Novel Post with Auto-Retry
@backoff.on_exception(backoff.expo, requests.exceptions.RequestException, max_tries=5, max_time=300)
def scrape_post(post_url):
    """Extracts title and ALL download links from a Blogger post"""
    try:
        response = session.get(post_url, timeout=30)
        if response.status_code == 429:
            logger.warning(f"⚠ Rate limit hit for {post_url}. Pausing for 60 seconds.")
            time.sleep(60)
            raise requests.exceptions.RequestException("Rate limit")
        elif response.status_code == 503:
            logger.warning(f"⚠ Service Unavailable for {post_url}. Pausing for 120 seconds.")
            time.sleep(120)
            raise requests.exceptions.RequestException("Service Unavailable")
        response.raise_for_status()

        soup = BeautifulSoup(response.text, "html.parser")

        # Extract Title
        title = (soup.find("h2") or soup.find("h1") or soup.find("h3") or
                 soup.find("meta", property="og:title"))
        title = title.get("content") if title and title.name == "meta" else title.text.strip() if title else "No Title Found"

        # Extract Download Links
        all_links = [a["href"] for a in soup.find_all("a", href=True)]
        google_drive_links = [link for link in all_links if "drive.google" in link]
        mediafire_links = [link for link in all_links if "mediafire" in link]

        logger.info(f"✅ Successfully scraped: {post_url}")
        return {
            "Title": title,
            "Google Drive Links": ", ".join(google_drive_links) if google_drive_links else "No Google Drive Link",
            "Mediafire Links": ", ".join(mediafire_links) if mediafire_links else "No Mediafire Link",
            "URL": post_url
        }
    except requests.exceptions.RequestException as e:
        logger.error(f"❌ Failed for {post_url}: {e}")
        with open(FAILED_LINKS_FILE, "a") as f:
            f.write(f"{post_url} | Failed: {str(e)}\n")
        return None
    except Exception as e:
        logger.error(f"❌ Parsing error for {post_url}: {e}")
        with open(FAILED_LINKS_FILE, "a") as f:
            f.write(f"{post_url} | Parsing error: {str(e)}\n")
        return None

# 📌 Step 3: Scrape Each Post & Save Data in Batches
novels_data = []
BATCH_SIZE = 50
start_time = time.time()
failed_urls = []

with concurrent.futures.ThreadPoolExecutor(max_workers=3) as executor:  # Reduced to 3
    future_to_url = {executor.submit(scrape_post, post_urls[idx]): idx for idx in range(last_index, len(post_urls))}

    for count, future in enumerate(concurrent.futures.as_completed(future_to_url), start=1):
        idx = future_to_url[future]
        try:
            result = future.result()
            if result:
                novels_data.append(result)
            else:
                failed_urls.append(post_urls[idx])
        except Exception as e:
            logger.error(f"❌ Error processing {post_urls[idx]}: {e}")
            failed_urls.append(post_urls[idx])

        # ✅ Save every batch of 50 posts
        if len(novels_data) >= BATCH_SIZE:
            df = pd.DataFrame(novels_data)
            try:
                if os.path.exists(SAVE_PATH_XLSX):
                    existing_df = pd.read_excel(SAVE_PATH_XLSX, engine='openpyxl')
                    if set(existing_df.columns) != set(df.columns):
                        logger.error("⚠ Column mismatch in Excel file. Creating new file.")
                        df.to_excel(SAVE_PATH_XLSX, index=False, engine='openpyxl')
                    else:
                        df = pd.concat([existing_df, df], ignore_index=True)
                        df.to_excel(SAVE_PATH_XLSX, index=False, engine='openpyxl')
                else:
                    df.to_excel(SAVE_PATH_XLSX, index=False)
                logger.info(f"✅ Saved batch of {len(novels_data)} posts to {SAVE_PATH_XLSX}")
                with open(PROGRESS_FILE, "w") as f:
                    f.write(str(idx))
                novels_data = []
            except Exception as e:
                logger.error(f"❌ Failed to save batch: {e}")

        # ⏳ Show estimated remaining time
        if count % 5 == 0:  # More frequent updates
            remaining_time = estimate_time(start_time, count, len(post_urls) - last_index)
            logger.info(f"⏳ Processed {count} posts. Estimated time remaining: {remaining_time}")

        time.sleep(random.uniform(0.5, 3))  # Increased max delay

# 📥 Step 4: Final Save
if novels_data:
    df = pd.DataFrame(novels_data)
    try:
        if os.path.exists(SAVE_PATH_XLSX):
            existing_df = pd.read_excel(SAVE_PATH_XLSX, engine='openpyxl')
            if set(existing_df.columns) != set(df.columns):
                logger.error("⚠ Column mismatch in Excel file. Creating new file.")
                df.to_excel(SAVE_PATH_XLSX, index=False, engine='openpyxl')
            else:
                df = pd.concat([existing_df, df], ignore_index=True)
                df.to_excel(SAVE_PATH_XLSX, index=False, engine='openpyxl')
        else:
            df.to_excel(SAVE_PATH_XLSX, index=False, engine='openpyxl')
        logger.info(f"✅ Saved final batch of {len(novels_data)} posts to {SAVE_PATH_XLSX}")
    except Exception as e:
        logger.error(f"❌ Failed to save final batch: {e}")

# 📌 Step 5: Retry Failed URLs
if failed_urls:
    logger.info(f"🔄 Retrying {len(failed_urls)} failed URLs")
    novels_data = []
    with concurrent.futures.ThreadPoolExecutor(max_workers=2) as executor:
        future_to_url = {executor.submit(scrape_post, url): url for url in failed_urls}
        for future in concurrent.futures.as_completed(future_to_url):
            url = future_to_url[future]
            try:
                result = future.result()
                if result:
                    novels_data.append(result)
            except Exception as e:
                logger.error(f"❌ Retry failed for {url}: {e}")

    if novels_data:
        df = pd.DataFrame(novels_data)
        try:
            if os.path.exists(SAVE_PATH_XLSX):
                existing_df = pd.read_excel(SAVE_PATH_XLSX, engine='openpyxl')
                df = pd.concat([existing_df, df], ignore_index=True)
            df.to_excel(SAVE_PATH_XLSX, index=False, engine='openpyxl')
            logger.info(f"✅ Saved {len(novels_data)} retried posts to {SAVE_PATH_XLSX}")
        except Exception as e:
            logger.error(f"❌ Failed to save retried batch: {e}")

# ✅ Delete progress file
if os.path.exists(PROGRESS_FILE):
    os.remove(PROGRESS_FILE)
    logger.info("✅ Progress file deleted")

# 📊 Report failed links
if os.path.exists(FAILED_LINKS_FILE):
    with open(FAILED_LINKS_FILE, "r") as f:
        failed_count = len(f.read().splitlines())
    logger.info(f"⚠ {failed_count} URLs failed. Check {FAILED_LINKS_FILE} for details.")
else:
    logger.info("✅ No failed URLs.")

logger.info(f"✅ Scraping complete! Data saved in '{SAVE_PATH_XLSX}'")
# Out:
# Mounted at /content/drive
# ERROR:__main__:❌ Failed for https://digestlibrary.com/2023/04/03/khoi-hui-bat-by-alia-bukhari/: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
# ERROR:__main__:❌ Failed for https://digestlibrary.com/2023/02/20/kaisar-by-sehar-sajid/: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
# ERROR:__main__:❌ Failed for https://digestlibrary.com/2023/02/01/shua-digest-may-1998-complete-pdf/: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
# ERROR:__main__:❌ Failed for https://digestlibrary.com/2023/01/25/hajje-akbar-by-aleem-ul-haq-haqi/: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
# ERROR:__main__:❌ Failed for https://digestlibrary.com/2022/10/31/ujale-bikharte-rahe-by-asia-razzaqi/: HTTPSConnectionPool(host='digestlibrary.com', port=443): Read timed out. (read timeout=30)
# ERROR:__main__:❌ Failed for https://digestlibrary.com/2022/09/11/mala-epi_9-complete-by-nimra-ahmad/: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
# ERROR:__main__:❌ Failed for https://digestlibrary.com/2022/09/10/fareb-e-nazer-by-alia-bukhari/: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))

# %%
pip install backoff
# Out:
# Collecting backoff
#   Downloading backoff-2.2.1-py3-none-any.whl.metadata (14 kB)
# Downloading backoff-2.2.1-py3-none-any.whl (15 kB)
# Installing collected packages: backoff
# Successfully installed backoff-2.2.1
